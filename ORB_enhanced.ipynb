# %%
# Imports
import pandas as pd
import numpy as np
import datetime
from datetime import time as dtime
from datetime import timedelta
from datetime import date
import matplotlib as plt

# importing historical data for backtest
def get1minBars(csvName):
    
    priceData1minBars_df = pd.read_csv(csvName, usecols=['date', 'open', 'high', 'low', 'close', 'volume'])
    
    # Parse datetime column and divide in 2 columns
    # SPY_Data['datetime'] = pd.to_datetime(SPY_Data['date'].str.strip(), format='%Y%m%d %H:%M:%S')
    priceData1minBars_df.rename(columns={
        'date': 'datetime'
    }, inplace=True)
    
    priceData1minBars_df['datetime'] = pd.to_datetime(priceData1minBars_df['datetime'])
    
    priceData1minBars_df['Date'] = priceData1minBars_df['datetime'].dt.date
    priceData1minBars_df['Time'] = priceData1minBars_df['datetime'].dt.time
    
    # sorting the data by the time column to make sure it is consistent
    priceData1minBars_df.sort_values('datetime', inplace=True)
    
    # Drop original 'date' column
    # SPY_Data.drop(columns=['date'], inplace=True)
    
    # Filter for regular trading hours using datetime column
    priceData1minBars_df = priceData1minBars_df[priceData1minBars_df['datetime'].dt.time >= pd.to_datetime("09:30").time()]
    priceData1minBars_df = priceData1minBars_df[priceData1minBars_df['datetime'].dt.time <= pd.to_datetime("16:00").time()]
    
    # Making sure the order of the columns stays the same 
    priceData1minBars_df = priceData1minBars_df[['Date', 'Time', 'open', 'high', 'low', 'close', 'volume']]
    
    return priceData1minBars_df

# %%
SPY_Data = get1minBars('SPY_1min_data.csv')
SPY_Data
# Out:
#               Date      Time    open    high     low   close  volume
# 0       2019-12-31  09:30:00  320.52  320.53  320.24  320.27    4255
# 1       2019-12-31  09:31:00  320.27  320.34  320.15  320.33    2049
# 2       2019-12-31  09:32:00  320.35  320.97  320.35  320.97    2953
# 3       2019-12-31  09:33:00  320.98  321.05  320.81  320.82    2529
# 4       2019-12-31  09:34:00  320.83  320.91  320.74  320.80    1373
# ...            ...       ...     ...     ...     ...     ...     ...
# 507925  2025-08-01  15:55:00  622.10  622.29  621.64  622.25    7142
# 507926  2025-08-01  15:56:00  622.27  622.53  622.12  622.46    6161
# 507927  2025-08-01  15:57:00  622.46  622.53  622.22  622.38    7356
# 507928  2025-08-01  15:58:00  622.39  622.44  621.95  621.96   10144
# 507929  2025-08-01  15:59:00  621.97  622.03  621.51  621.71   22237
#
# [544980 rows x 7 columns]

# %%
# higher time frame datageneration

# Uses your adx(df, period=14) that returns ['+DI','-DI','DX','ADX'] on OHLC.
def adx(df, period: int = 14,
        high_col: str = "high", 
        low_col: str = "low", 
        close_col: str = "close"):
    """
    Returns a DataFrame with columns: +DI, -DI, DX, ADX computed with Wilder's smoothing.
    df must have High/Low/Close columns.
    """
    high, low, close = df[high_col].astype(float), df[low_col].astype(float), df[close_col].astype(float)

    # 1) True Range
    prev_close = close.shift(1)
    tr = pd.concat([
        (high - low),
        (high - prev_close).abs(),
        (low - prev_close).abs()
    ], axis=1).max(axis=1)

    # 2) Directional Movement
    up_move = high.diff()
    down_move = -low.diff()  # prev_low - curr_low
    plus_dm  = np.where((up_move > down_move) & (up_move > 0), up_move, 0.0)
    minus_dm = np.where((down_move > up_move) & (down_move > 0), down_move, 0.0)
    plus_dm  = pd.Series(plus_dm, index=df.index)
    minus_dm = pd.Series(minus_dm, index=df.index)

    # 3) Wilder's smoothing (RMA) via EMA with alpha=1/period
    alpha = 1 / period
    atr        = tr.ewm(alpha=alpha, adjust=False).mean()
    plus_dm_sm = plus_dm.ewm(alpha=alpha, adjust=False).mean()
    minus_dm_sm= minus_dm.ewm(alpha=alpha, adjust=False).mean()

    # 4) DIs
    plus_di  = 100 * (plus_dm_sm / atr)
    minus_di = 100 * (minus_dm_sm / atr)

    # 5) DX
    di_sum  = (plus_di + minus_di)
    di_diff = (plus_di - minus_di).abs()
    dx = 100 * (di_diff / di_sum.replace(0, np.nan))

    # 6) ADX
    adx = dx.ewm(alpha=alpha, adjust=False).mean()

    out = pd.DataFrame({
        "+DI": plus_di,
        "-DI": minus_di,
        "DX": dx,
        "ADX": adx
    })
    return out



def adx_HTF(df):
    
    df = df.copy(deep=True)
    
    df['datetime'] = pd.to_datetime(
        df['Date'].astype(str) + ' ' + df['Time'].astype(str)
    )
    
    df_1H = (
        df
        .set_index('datetime')
        .resample('60min', origin='start_day', offset='30min')
        .agg({'open':'first','high':'max','low':'min','close':'last','volume':'sum'})
        .dropna(subset=['open','high','low','close'])
        .reset_index()
    )
    
    df_1H['Date'] = df_1H['datetime'].dt.date
    df_1H['Time'] = df_1H['datetime'].dt.time
    df_1H = df_1H[['Date','Time','open','high','low','close','volume']]
   
        # df has columns: open, high, low, close, volume
    df_1H['ema20'] = df_1H['close'].ewm(span=20, adjust=False).mean().rename('EMA20').shift(1)
    df_1H['ema50'] = df_1H['close'].ewm(span=50, adjust=False).mean().rename('EMA50').shift(1)
    
    # Alignment (1 if uptrend, 0 if downtrend)
    df_1H['ema_alignment'] = (df_1H['ema20'] > df_1H['ema50']).astype(int).rename('EMA_alignment')
        
    # 2) HTF DMI/ADX
    adx_1H = adx(df_1H, period=14)
    df_1H['ADX60']  = adx_1H['ADX'].shift(1)
    df_1H['DIp60']  = adx_1H['+DI'].shift(1)
    df_1H['DIn60']  = adx_1H['-DI'].shift(1)
    df_1H['ADX60_rising3'] = (df_1H['ADX60'] > df_1H['ADX60'].shift(1)) & (df_1H['ADX60'].shift(1) > df_1H['ADX60'].shift(2))
    
    return df_1H



def true_range(df, high_col="high", low_col="low", close_col="close"):
    """
    Wilder's True Range (TR) per bar.
    TR_t = max( high_t - low_t, |high_t - close_{t-1}|, |low_t - close_{t-1}| )
    Returns a pd.Series named 'TR'.
    """
    high  = df[high_col].astype(float)
    low   = df[low_col].astype(float)
    close = df[close_col].astype(float)

    prev_close = close.shift(1)
    tr = pd.concat([
        high - low,
        (high - prev_close).abs(),
        (low  - prev_close).abs()
    ], axis=1).max(axis=1)

    tr.name = "TR"
    return tr


def ATR(df, period: int = 14,
        high_col: str = "high",
        low_col: str = "low",
        close_col: str = "close",
        method: str = "wilder"):
    """
    Average True Range (ATR) over `period`.
    method='wilder' uses RMA (EMA with alpha=1/period), which is the standard.
    method='sma' uses a simple moving average.
    Returns a pd.Series named f'ATR_{period}'.
    """
    tr = true_range(df, high_col, low_col, close_col)

    if method.lower() == "wilder":
        atr = tr.ewm(alpha=1/period, adjust=False).mean()
    elif method.lower() == "sma":
        atr = tr.rolling(window=period, min_periods=period).mean()
    else:
        raise ValueError("method must be 'wilder' or 'sma'")

    atr.name = f"ATR_{period}"
    return atr


def NATR(df, period: int = 14,
         high_col: str = "high",
         low_col: str = "low",
         close_col: str = "close",
         as_percent: bool = False,
         method: str = "wilder"):
    """
    Normalized ATR = ATR / Close  (dimensionless volatility).
    If as_percent=True, returns percentage (×100).
    Returns a pd.Series named f'NATR_{period}' (or '%').
    """
    df['ATR'] = ATR(df, period, high_col, low_col, close_col, method=method)
    close = df[close_col].astype(float)

    df['NATR'] = (df['ATR'] / close).replace([np.inf, -np.inf], np.nan)
    if as_percent:
        df['NATR'] = 100.0 * df['NATR']
    
    # patching future leak
    df['ATR'] = df['ATR'].shift(1)
    df['NATR'] = df['NATR'].shift(1)
    
    # renaming a column
    df = df.rename(columns={'volume': 'volume60'})
    
    return df


# generate the HTF data
def HTF(df):
    
    df = df.copy(deep=True)
    
    # calculate ADX on higher timeframe (1h bars)
    htf = adx_HTF(df)
    
    # calculate the NATR on the HTF (1h bars)
    htf = NATR(htf)
    
    return htf

# %%
htf_test = HTF(SPY_Data)
htf_test
# Out:
#             Date      Time    open    high     low   close  volume60  \
# 0     2019-12-31  09:30:00  320.52  321.54  320.15  320.78     55212
# 1     2019-12-31  10:30:00  320.78  320.87  320.39  320.51     36136
# 2     2019-12-31  11:30:00  320.51  320.88  320.30  320.66     26634
# 3     2019-12-31  12:30:00  320.65  320.82  320.58  320.73     21344
# 4     2019-12-31  13:30:00  320.72  321.03  320.72  321.02     26587
# ...          ...       ...     ...     ...     ...     ...       ...
# 9779  2025-08-01  11:30:00  621.51  624.97  621.38  624.21    103595
# 9780  2025-08-01  12:30:00  624.21  624.46  620.33  620.57    137281
# 9781  2025-08-01  13:30:00  620.57  621.81  619.29  621.62    108451
# 9782  2025-08-01  14:30:00  621.63  623.11  620.95  621.79    142412
# 9783  2025-08-01  15:30:00  621.78  623.30  620.84  621.71    147574
#
#            ema20       ema50  ema_alignment       ADX60      DIp60      DIn60  \
# 0            NaN         NaN              0         NaN        NaN        NaN
# 1     320.780000  320.780000              0         NaN   0.000000   0.000000
# 2     320.754286  320.769412              0         NaN   0.000000   0.000000
# 3     320.745306  320.765121              0  100.000000   0.000000   0.505476
# 4     320.743848  320.763744              0  100.000000   0.000000   0.498243
# ...          ...         ...            ...         ...        ...        ...
# 9779  632.830361  633.309401              0   25.823801  10.663527  46.998798
# 9780  632.009374  632.952561              0   28.047066  11.839346  43.162784
# 9781  630.919910  632.466971              0   30.248836  10.752101  41.533751
# 9782  630.034204  632.041599              0   32.426900  10.140201  41.518732
# 9783  629.249042  631.639576              0   33.787214  12.637961  39.446519
#
#       ADX60_rising3       ATR      NATR
# 0             False       NaN       NaN
# 1             False  1.390000  0.004333
# 2             False  1.325000  0.004134
# 3             False  1.271786  0.003966
# 4             False  1.198087  0.003735
# ...             ...       ...       ...
# 9779           True  3.107280  0.005000
# 9780           True  3.141760  0.005033
# 9781           True  3.212348  0.005176
# 9782           True  3.162895  0.005088
# 9783           True  3.091260  0.004972
#
# [9784 rows x 16 columns]

# %%
# get first breach out of ORB

def get_opening_range(df, date):
    day_df = df[df['Date'] == date].copy()
    mask = (day_df['Time'] >= pd.to_datetime("09:30").time()) & \
           (day_df['Time'] <  pd.to_datetime("9:45").time())
    or_data = day_df.loc[mask]
    if or_data.empty:
        return None, None
    return or_data['high'].max(), or_data['low'].min()


def get_first_breach(df, date):
    high_or, low_or = get_opening_range(df, date)
    if high_or is None:
        return None

    day_df = df[df['Date'] == date].copy()
    # only consider after OR is formed
    intraday = day_df[day_df['Time'] >= pd.to_datetime("9:45").time()]

    for _, row in intraday.iterrows():
        if row['close'] > high_or:   # breach to upside
            return {
                'Date': date,
                'timeBreach': row['Time'],
                'breach': 'high',
                'OR_high': high_or,
                'OR_low': low_or,
            }
        elif row['close'] < low_or:   # breach to downside
            return {
                'Date': date,
                'timeBreach': row['Time'],
                'breach': 'low',
                'OR_high': high_or,
                'OR_low': low_or,
            }
    return None


# get the first retest after the breach
def get_first_retest(data_df, date, breach_df):
    
    day_df = data_df[data_df['Date'] == date].copy()
    breachInfo = breach_df[breach_df['Date'] == date].copy()
    
    high_or = breachInfo['OR_high'].iloc[0]
    low_or = breachInfo['OR_low'].iloc[0]
    timeBreach = breachInfo['timeBreach'].iloc[0]
    typeBreach = breachInfo['breach'].iloc[0]
    
    # only consider after first OR breach
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeBreach)).time()]
    
    fullBreach = False
    
    for _, row in intraday.iterrows():
        
        if typeBreach == 'high':
            if row['low'] > high_or :
                fullBreach = True # we can start looking for a real retest now
        elif typeBreach == 'low':
            if row['high'] < low_or :
                fullBreach = True # we can start looking for a real retest now
        
        if fullBreach == True:
            if typeBreach == 'high':
                if row['low'] <= high_or:   # retest
                    return {
                        'Date': date,
                        'timeBreach': timeBreach,
                        'breach': typeBreach,
                        'OR_high': high_or,
                        'OR_low': low_or,
                        'timeRetest': row['Time']
                    }
            elif typeBreach == 'low':
                if row['high'] >= low_or:   # retest
                    return {
                        'Date': date,
                        'timeBreach': timeBreach,
                        'breach': typeBreach,
                        'OR_high': high_or,
                        'OR_low': low_or,
                        'timeRetest': row['Time']
                    }
    return None

# detect confirmation bar out of ORB after retest
def detectConfirmation(data_df, date, retests_df):
    
    day_df = data_df[data_df['Date'] == date].copy()
    retestInfo = retests_df[retests_df['Date'] == date].copy()
    
    high_or = retestInfo['OR_high'].iloc[0]
    low_or = retestInfo['OR_low'].iloc[0]
    timeRetest = retestInfo['timeRetest'].iloc[0]
    typeBreach = retestInfo['breach'].iloc[0]

    # only consider after first OR breach
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeRetest)).time()]
    
    confirmationBar = False
    
    for _, row in intraday.iterrows():
        
        if typeBreach == 'high':
            if row['low'] > high_or :
                confirmationBar = True # we can start looking for a real retest now
        elif typeBreach == 'low':
            if row['high'] < low_or :
                confirmationBar = True # we can start looking for a real retest now
        
        if confirmationBar == True:
            if typeBreach == 'high':
 
                return {
                    'Date': date,
                    'timeBreach': retestInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': row['Time']
                }
            elif typeBreach == 'low':
                return {
                    'Date': date,
                    'timeBreach': retestInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': row['Time']
                }
    return None



def getORB_retest_data(df):
    
    df = df.copy(deep=True)
    
    breaches = []
    for d in SPY_Data['Date'].unique():
        b = get_first_breach(SPY_Data, d)
        if b:
            breaches.append(b)
    
    breach_df = pd.DataFrame(breaches)
    breach_df
    
    
    
    retests = []
    for d in breach_df['Date'].unique():
        b = get_first_retest(SPY_Data, d, breach_df)
        if b:
            retests.append(b)
    
    retests_df = pd.DataFrame(retests)
    retests_df
    
    
    
    confirmationBars = []
    for d in retests_df['Date'].unique():
        b = detectConfirmation(SPY_Data, d, retests_df)
        if b:
            confirmationBars.append(b)
    
    confirmationBar_df = pd.DataFrame(confirmationBars)
    
    return confirmationBar_df

# %%
BO_and_retest = getORB_retest_data(SPY_Data)
BO_and_retest
# Out:
#             Date timeBreach breach  OR_high  OR_low timeRetest  \
# 0     2019-12-31   09:47:00   high   321.34  320.15   09:50:00
# 1     2020-01-02   10:11:00    low   324.00  323.41   12:41:00
# 2     2020-01-03   10:42:00   high   322.94  321.10   10:46:00
# 3     2020-01-06   09:46:00   high   321.43  320.36   09:55:00
# 4     2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# ...          ...        ...    ...      ...     ...        ...
# 1090  2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1091  2025-07-29   09:48:00    low   638.67  637.93   09:57:00
# 1092  2025-07-30   09:45:00   high   636.05  635.29   11:03:00
# 1093  2025-07-31   10:50:00    low   639.75  637.82   12:14:00
# 1094  2025-08-01   09:45:00    low   626.34  622.26   09:47:00
#
#      timeConfirmationBar
# 0               15:30:00
# 1               12:42:00
# 2               11:45:00
# 3               09:57:00
# 4               11:13:00
# ...                  ...
# 1090            09:59:00
# 1091            10:02:00
# 1092            11:59:00
# 1093            12:47:00
# 1094            09:48:00
#
# [1095 rows x 7 columns]

# %%
def runBacktest(data_df, date, confirmationBar_df, exit_mode="stop", slippage=0.02):
    """
    Backtest function with configurable exit logic and slippage.

    exit_mode options:
    - "stop"       : Exit at stopLoss price when breached (worst-case intrabar fill).
    - "next_open"  : Exit at next bar's open after breach (no intrabar lookahead).
    - "hybrid"     : Exit at stopLoss if touched, else at next bar's open.

    slippage:
    - Applied against you on exit.
    - Longs: exitPrice -= slippage
    - Shorts: exitPrice += slippage
    """
    if str(date) == '2024-11-05':
        print('')
    
    
    day_df = data_df[data_df['Date'] == date].copy()
    signalInfo = confirmationBar_df[confirmationBar_df['Date'] == date].copy()
    
    if signalInfo.empty or day_df.empty:
        return None

    high_or = signalInfo['OR_high'].iloc[0]
    low_or = signalInfo['OR_low'].iloc[0]
    timeRetest = signalInfo['timeRetest'].iloc[0]
    timeConfirmationBar = signalInfo['timeConfirmationBar'].iloc[0]
    typeBreach = signalInfo['breach'].iloc[0]
    
    DI_plus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['+DI'].iloc[0]
    DI_minus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['-DI'].iloc[0]
    ADX = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['ADX'].iloc[0]
    vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['vwap'].iloc[0]
    prev_vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['previous_vwap'].iloc[0]
    
    # only consider after confirmation candle
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)
    if intraday.empty:
        return None
    
    # entry price
    if typeBreach == 'high':
        entryPrice = intraday.iloc[0]['open'] + slippage
    else:
        entryPrice = intraday.iloc[0]['open'] - slippage
    
    
    # initial stop
    if typeBreach == 'high':   # long
        # stopLoss = high_or - ((high_or - low_or) * 0.15)
        stopLoss = low_or
    else:   # short
        # stopLoss = low_or + ((high_or - low_or) * 0.15)
        stopLoss = high_or

    # buffer = fraction of initial risk
    initialRisk = abs(entryPrice - stopLoss)
    buffer = initialRisk

    # loop intraday
    for i in range(len(intraday) - 1):  
        row = intraday.iloc[i]
        next_row = intraday.iloc[i+1]

        if typeBreach == 'high':  # long trade
            if row['close'] >= stopLoss + buffer:
                stopLoss = row['close'] - buffer

            if row['close'] <= stopLoss:  # stop triggered
                if exit_mode == "stop":
                    exitPrice, exitTime = next_row['open'], row['Time']
                elif exit_mode == "next_open":
                    exitPrice, exitTime = next_row['open'], next_row['Time']
                else:
                    raise ValueError("Invalid exit_mode")

                # apply slippage against you
                exitPrice -= slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': exitPrice - entryPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }

        else:  # short trade
            if row['close'] <= stopLoss - buffer:
                stopLoss = row['close'] + buffer

            if row['close'] >= stopLoss:  # stop triggered
                if exit_mode == "stop":
                    exitPrice, exitTime = stopLoss, row['Time']
                elif exit_mode == "next_open":
                    exitPrice, exitTime = next_row['open'], next_row['Time']
                else:
                    raise ValueError("Invalid exit_mode")

                # apply slippage against you
                exitPrice += slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }

    # if stop never hit, exit at last close
    finalExit = intraday.iloc[-1]['close']
    finalExitTime = intraday.iloc[-1]['Time']

    # apply slippage
    if typeBreach == 'high':
        finalExit -= slippage
    else:
        finalExit += slippage

    return {
        'Date': date,
        'timeBreach': signalInfo['timeBreach'].iloc[0],
        'breach': typeBreach,
        'OR_high': high_or,
        'OR_low': low_or,
        'timeRetest': timeRetest,
        'timeConfirmationBar': timeConfirmationBar,
        'timeExit': finalExitTime,
        'entryPrice': entryPrice,
        'exitPrice': finalExit,
        'returns': finalExit - entryPrice if typeBreach == 'high' else entryPrice - finalExit,
        '+DI': DI_plus,
        '-DI': DI_minus,
        'ADX': ADX,
        'vwap': vwap,
        'previous_vwap': prev_vwap
    }

# %%
def runBacktest_WithTargets(data_df, date, confirmationBar_df, TargetMultiplier = 3, slippage=0.04):

    
    day_df = data_df[data_df['Date'] == date].copy()
    signalInfo = confirmationBar_df[confirmationBar_df['Date'] == date].copy()
    
    if signalInfo.empty or day_df.empty:
        return None

    high_or = signalInfo['OR_high'].iloc[0]
    low_or = signalInfo['OR_low'].iloc[0]
    timeRetest = signalInfo['timeRetest'].iloc[0]
    timeConfirmationBar = signalInfo['timeConfirmationBar'].iloc[0]
    typeBreach = signalInfo['breach'].iloc[0]
    
    DI_plus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['+DI'].iloc[0]
    DI_minus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['-DI'].iloc[0]
    ADX = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['ADX'].iloc[0]
    vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['vwap'].iloc[0]
    prev_vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['previous_vwap'].iloc[0]
    
    # only consider after confirmation candle
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)
    if intraday.empty:
        return None
    
    # entry price
    if typeBreach == 'high':
        entryPrice = intraday.iloc[0]['open'] + slippage
    else:
        entryPrice = intraday.iloc[0]['open'] - slippage
    
    
    # initial stop
    if typeBreach == 'high':   # long
        # stopLoss = high_or - ((high_or - low_or) * 0.15)
        stopLoss = low_or
    else:   # short
        # stopLoss = low_or + ((high_or - low_or) * 0.15)
        stopLoss = high_or

    # buffer = fraction of initial risk
    initialRisk = abs(entryPrice - stopLoss)
    buffer = initialRisk

    # loop intraday
    for i in range(len(intraday) - 1):  
        row = intraday.iloc[i]
        next_row = intraday.iloc[i+1]

        if typeBreach == 'high':  # long trade


            if row['close'] <= stopLoss:  # stop triggered
                
                exitPrice, exitTime = next_row['open'], next_row['Time']

                # apply slippage against you
                exitPrice -= slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': exitPrice - entryPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['high'] >= entryPrice + initialRisk * TargetMultiplier: # target Reached 
                exitPrice = entryPrice + initialRisk * TargetMultiplier 
                # apply slippage against you 
                exitPrice -= slippage
                exitTime = row['Time']
                return { 'Date': date,
                         'timeBreach': signalInfo['timeBreach'].iloc[0],
                         'breach': typeBreach,
                         'OR_high': high_or,
                         'OR_low': low_or,
                         'timeRetest': timeRetest,
                         'timeConfirmationBar': timeConfirmationBar,
                         'timeExit': exitTime,
                         'entryPrice': entryPrice,
                         'exitPrice': exitPrice,
                         'returns': exitPrice - entryPrice,
                         '+DI': DI_plus,
                         '-DI': DI_minus,
                         'ADX': ADX,
                         'vwap': vwap,
                         'previous_vwap': prev_vwap }
            
            if row['close'] >= stopLoss + buffer:
                stopLoss = row['close'] - buffer


        else:  # short trade


            if row['close'] >= stopLoss:  # stop triggered
                exitPrice, exitTime = next_row['open'], next_row['Time']

                # apply slippage against you
                exitPrice += slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['low'] <= entryPrice - initialRisk * TargetMultiplier: # target Reached 
                exitPrice = entryPrice - initialRisk * TargetMultiplier 
                # apply slippage against you 
                exitPrice += slippage
                exitTime = row['Time']
                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['close'] <= stopLoss - buffer:
                stopLoss = row['close'] + buffer
                
    # if stop never hit, exit at last close
    finalExit = intraday.iloc[-1]['close']
    finalExitTime = intraday.iloc[-1]['Time']

    # apply slippage
    if typeBreach == 'high':
        finalExit -= slippage
    else:
        finalExit += slippage

    return {
        'Date': date,
        'timeBreach': signalInfo['timeBreach'].iloc[0],
        'breach': typeBreach,
        'OR_high': high_or,
        'OR_low': low_or,
        'timeRetest': timeRetest,
        'timeConfirmationBar': timeConfirmationBar,
        'timeExit': finalExitTime,
        'entryPrice': entryPrice,
        'exitPrice': finalExit,
        'returns': finalExit - entryPrice if typeBreach == 'high' else entryPrice - finalExit,
        '+DI': DI_plus,
        '-DI': DI_minus,
        'ADX': ADX,
        'vwap': vwap,
        'previous_vwap': prev_vwap
    }

# %%
SPY_Data_VWAP = SPY_Data.copy(deep=True)

SPY_Data_VWAP['pv'] = (SPY_Data_VWAP['high'] + SPY_Data_VWAP['low'] + SPY_Data_VWAP['close']) * SPY_Data_VWAP['volume'] / 3
SPY_Data_VWAP['cum_pv'] = SPY_Data_VWAP.groupby('Date')['pv'].cumsum()
SPY_Data_VWAP['cum_vol'] = SPY_Data_VWAP.groupby('Date')['volume'].cumsum()
SPY_Data_VWAP['vwap'] = SPY_Data_VWAP['cum_pv'] / SPY_Data_VWAP['cum_vol']
previous_vwap = SPY_Data_VWAP.groupby('Date')['vwap'].last()
SPY_Data_VWAP['previous_vwap'] = SPY_Data_VWAP['Date'].map(previous_vwap.shift(1))

# SPY_Data_VWAP = SPY_Data_VWAP.iloc[390:,]
# SPY_Data_VWAP




# df has columns: Date, Open, High, Low, Close, Volume
adx_df = adx(SPY_Data, period=14)
adx_df = SPY_Data_VWAP.join(adx_df)
adx_df['ADX'] = adx_df['ADX'].shift(1)


adx_df = adx_df.iloc[390:,]



# Run backtest
backtest = []
for d in BO_and_retest['Date'].unique():
    b = runBacktest_WithTargets(adx_df, d, BO_and_retest)
    if b:
        backtest.append(b)

backtest_df = pd.DataFrame(backtest)
print("Total PnL:", backtest_df['returns'].sum())
backtest_df
# Out:
# Total PnL: 19.249999999983487
#             Date timeBreach breach  OR_high  OR_low timeRetest  \
# 0     2020-01-02   10:11:00    low   324.00  323.41   12:41:00
# 1     2020-01-03   10:42:00   high   322.94  321.10   10:46:00
# 2     2020-01-06   09:46:00   high   321.43  320.36   09:55:00
# 3     2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# 4     2020-01-09   09:46:00    low   326.47  325.87   09:48:00
# ...          ...        ...    ...      ...     ...        ...
# 1089  2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1090  2025-07-29   09:48:00    low   638.67  637.93   09:57:00
# 1091  2025-07-30   09:45:00   high   636.05  635.29   11:03:00
# 1092  2025-07-31   10:50:00    low   639.75  637.82   12:14:00
# 1093  2025-08-01   09:45:00    low   626.34  622.26   09:47:00
#
#      timeConfirmationBar  timeExit  entryPrice  exitPrice  returns        +DI  \
# 0               12:42:00  14:43:00      323.32     323.78    -0.46  36.389123
# 1               11:45:00  15:59:00      323.08     322.40    -0.68  27.679027
# 2               09:57:00  15:59:00      321.67     323.63     1.96  22.183990
# 3               11:13:00  15:50:00      323.62     324.58     0.96  30.934500
# 4               10:02:00  10:40:00      325.80     326.51    -0.71  19.087368
# ...                  ...       ...         ...        ...      ...        ...
# 1089            09:59:00  10:18:00      635.15     634.06    -1.09  28.687251
# 1090            10:02:00  11:28:00      637.88     635.55     2.33  21.014290
# 1091            11:59:00  14:38:00      636.20     636.56     0.36  33.638253
# 1092            12:47:00  14:28:00      637.55     634.02     3.53  16.225020
# 1093            09:48:00  12:07:00      621.48     624.89    -3.41   9.660471
#
#             -DI        ADX        vwap  previous_vwap
# 0     11.188261  21.224700  323.285371     321.132256
# 1     13.209203  24.469975  322.502957     323.630248
# 2     32.969274  24.218411  321.187351     322.772024
# 3     13.796344  25.297917  323.423256     322.923538
# 4     23.236385  17.128724  326.100222     324.556639
# ...         ...        ...         ...            ...
# 1089  19.533504  26.412032  634.658527     632.050872
# 1090  21.244910  22.842343  638.075902     636.841146
# 1091   8.497658  31.365205  635.860109     636.097311
# 1092  35.922195  19.319053  637.965776     634.709197
# 1093  49.292562  59.109188  623.760283     635.397610
#
# [1094 rows x 16 columns]

# %%
# function that helps joining the higher time frame data to the lower time frame data for when making decisions
def join_HTF_to_LTF_data(LTF, HTF):
    
    LTF = LTF.copy(deep=True)
    HTF = HTF.copy(deep=True)
    
    LTF['ts'] = pd.to_datetime(LTF['Date'].astype(str) + ' ' + LTF['timeConfirmationBar'].astype(str), errors='coerce')
    LTF['ts_30'] = (LTF['ts'] - pd.Timedelta('30min')).dt.floor('H') + pd.Timedelta('30min')
    LTF['hour_rounded_down'] = LTF['ts_30'].dt.strftime('%H:%M:%S')
    
    # temp = temp.copy(deep=True)
    
    # 1) Make Date real datetimes (same tz & day-level)
    for df in (LTF, HTF):
        df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.tz_localize(None).dt.normalize()
    
    # 2) Build matching time string keys
    LTF['time_key'] = LTF['ts_30'].dt.strftime('%H:%M:%S')        # you already have ts_30
    HTF['Time_key'] = pd.to_datetime(
        HTF['Time'], format='%H:%M:%S', errors='coerce'
    ).dt.strftime('%H:%M:%S')
    
    # 3) (Optional) ensure right side is unique per key
    htf_keyed = HTF.drop_duplicates(['Date','Time_key'])
    
    # tracking column names
    LTF_columns = LTF.columns
    
    
    # 4) Merge
    LTF = LTF.merge(
        htf_keyed,
        left_on=['Date','time_key'],
        right_on=['Date','Time_key'],
        how='left',
        validate='many_to_one'
    )
    
    new_cols = ['ema20', 'ema50', 'ema_alignment','volume60','ADX60','DIp60','DIn60','ADX60_rising3','ATR','NATR']
    LTF = LTF[[*LTF_columns, *new_cols]]
    LTF = LTF.drop(columns=['ts', 'ts_30', 'hour_rounded_down'])
    
    return LTF

# %%
def trade_stats(df, pnl_col='returns', r_col=None, equity_start=0.0):
    """
    df must have a PnL column (default: 'returns').
    If you also have an R-multiple column, pass its name via r_col.
    Returns (stats_dict, equity_series, drawdown_series).
    """
    # sort (optional, helps equity curve look right)
    if {'Date','timeExit'}.issubset(df.columns):
        df = df.sort_values(['Date','timeExit'])
    s = pd.Series(df[pnl_col].astype(float).values)
    n = int(s.size)
    if n == 0:
        return {}, pd.Series(dtype=float), pd.Series(dtype=float)

    wins   = s[s > 0]
    losses = s[s < 0]

    gross_profit = float(wins.sum())
    gross_loss   = float(-losses.sum())  # positive number

    win_rate  = float(len(wins) / (len(wins) + len(losses)))
    loss_rate = float(len(losses) / (len(wins) + len(losses)))

    avg_win  = float(wins.mean())   if len(wins)   else 0.0
    avg_loss = float(losses.mean()) if len(losses) else 0.0  # negative
    payoff   = (avg_win / abs(avg_loss)) if len(wins) and len(losses) else np.inf

    profit_factor = (gross_profit / gross_loss) if gross_loss > 0 else np.inf
    expectancy    = win_rate * avg_win + loss_rate * avg_loss  # per trade

    equity = pd.Series(equity_start + s.cumsum(), name='equity')
    run_max = equity.cummax()
    drawdown = equity - run_max
    max_dd = float(drawdown.min())  # negative

    std = float(s.std(ddof=1))
    sharpe_per_trade = (float(s.mean() - 0.04) / std * np.sqrt(n)) if std > 0 and n > 1 else np.nan

    stats = {
        'n_trades': n,
        'win_rate': win_rate,
        'avg_win': avg_win,
        'avg_loss': avg_loss,                 # negative number
        'payoff_ratio': payoff,               # |avg_win| / |avg_loss|
        'expectancy_per_trade': expectancy,   # same units as returns
        'gross_profit': gross_profit,
        'gross_loss': gross_loss,
        'profit_factor': profit_factor,
        'total_pnl': float(s.sum()),
        'median_pnl': float(s.median()),
        'max_drawdown': max_dd,               # same units as returns
        'sharpe_per_trade': sharpe_per_trade
    }

    if r_col and r_col in df.columns:
        r = df[r_col].astype(float)
        stats.update({
            'avg_R': float(r.mean()),
            'median_R': float(r.median()),
            'total_R': float(r.sum()),
            'win_rate_Rpos': float((r > 0).mean())
        })

    return stats, equity, drawdown







temp = backtest_df.copy(deep=True)

temp = join_HTF_to_LTF_data(temp, htf_test)

temp = temp[temp['Date'] != datetime.date(2025, 4, 9)]
temp = temp[temp['Date'] != pd.Timestamp('2025-04-09')]


temp['ORB_width'] = (temp['OR_high'] - temp['OR_low'])/ temp['OR_low']* 100

# temp = temp[(temp['ORB_width'] > 0.15) & (temp['ORB_width'] < 0.5)]
# temp = temp[temp['ORB_width'] < 0.5]

# temp = backtest_df2[backtest_df2['timeConfirmationBar'] > dtime(15, 0)]

# temp = temp[temp['returns'] > 0]
# mask = (temp['breach'] == 'high') & (temp['+DI'] > temp['-DI']) & (temp['ADX'] > 18)
# temp['returns'] = temp['returns'].where(mask, 0) 

# print(temp['ADX'].median())

# mask = ~((temp['breach'] == 'low') & (temp['DIp60'] > temp['DIn60']) & (temp['ADX60'] < 18)) #& (temp['ADX60_rising3'] == False)
# temp['returns'] = temp['returns'].where(mask, 0) 

# temp = temp[(temp['ORB_width'] < 0.5) & (temp['ADX60'] > 18) & (((temp['DIp60'] > temp['DIn60']) & (temp['breach'] == 'high')) | ((temp['DIp60'] < temp['DIn60']) & (temp['breach'] == 'low'))) & (temp['ADX'] > 12)]

# temp = temp[(temp['ORB_width'] < 0.3) & (temp['ADX60'] > 18) & (((temp['ema20'] > temp['ema50']) & (temp['breach'] == 'high')) | ((temp['ema20'] < temp['ema50']) & (temp['breach'] == 'low'))) & (temp['ADX'] > 12) & (((temp['+DI'] > temp['-DI']) & (temp['breach'] == 'high')) | ((temp['+DI'] < temp['-DI']) & (temp['breach'] == 'low'))) & (((temp['entryPrice'] > temp['vwap']) & (temp['breach'] == 'high')) | ((temp['entryPrice'] < temp['vwap']) & (temp['breach'] == 'low')))]

# best win to dd
#[0.3, 18, None, None, None, True, 12, True, False]
# best win rate
#[0.5, 18, None, None, None, None, 20, True, False]


# mask = ~((temp['breach'] == 'high') & (temp['entryPrice'] < temp['vwap']))
# temp['returns'] = temp['returns'].where(mask, 0) 

print('Number of trades: ', temp[temp['returns']!= 0]['returns'].count())
temp['returns'] = temp['returns'] * 50 

stats, equity, dd = trade_stats(temp, pnl_col='returns')  # or r_col='R' if you have it
print(pd.Series(stats))



if 'Date' in temp.columns:
    temp['Date'] = pd.to_datetime(temp['Date'], errors='coerce')
    df = temp.sort_values('Date')

r = pd.to_numeric(df['returns'], errors='coerce').fillna(0)

# 1) Cumulative PnL (use for per-trade PnL/points)
df['cum_pnl'] = r.cumsum()


import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(df['Date'] if 'Date' in df.columns else df.index, df['cum_pnl'])
plt.title('Cumulative PnL')
plt.xlabel('Date' if 'Date' in df.columns else 'Trade #')
plt.ylabel('PnL')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()



temp
# Out:
# Number of trades:  1092
# n_trades                 1093.000000
# win_rate                    0.391026
# avg_win                    97.528103
# avg_loss                  -63.645113
# payoff_ratio                1.532374
# expectancy_per_trade       -0.622253
# gross_profit            41644.500000
# gross_loss              42324.000000
# profit_factor               0.983945
# total_pnl                -679.500000
# median_pnl                -22.000000
# max_drawdown            -4718.500000
# sharpe_per_trade           -0.199912
# dtype: float64
#            Date timeBreach breach  OR_high  OR_low timeRetest  \
# 0    2020-01-02   10:11:00    low   324.00  323.41   12:41:00
# 1    2020-01-03   10:42:00   high   322.94  321.10   10:46:00
# 2    2020-01-06   09:46:00   high   321.43  320.36   09:55:00
# 3    2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# 4    2020-01-09   09:46:00    low   326.47  325.87   09:48:00
# ...         ...        ...    ...      ...     ...        ...
# 1089 2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1090 2025-07-29   09:48:00    low   638.67  637.93   09:57:00
# 1091 2025-07-30   09:45:00   high   636.05  635.29   11:03:00
# 1092 2025-07-31   10:50:00    low   639.75  637.82   12:14:00
# 1093 2025-08-01   09:45:00    low   626.34  622.26   09:47:00
#
#      timeConfirmationBar  timeExit  entryPrice  exitPrice  ...       ema50  \
# 0               12:42:00  14:43:00      323.32     323.78  ...  321.098323
# 1               11:45:00  15:59:00      323.08     322.40  ...  321.598776
# 2               09:57:00  15:59:00      321.67     323.63  ...  321.843003
# 3               11:13:00  15:50:00      323.62     324.58  ...  322.353723
# 4               10:02:00  10:40:00      325.80     326.51  ...  322.879630
# ...                  ...       ...         ...        ...  ...         ...
# 1089            09:59:00  10:18:00      635.15     634.06  ...  628.011180
# 1090            10:02:00  11:28:00      637.88     635.55  ...  632.756108
# 1091            11:59:00  14:38:00      636.20     636.56  ...  633.664124
# 1092            12:47:00  14:28:00      637.55     634.02  ...  634.359902
# 1093            09:48:00  12:07:00      621.48     624.89  ...  634.216356
#
#       ema_alignment  volume60      ADX60      DIp60      DIn60 ADX60_rising3  \
# 0                 1     29925  94.169703  17.336585   1.138629         False
# 1                 1     42222  81.288298  19.176507  16.290885         False
# 2                 1     80736  58.381624  18.020335  19.912363         False
# 3                 1     51908  26.603792  20.851126  18.711194         False
# 4                 1     67463  25.953374  24.447575  15.537389         False
# ...             ...       ...        ...        ...        ...           ...
# 1089              1     93199  27.222619  35.969261  11.672061          True
# 1090              1     74009  32.240598  25.966579  18.964144         False
# 1091              1     37272  19.579287  24.020484  22.175622         False
# 1092              1     60882  16.917541  24.345256  26.954579         False
# 1093              1    214909  19.882191  15.768141  34.429888          True
#
#            ATR      NATR  ORB_width
# 0     1.088863  0.003370   0.182431
# 1     1.160276  0.003596   0.573030
# 2     1.049477  0.003255   0.333999
# 3     0.899041  0.002780   0.269625
# 4     0.965456  0.002976   0.184123
# ...        ...       ...        ...
# 1089  1.428511  0.002253   0.145113
# 1090  1.109081  0.001741   0.116000
# 1091  1.309101  0.002061   0.119630
# 1092  2.123122  0.003327   0.302593
# 1093  2.437082  0.003857   0.655674
#
# [1093 rows x 28 columns]

# %%
from itertools import product

def make_param_grid():
    grid = {
        # HTF regime
        'ORB_width'        : [None, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8],
        'ADX60'        : [None, 12, 14, 16, 18, 20, 22, 24],
        'ADX60_rising3' : [None, True, False],
        'DIp60_over_DIn60' : [None, True, False],
        'NATR' : [None, 0.0075, 0.010, 0.0125, 0.0150, 0.0175],
        'ema20_over_ema50' : [None, True, False],
        'ADX' : [None, 12, 14, 16, 18, 20, 22, 24],
        'DI+_over_DI-' : [None, True, False],
        'vwap' : [None, True, False],
        'excludeSide' : [None, 'high', 'low'],
    }

    keys, vals = zip(*grid.items())
    combos = [dict(zip(keys, v)) for v in product(*vals)]
    return combos

# %%
def testParameters(df, bestReturns, bestWinrate, bestWinToDrawdown, ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide):
    df = df.copy(deep=True)

    # ORB_width
    if ORB_width != None:
        df = df[df['ORB_width'] < ORB_width]

    # ADX60
    if ADX60 != None:
        df = df[df['ADX60'] > ADX60]

    # ADX60 rising
    if ADX60_rising3 != None:
        df = df[df['ADX60_rising3'] == ADX60_rising3]

    # DIp60_over_DIn60
    if DIp60_over_DIn60 != None:
        if DIp60_over_DIn60 == True:
            df = df[((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] < df['DIn60']) & (df['breach'] == 'low'))]
        elif DIp60_over_DIn60 == False:
            df = df[((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] > df['DIn60']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # NATR
    if NATR != None:
        df = df[df['NATR'] > NATR]

    # ema20_over_ema50
    if ema20_over_ema50 != None:
        if ema20_over_ema50 == True:
            df = df[((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] < df['ema50']) & (df['breach'] == 'low'))]
        elif ema20_over_ema50 == False:
            df = df[((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] > df['ema50']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX != None:
        df = df[df['ADX'] > ADX]

    # DI+_over_DI-
    if DIp_over_DIn != None:
        if DIp_over_DIn == True:
            df = df[((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] < df['-DI']) & (df['breach'] == 'low'))]
        elif DIp_over_DIn == False:
            df = df[((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] > df['-DI']) & (df['breach'] == 'low'))]
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap != None:
        if vwap == True:
            df = df[((vwap < df['entryPrice']) & (df['breach'] == 'high')) | ((vwap > df['entryPrice']) & (df['breach'] == 'low'))]
        elif vwap == False:
            df = df[((vwap > df['entryPrice']) & (df['breach'] == 'high')) | ((vwap < df['entryPrice']) & (df['breach'] == 'low'))]
        else:
            print('error with vwap')

    
    if excludeSide != None:
        if excludeSide == 'high':
            df = df[df['breach'] != 'high']
        elif excludeSide == 'low':
            df = df[df['breach'] != 'high']
        else:
            print('error with excludeSide')
            

    stats, equity, dd = trade_stats(df, pnl_col='returns')
    # print(pd.Series(stats))
    if len(df) > 250:
        if bestReturns == 0:
            bestReturns = stats
        if bestWinrate == 0:
            bestWinrate = stats
        if bestWinToDrawdown == 0:
            bestWinToDrawdown = stats

        if stats['total_pnl'] > bestReturns['total_pnl']:
            bestReturns = stats
            print('new bestReturns:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                   NATR, ema20_over_ema50, ADX, DIp_over_DIn, vwap])
        if stats['win_rate'] > bestWinrate['win_rate']:
            bestWinrate = stats
            print('new win_rate:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                   NATR, ema20_over_ema50, ADX, DIp_over_DIn, vwap])
        if ((stats['total_pnl'] / max(-stats['max_drawdown'], 1e-9)) > (
                bestWinToDrawdown['total_pnl'] / max(-bestWinToDrawdown['max_drawdown'], 1e-9))) & (
                stats['total_pnl'] > 0):
            bestWinToDrawdown = stats
            print('new bestWinToDrawdown:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                   NATR, ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
            
            

    return stats, bestReturns, bestWinrate, bestWinToDrawdown




bestReturns = 0
bestWinrate = 0
bestWinToDrawdown = 0

for p in make_param_grid():
    stats, bestReturns, bestWinrate, bestWinToDrawdown = testParameters(temp,
                                                                        bestReturns,
                                                                        bestWinrate,
                                                                        bestWinToDrawdown,
                                                                        ORB_width=p['ORB_width'],
                                                                        ADX60=p['ADX60'],
                                                                        ADX60_rising3=p['ADX60_rising3'],
                                                                        DIp60_over_DIn60=p['DIp60_over_DIn60'],
                                                                        # NATR=p['NATR'],
                                                                        ema20_over_ema50=p['ema20_over_ema50'],
                                                                        ADX=p['ADX'],
                                                                        DIp_over_DIn=p['DI+_over_DI-'],
                                                                        vwap=p['vwap'],
                                                                        excludeSide=p['excludeSide']
                                                                        )
    # if (len(stats) > 0):
    #     print(stats['total_pnl'])
    # print(pd.Series(stats))
print('bestReturns:\n', pd.Series(bestReturns))
print('bestWinrate:\n', pd.Series(bestWinrate))
print('bestWinToDrawdown:\n', pd.Series(bestWinToDrawdown))
# Out:
# new bestReturns: n_trades                  558.000000
# win_rate                    0.412926
# avg_win                    92.406522
# avg_loss                  -61.045872
# payoff_ratio                1.513723
# expectancy_per_trade        2.318671
# gross_profit            21253.500000
# gross_loss              19962.000000
# profit_factor               1.064698
# total_pnl                1291.500000
# median_pnl                -15.750000
# max_drawdown            -2278.500000
# sharpe_per_trade            0.527137
# dtype: float64
# [None, None, None, None, None, None, None, None, True]
# new win_rate: n_trades                  558.000000
# win_rate                    0.412926
# avg_win                    92.406522
# avg_loss                  -61.045872
# payoff_ratio                1.513723
# expectancy_per_trade        2.318671
# gross_profit            21253.500000
# gross_loss              19962.000000
# profit_factor               1.064698
# total_pnl                1291.500000
# median_pnl                -15.750000
# max_drawdown            -2278.500000
# sharpe_per_trade            0.527137
# dtype: float64
# [None, None, None, None, None, None, None, None, True]
# new bestWinToDrawdown: n_trades                  558.000000
# win_rate                    0.412926
# avg_win                    92.406522
# avg_loss                  -61.045872
# payoff_ratio                1.513723
# expectancy_per_trade        2.318671
# gross_profit            21253.500000
# gross_loss              19962.000000
# profit_factor               1.064698
# total_pnl                1291.500000
# median_pnl                -15.750000
# max_drawdown            -2278.500000
# sharpe_per_trade            0.527137
# dtype: float64
# [None, None, None, None, None, None, None, None, True]
# new win_rate: n_trades                  444.000000
# win_rate                    0.417607
# avg_win                    92.029730
# avg_loss                  -61.517442
# payoff_ratio                1.495994
# expectancy_per_trade        2.604966
# gross_profit            17025.500000
# gross_loss              15871.500000
# profit_factor               1.072709
# total_pnl                1154.000000
# median_pnl                -16.500000
# max_drawdown            -2521.000000
# sharpe_per_trade            0.525170
# dtype: float64
# [None, None, None, None, None, None, None, True, True]
# new bestReturns: n_trades                  543.000000
# win_rate                    0.418819
# avg_win                    92.585903
# avg_loss                  -61.677778
# payoff_ratio                1.501123
# expectancy_per_trade        2.930812
# gross_profit            21017.000000
# gross_loss              19428.500000
# profit_factor               1.081761
# total_pnl                1588.500000
# median_pnl                -15.500000
# max_drawdown            -2217.500000
# sharpe_per_trade            0.654123
# dtype: float64
# [None, None, None, None, None, None, 12, None, True]
# new win_rate: n_trades                  543.000000
# win_rate                    0.418819
# avg_win                    92.585903
# avg_loss                  -61.677778
# payoff_ratio                1.501123
# expectancy_per_trade        2.930812
# gross_profit            21017.000000
# gross_loss              19428.500000
# profit_factor               1.081761
# total_pnl                1588.500000
# median_pnl                -15.500000
# max_drawdown            -2217.500000
# sharpe_per_trade            0.654123
# dtype: float64
# [None, None, None, None, None, None, 12, None, True]
# new bestWinToDrawdown: n_trades                  543.000000
# win_rate                    0.418819
# avg_win                    92.585903
# avg_loss                  -61.677778
# payoff_ratio                1.501123
# expectancy_per_trade        2.930812
# gross_profit            21017.000000
# gross_loss              19428.500000
# profit_factor               1.081761
# total_pnl                1588.500000
# median_pnl                -15.500000
# max_drawdown            -2217.500000
# sharpe_per_trade            0.654123
# dtype: float64
# [None, None, None, None, None, None, 12, None, True]
# new win_rate: n_trades                  431.000000
# win_rate                    0.423256
# avg_win                    92.247253
# avg_loss                  -61.979839
# payoff_ratio                1.488343
# expectancy_per_trade        3.297674
# gross_profit            16789.000000
# gross_loss              15371.000000
# profit_factor               1.092252
# total_pnl                1418.000000
# median_pnl                -16.000000
# max_drawdown            -2473.000000
# sharpe_per_trade            0.651566
# dtype: float64
# [None, None, None, None, None, None, 12, True, True]
# new bestWinToDrawdown: n_trades                  501.000000
# win_rate                    0.420000
# avg_win                    93.616667
# avg_loss                  -62.808621
# payoff_ratio                1.490507
# expectancy_per_trade        2.890000
# gross_profit            19659.500000
# gross_loss              18214.500000
# profit_factor               1.079332
# total_pnl                1445.000000
# median_pnl                -15.500000
# max_drawdown            -1971.500000
# sharpe_per_trade            0.610489
# dtype: float64
# [None, None, None, None, None, None, 14, None, True]
# new win_rate: n_trades                  390.000000
# win_rate                    0.424165
# avg_win                    93.524242
# avg_loss                  -63.475446
# payoff_ratio                1.473392
# expectancy_per_trade        3.118252
# gross_profit            15431.500000
# gross_loss              14218.500000
# profit_factor               1.085311
# total_pnl                1213.000000
# median_pnl                -16.000000
# max_drawdown            -2338.500000
# sharpe_per_trade            0.574965
# dtype: float64
# [None, None, None, None, None, None, 14, True, True]
# new win_rate: n_trades                  403.000000
# win_rate                    0.435323
# avg_win                    91.397143
# avg_loss                  -64.696035
# payoff_ratio                1.412716
# expectancy_per_trade        3.254975
# gross_profit            15994.500000
# gross_loss              14686.000000
# profit_factor               1.089098
# total_pnl                1308.500000
# median_pnl                -13.500000
# max_drawdown            -1263.000000
# sharpe_per_trade            0.623299
# dtype: float64
# [None, None, None, None, None, None, 18, None, True]
# new bestWinToDrawdown: n_trades                  403.000000
# win_rate                    0.435323
# avg_win                    91.397143
# avg_loss                  -64.696035
# payoff_ratio                1.412716
# expectancy_per_trade        3.254975
# gross_profit            15994.500000
# gross_loss              14686.000000
# profit_factor               1.089098
# total_pnl                1308.500000
# median_pnl                -13.500000
# max_drawdown            -1263.000000
# sharpe_per_trade            0.623299
# dtype: float64
# [None, None, None, None, None, None, 18, None, True]
# new win_rate: n_trades                  309.000000
# win_rate                    0.441558
# avg_win                    91.102941
# avg_loss                  -65.912791
# payoff_ratio                1.382174
# expectancy_per_trade        3.418831
# gross_profit            12390.000000
# gross_loss              11337.000000
# profit_factor               1.092882
# total_pnl                1053.000000
# median_pnl                -14.500000
# max_drawdown            -1462.000000
# sharpe_per_trade            0.568238
# dtype: float64
# [None, None, None, None, None, None, 18, True, True]
# new win_rate: n_trades                  351.000000
# win_rate                    0.448571
# avg_win                    89.098726
# avg_loss                  -65.658031
# payoff_ratio                1.357012
# expectancy_per_trade        3.761429
# gross_profit            13988.500000
# gross_loss              12672.000000
# profit_factor               1.103890
# total_pnl                1316.500000
# median_pnl                -11.000000
# max_drawdown            -1210.000000
# sharpe_per_trade            0.688447
# dtype: float64
# [None, None, None, None, None, None, 20, None, True]
# new bestWinToDrawdown: n_trades                  351.000000
# win_rate                    0.448571
# avg_win                    89.098726
# avg_loss                  -65.658031
# payoff_ratio                1.357012
# expectancy_per_trade        3.761429
# gross_profit            13988.500000
# gross_loss              12672.000000
# profit_factor               1.103890
# total_pnl                1316.500000
# median_pnl                -11.000000
# max_drawdown            -1210.000000
# sharpe_per_trade            0.688447
# dtype: float64
# [None, None, None, None, None, None, 20, None, True]
# new win_rate: n_trades                  266.000000
# win_rate                    0.456604
# avg_win                    87.119835
# avg_loss                  -66.437500
# payoff_ratio                1.311305
# expectancy_per_trade        3.677358
# gross_profit            10541.500000
# gross_loss               9567.000000
# profit_factor               1.101861
# total_pnl                 974.500000
# median_pnl                -12.000000
# max_drawdown            -1075.000000
# sharpe_per_trade            0.591638
# dtype: float64
# [None, None, None, None, None, None, 20, True, True]
# new bestWinToDrawdown: n_trades                  306.000000
# win_rate                    0.434641
# avg_win                    92.342105
# avg_loss                  -63.141618
# payoff_ratio                1.462460
# expectancy_per_trade        4.437908
# gross_profit            12281.500000
# gross_loss              10923.500000
# profit_factor               1.124319
# total_pnl                1358.000000
# median_pnl                -13.000000
# max_drawdown            -1027.500000
# sharpe_per_trade            0.773877
# dtype: float64
# [None, None, None, None, None, None, 22, None, True]
# new bestReturns: n_trades                  581.000000
# win_rate                    0.417241
# avg_win                    96.041322
# avg_loss                  -62.508876
# payoff_ratio                1.536443
# expectancy_per_trade        3.644828
# gross_profit            23242.000000
# gross_loss              21128.000000
# profit_factor               1.100057
# total_pnl                2114.000000
# median_pnl                -16.000000
# max_drawdown            -3696.000000
# sharpe_per_trade            0.786362
# dtype: float64
# [None, None, None, None, None, True, None, None, None]
# new bestWinToDrawdown: n_trades                  384.000000
# win_rate                    0.430809
# avg_win                    75.821212
# avg_loss                  -49.185780
# payoff_ratio                1.541527
# expectancy_per_trade        4.668407
# gross_profit            12510.500000
# gross_loss              10722.500000
# profit_factor               1.166752
# total_pnl                1788.000000
# median_pnl                -12.500000
# max_drawdown            -1254.500000
# sharpe_per_trade            1.136695
# dtype: float64
# [None, None, None, None, None, True, None, None, True]
# new bestReturns: n_trades                  566.000000
# win_rate                    0.419469
# avg_win                    96.670886
# avg_loss                  -63.289634
# payoff_ratio                1.527436
# expectancy_per_trade        3.808850
# gross_profit            22911.000000
# gross_loss              20759.000000
# profit_factor               1.103666
# total_pnl                2152.000000
# median_pnl                -15.750000
# max_drawdown            -3590.500000
# sharpe_per_trade            0.803520
# dtype: float64
# [None, None, None, None, None, True, 12, None, None]
# new bestReturns: n_trades                  523.000000
# win_rate                    0.425287
# avg_win                    97.806306
# avg_loss                  -64.566667
# payoff_ratio                1.514811
# expectancy_per_trade        4.488506
# gross_profit            21713.000000
# gross_loss              19370.000000
# profit_factor               1.120960
# total_pnl                2343.000000
# median_pnl                -15.500000
# max_drawdown            -3309.000000
# sharpe_per_trade            0.893856
# dtype: float64
# [None, None, None, None, None, True, 14, None, None]
# new bestWinToDrawdown: n_trades                  339.000000
# win_rate                    0.440828
# avg_win                    75.677852
# avg_loss                  -50.177249
# payoff_ratio                1.508210
# expectancy_per_trade        5.303254
# gross_profit            11276.000000
# gross_loss               9483.500000
# profit_factor               1.189012
# total_pnl                1792.500000
# median_pnl                -12.000000
# max_drawdown            -1066.000000
# sharpe_per_trade            1.200478
# dtype: float64
# [None, None, None, None, None, True, 14, None, True]
# new bestReturns: n_trades                  476.000000
# win_rate                    0.429474
# avg_win                   100.397059
# avg_loss                  -64.221402
# payoff_ratio                1.563296
# expectancy_per_trade        6.477895
# gross_profit            20481.000000
# gross_loss              17404.000000
# profit_factor               1.176798
# total_pnl                3077.000000
# median_pnl                -13.500000
# max_drawdown            -2592.000000
# sharpe_per_trade            1.215613
# dtype: float64
# [None, None, None, None, None, True, 16, None, None]
# new bestReturns: n_trades                  420.000000
# win_rate                    0.443914
# avg_win                   101.155914
# avg_loss                  -65.049356
# payoff_ratio                1.555064
# expectancy_per_trade        8.731504
# gross_profit            18815.000000
# gross_loss              15156.500000
# profit_factor               1.241382
# total_pnl                3658.500000
# median_pnl                -11.750000
# max_drawdown            -1614.000000
# sharpe_per_trade            1.520436
# dtype: float64
# [None, None, None, None, None, True, 18, None, None]
# new bestWinToDrawdown: n_trades                  420.000000
# win_rate                    0.443914
# avg_win                   101.155914
# avg_loss                  -65.049356
# payoff_ratio                1.555064
# expectancy_per_trade        8.731504
# gross_profit            18815.000000
# gross_loss              15156.500000
# profit_factor               1.241382
# total_pnl                3658.500000
# median_pnl                -11.750000
# max_drawdown            -1614.000000
# sharpe_per_trade            1.520436
# dtype: float64
# [None, None, None, None, None, True, 18, None, None]
# new bestWinToDrawdown: n_trades                 264.000000
# win_rate                   0.456274
# avg_win                   76.112500
# avg_loss                 -51.017483
# payoff_ratio               1.491891
# expectancy_per_trade       6.988593
# gross_profit            9133.500000
# gross_loss              7295.500000
# profit_factor              1.251936
# total_pnl               1838.000000
# median_pnl                -8.000000
# max_drawdown            -781.500000
# sharpe_per_trade           1.407630
# dtype: float64
# [None, None, None, None, None, True, 18, None, True]
# new bestWinToDrawdown: n_trades                  327.000000
# win_rate                    0.450920
# avg_win                    98.789116
# avg_loss                  -67.000000
# payoff_ratio                1.474464
# expectancy_per_trade        7.757669
# gross_profit            14522.000000
# gross_loss              11993.000000
# profit_factor               1.210873
# total_pnl                2529.000000
# median_pnl                -11.500000
# max_drawdown            -1051.000000
# sharpe_per_trade            1.167407
# dtype: float64
# [None, None, None, None, None, True, 18, True, None]
# new win_rate: n_trades                 251.000000
# win_rate                   0.458167
# avg_win                   75.173913
# avg_loss                 -46.047794
# payoff_ratio               1.632519
# expectancy_per_trade       9.492032
# gross_profit            8645.000000
# gross_loss              6262.500000
# profit_factor              1.380439
# total_pnl               2382.500000
# median_pnl                -7.000000
# max_drawdown            -782.000000
# sharpe_per_trade           1.836537
# dtype: float64
# [None, None, None, True, None, None, None, True, True]
# new bestWinToDrawdown: n_trades                 251.000000
# win_rate                   0.458167
# avg_win                   75.173913
# avg_loss                 -46.047794
# payoff_ratio               1.632519
# expectancy_per_trade       9.492032
# gross_profit            8645.000000
# gross_loss              6262.500000
# profit_factor              1.380439
# total_pnl               2382.500000
# median_pnl                -7.000000
# max_drawdown            -782.000000
# sharpe_per_trade           1.836537
# dtype: float64
# [None, None, None, True, None, None, None, True, True]
# new bestWinToDrawdown: n_trades                  267.000000
# win_rate                    0.453184
# avg_win                    92.165289
# avg_loss                  -60.328767
# payoff_ratio                1.527717
# expectancy_per_trade        8.779026
# gross_profit            11152.000000
# gross_loss               8808.000000
# profit_factor               1.266122
# total_pnl                2344.000000
# median_pnl                -11.500000
# max_drawdown             -752.500000
# sharpe_per_trade            1.365033
# dtype: float64
# [None, None, None, True, None, True, 16, True, None]
# new win_rate: n_trades                  283.000000
# win_rate                    0.462898
# avg_win                   101.137405
# avg_loss                  -64.963816
# payoff_ratio                1.556827
# expectancy_per_trade       11.924028
# gross_profit            13249.000000
# gross_loss               9874.500000
# profit_factor               1.341739
# total_pnl                3374.500000
# median_pnl                -11.000000
# max_drawdown            -1140.500000
# sharpe_per_trade            1.625776
# dtype: float64
# [None, None, False, None, None, True, 16, None, None]
# new bestWinToDrawdown: n_trades                 259.000000
# win_rate                   0.459459
# avg_win                   81.436975
# avg_loss                 -46.342857
# payoff_ratio               1.757271
# expectancy_per_trade      12.366795
# gross_profit            9691.000000
# gross_loss              6488.000000
# profit_factor              1.493681
# total_pnl               3203.000000
# median_pnl                -5.000000
# max_drawdown            -675.000000
# sharpe_per_trade           2.335803
# dtype: float64
# [None, 18, None, True, None, None, None, None, True]
# new win_rate: n_trades                 255.000000
# win_rate                   0.466667
# avg_win                   81.436975
# avg_loss                 -47.125000
# payoff_ratio               1.728106
# expectancy_per_trade      12.870588
# gross_profit            9691.000000
# gross_loss              6409.000000
# profit_factor              1.512092
# total_pnl               3282.000000
# median_pnl                -4.000000
# max_drawdown            -667.500000
# sharpe_per_trade           2.396638
# dtype: float64
# [None, 18, None, True, None, None, 12, None, True]
# new bestWinToDrawdown: n_trades                 255.000000
# win_rate                   0.466667
# avg_win                   81.436975
# avg_loss                 -47.125000
# payoff_ratio               1.728106
# expectancy_per_trade      12.870588
# gross_profit            9691.000000
# gross_loss              6409.000000
# profit_factor              1.512092
# total_pnl               3282.000000
# median_pnl                -4.000000
# max_drawdown            -667.500000
# sharpe_per_trade           2.396638
# dtype: float64
# [None, 18, None, True, None, None, 12, None, True]
# new bestReturns: n_trades                  319.000000
# win_rate                    0.432602
# avg_win                   110.605072
# avg_loss                  -62.165746
# payoff_ratio                1.779196
# expectancy_per_trade       12.575235
# gross_profit            15263.500000
# gross_loss              11252.000000
# profit_factor               1.356514
# total_pnl                4011.500000
# median_pnl                -12.000000
# max_drawdown            -1965.000000
# sharpe_per_trade            1.847688
# dtype: float64
# [None, 20, None, None, None, True, 16, None, None]
# new bestWinToDrawdown: n_trades                 304.000000
# win_rate                   0.424342
# avg_win                   75.197674
# avg_loss                 -39.762857
# payoff_ratio               1.891154
# expectancy_per_trade       9.019737
# gross_profit            9700.500000
# gross_loss              6958.500000
# profit_factor              1.394050
# total_pnl               2742.000000
# median_pnl               -11.250000
# max_drawdown            -404.500000
# sharpe_per_trade           2.197481
# dtype: float64
# [0.3, None, None, None, None, None, None, None, True]
# new bestWinToDrawdown: n_trades                 299.000000
# win_rate                   0.431438
# avg_win                   75.197674
# avg_loss                 -40.367647
# payoff_ratio               1.862820
# expectancy_per_trade       9.491639
# gross_profit            9700.500000
# gross_loss              6862.500000
# profit_factor              1.413552
# total_pnl               2838.000000
# median_pnl               -11.000000
# max_drawdown            -404.500000
# sharpe_per_trade           2.278210
# dtype: float64
# [0.3, None, None, None, None, None, 12, None, True]
# new bestWinToDrawdown: n_trades                 272.000000
# win_rate                   0.444853
# avg_win                   74.921488
# avg_loss                 -40.635762
# payoff_ratio               1.843733
# expectancy_per_trade      10.770221
# gross_profit            9065.500000
# gross_loss              6136.000000
# profit_factor              1.477428
# total_pnl               2929.500000
# median_pnl                -8.750000
# max_drawdown            -404.500000
# sharpe_per_trade           2.459265
# dtype: float64
# [0.3, None, None, None, None, None, 14, None, True]
# new bestWinToDrawdown: n_trades                 292.000000
# win_rate                   0.434932
# avg_win                   75.448819
# avg_loss                 -40.315152
# payoff_ratio               1.871476
# expectancy_per_trade      10.034247
# gross_profit            9582.000000
# gross_loss              6652.000000
# profit_factor              1.440469
# total_pnl               2930.000000
# median_pnl               -10.500000
# max_drawdown            -404.500000
# sharpe_per_trade           2.367749
# dtype: float64
# [0.3, 12, None, None, None, None, 12, None, True]
# new bestWinToDrawdown: n_trades                 267.000000
# win_rate                   0.445693
# avg_win                   75.184874
# avg_loss                 -40.567568
# payoff_ratio               1.853325
# expectancy_per_trade      11.022472
# gross_profit            8947.000000
# gross_loss              6004.000000
# profit_factor              1.490173
# total_pnl               2943.000000
# median_pnl                -8.500000
# max_drawdown            -404.500000
# sharpe_per_trade           2.483767
# dtype: float64
# [0.3, 12, None, None, None, None, 14, None, True]
# new bestWinToDrawdown: n_trades                 282.000000
# win_rate                   0.432624
# avg_win                   76.057377
# avg_loss                 -39.178125
# payoff_ratio               1.941323
# expectancy_per_trade      10.675532
# gross_profit            9279.000000
# gross_loss              6268.500000
# profit_factor              1.480258
# total_pnl               3010.500000
# median_pnl               -10.500000
# max_drawdown            -404.500000
# sharpe_per_trade           2.487957
# dtype: float64
# [0.3, 14, None, None, None, None, None, None, True]
# new bestWinToDrawdown: n_trades                 277.000000
# win_rate                   0.440433
# avg_win                   76.057377
# avg_loss                 -39.822581
# payoff_ratio               1.909906
# expectancy_per_trade      11.214801
# gross_profit            9279.000000
# gross_loss              6172.500000
# profit_factor              1.503281
# total_pnl               3106.500000
# median_pnl                -9.500000
# max_drawdown            -404.500000
# sharpe_per_trade           2.572136
# dtype: float64
# [0.3, 14, None, None, None, None, 12, None, True]
# new bestWinToDrawdown: n_trades                 257.000000
# win_rate                   0.428016
# avg_win                   78.109091
# avg_loss                 -38.482993
# payoff_ratio               2.029704
# expectancy_per_trade      11.420233
# gross_profit            8592.000000
# gross_loss              5657.000000
# profit_factor              1.518826
# total_pnl               2935.000000
# median_pnl               -10.000000
# max_drawdown            -349.000000
# sharpe_per_trade           2.511864
# dtype: float64
# [0.3, 16, None, None, None, None, None, None, True]
# new bestWinToDrawdown: n_trades                 252.000000
# win_rate                   0.436508
# avg_win                   78.109091
# avg_loss                 -39.161972
# payoff_ratio               1.994514
# expectancy_per_trade      12.027778
# gross_profit            8592.000000
# gross_loss              5561.000000
# profit_factor              1.545046
# total_pnl               3031.000000
# median_pnl                -9.250000
# max_drawdown            -349.000000
# sharpe_per_trade           2.599448
# dtype: float64
# [0.3, 16, None, None, None, None, 12, None, True]
# new win_rate: n_trades                  292.000000
# win_rate                    0.467354
# avg_win                    81.477941
# avg_loss                  -46.641935
# payoff_ratio                1.746882
# expectancy_per_trade       13.235395
# gross_profit            11081.000000
# gross_loss               7229.500000
# profit_factor               1.532748
# total_pnl                3851.500000
# median_pnl                 -7.000000
# max_drawdown             -586.000000
# sharpe_per_trade            2.791718
# dtype: float64
# [0.4, None, None, None, None, True, 18, None, None]
# new win_rate: n_trades                 251.000000
# win_rate                   0.468000
# avg_win                   79.000000
# avg_loss                 -47.150376
# payoff_ratio               1.675490
# expectancy_per_trade      11.888000
# gross_profit            9243.000000
# gross_loss              6271.000000
# profit_factor              1.473928
# total_pnl               2972.000000
# median_pnl                -6.000000
# max_drawdown            -610.000000
# sharpe_per_trade           2.367738
# dtype: float64
# [0.4, None, None, None, None, True, 20, None, None]

# %%
from itertools import product

def make_Counterparam_grid():
    grid = {
        # HTF regime
        'ORB_width'        : [ 0.3, 0.4, 0.5, 0.6, 0.7, 0.8],
        'ADX60'        : [ 12, 14, 16, 18, 20, 22, 24],
        'ADX60_rising3' : [None, True, False],
        'DIp60_over_DIn60' : [None, True, False],
        'NATR' : [ 0.0075, 0.010, 0.0125, 0.0150, 0.0175],
        'ema20_over_ema50' : [None, True, False],
        'ADX' : [12, 14, 16, 18, 20, 22, 24],
        'DI+_over_DI-' : [None, True, False],
        'vwap' : [None, True, False],
        'excludeSide' : [None, 'high', 'low'],
    }

    keys, vals = zip(*grid.items())
    combos = [dict(zip(keys, v)) for v in product(*vals)]
    return combos

# %%
def testCounterParameters(df, worstReturns, worstWinrate, worstWinToDrawdown, ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide):
    df = df.copy(deep=True)

    # ORB_width
    if ORB_width != None:
        df = df[df['ORB_width'] < ORB_width]

    # ADX60
    if ADX60 != None:
        df = df[df['ADX60'] > ADX60]

    # ADX60 rising
    if ADX60_rising3 != None:
        df = df[df['ADX60_rising3'] == ADX60_rising3]

    # DIp60_over_DIn60
    if DIp60_over_DIn60 != None:
        if DIp60_over_DIn60 == True:
            df = df[((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] < df['DIn60']) & (df['breach'] == 'low'))]
        elif DIp60_over_DIn60 == False:
            df = df[((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] > df['DIn60']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # # NATR
    # if NATR != None:
    #     df = df[df['NATR'] > NATR]

    # ema20_over_ema50
    if ema20_over_ema50 != None:
        if ema20_over_ema50 == True:
            df = df[((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] < df['ema50']) & (df['breach'] == 'low'))]
        elif ema20_over_ema50 == False:
            df = df[((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] > df['ema50']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX != None:
        df = df[df['ADX'] > ADX]

    # DI+_over_DI-
    if DIp_over_DIn != None:
        if DIp_over_DIn == True:
            df = df[((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] < df['-DI']) & (df['breach'] == 'low'))]
        elif DIp_over_DIn == False:
            df = df[((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] > df['-DI']) & (df['breach'] == 'low'))]
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap != None:
        if vwap == True:
            df = df[((df['vwap'] < df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] > df['entryPrice']) & (df['breach'] == 'low'))]
        elif vwap == False:
            df = df[((df['vwap'] > df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] < df['entryPrice']) & (df['breach'] == 'low'))]
        else:
            print('error with vwap')

    
    if excludeSide != None:
        if excludeSide == 'high':
            df = df[df['breach'] != 'high']
        elif excludeSide == 'low':
            df = df[df['breach'] != 'low']
        else:
            print('error with excludeSide')
            

    stats, equity, dd = trade_stats(df, pnl_col='returns')
    # print(pd.Series(stats))
    if len(df) > 150:
        if worstReturns == 0:
            worstReturns = stats
        if worstWinrate == 0:
            worstWinrate = stats
        if worstWinToDrawdown == 0:
            worstWinToDrawdown = stats

        if stats['total_pnl'] < worstReturns['total_pnl']:
            worstReturns = stats
            print('new worst Returns:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
        if stats['win_rate'] < worstWinrate['win_rate']:
            worstWinrate = stats
            print('new worst win_rate:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
        if ((stats['total_pnl'] / max(-stats['max_drawdown'], 1e-9)) < (
                worstWinToDrawdown['total_pnl'] / max(-worstWinToDrawdown['max_drawdown'], 1e-9))) & (
                stats['total_pnl'] > 0):
            worstWinToDrawdown = stats
            print('new best WinToDrawdown:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
            
            

    return stats, worstReturns, worstWinrate, worstWinToDrawdown




worstReturns = 0
worstWinrate = 0
worstWinToDrawdown = 0

for p in make_Counterparam_grid():
    stats, worstReturns, worstWinrate, worstWinToDrawdown = testCounterParameters(temp,
                                                                        worstReturns,
                                                                        worstWinrate,
                                                                        worstWinToDrawdown,
                                                                        ORB_width=p['ORB_width'],
                                                                        ADX60=p['ADX60'],
                                                                        ADX60_rising3=p['ADX60_rising3'],
                                                                        DIp60_over_DIn60=p['DIp60_over_DIn60'],
                                                                        # NATR=p['NATR'],
                                                                        ema20_over_ema50=p['ema20_over_ema50'],
                                                                        ADX=p['ADX'],
                                                                        DIp_over_DIn=p['DI+_over_DI-'],
                                                                        vwap=p['vwap'],
                                                                        excludeSide=p['excludeSide']
                                                                        )
    # if (len(stats) > 0):
    #     print(stats['total_pnl'])
    # print(pd.Series(stats))
print('worstReturns:\n', pd.Series(worstReturns))
print('worstWinrate:\n', pd.Series(worstWinrate))
print('worstWinToDrawdown:\n', pd.Series(worstWinToDrawdown))
# Out:
# new worst Returns: n_trades                 252.000000
# win_rate                   0.369048
# avg_win                   69.629032
# avg_loss                 -45.465409
# payoff_ratio               1.531473
# expectancy_per_trade      -2.990079
# gross_profit            6475.500000
# gross_loss              7229.000000
# profit_factor              0.895767
# total_pnl               -753.500000
# median_pnl               -22.250000
# max_drawdown           -1434.500000
# sharpe_per_trade          -0.678464
# dtype: float64
# [0.3, 12, None, None, None, 12, None, None, 'high']
# new worst win_rate: n_trades                 252.000000
# win_rate                   0.369048
# avg_win                   69.629032
# avg_loss                 -45.465409
# payoff_ratio               1.531473
# expectancy_per_trade      -2.990079
# gross_profit            6475.500000
# gross_loss              7229.000000
# profit_factor              0.895767
# total_pnl               -753.500000
# median_pnl               -22.250000
# max_drawdown           -1434.500000
# sharpe_per_trade          -0.678464
# dtype: float64
# [0.3, 12, None, None, None, 12, None, None, 'high']
# new best WinToDrawdown: n_trades                  456.000000
# win_rate                    0.412281
# avg_win                    69.760638
# avg_loss                  -44.406716
# payoff_ratio                1.570948
# expectancy_per_trade        2.662281
# gross_profit            13115.000000
# gross_loss              11901.000000
# profit_factor               1.102008
# total_pnl                1214.000000
# median_pnl                -17.250000
# max_drawdown            -1005.500000
# sharpe_per_trade            0.794983
# dtype: float64
# [0.3, 12, None, None, None, 12, True, None, None]
# new worst Returns: n_trades                 217.000000
# win_rate                   0.373272
# avg_win                   63.839506
# avg_loss                 -47.952206
# payoff_ratio               1.331315
# expectancy_per_trade      -6.223502
# gross_profit            5171.000000
# gross_loss              6521.500000
# profit_factor              0.792916
# total_pnl              -1350.500000
# median_pnl               -22.500000
# max_drawdown           -1664.000000
# sharpe_per_trade          -1.348705
# dtype: float64
# [0.3, 12, None, None, None, 12, True, None, 'high']
# new worst win_rate: n_trades                 245.000000
# win_rate                   0.367347
# avg_win                   70.961111
# avg_loss                 -45.667742
# payoff_ratio               1.553856
# expectancy_per_trade      -2.824490
# gross_profit            6386.500000
# gross_loss              7078.500000
# profit_factor              0.902239
# total_pnl               -692.000000
# median_pnl               -22.500000
# max_drawdown           -1462.500000
# sharpe_per_trade          -0.625860
# dtype: float64
# [0.3, 12, None, None, None, 14, None, None, 'high']
# new worst win_rate: n_trades                 228.000000
# win_rate                   0.359649
# avg_win                   69.890244
# avg_loss                 -46.136986
# payoff_ratio               1.514842
# expectancy_per_trade      -4.407895
# gross_profit            5731.000000
# gross_loss              6736.000000
# profit_factor              0.850802
# total_pnl              -1005.000000
# median_pnl               -22.750000
# max_drawdown           -1461.000000
# sharpe_per_trade          -0.947513
# dtype: float64
# [0.3, 12, None, None, None, 16, None, None, 'high']
# new best WinToDrawdown: n_trades                  390.000000
# win_rate                    0.407692
# avg_win                    70.383648
# avg_loss                  -45.212121
# payoff_ratio                1.556743
# expectancy_per_trade        1.915385
# gross_profit            11191.000000
# gross_loss              10444.000000
# profit_factor               1.071524
# total_pnl                 747.000000
# median_pnl                -17.250000
# max_drawdown            -1101.500000
# sharpe_per_trade            0.520262
# dtype: float64
# [0.3, 12, None, None, None, 16, True, None, None]
# new worst Returns: n_trades                 197.000000
# win_rate                   0.360406
# avg_win                   65.697183
# avg_loss                 -48.321429
# payoff_ratio               1.359587
# expectancy_per_trade      -7.228426
# gross_profit            4664.500000
# gross_loss              6088.500000
# profit_factor              0.766116
# total_pnl              -1424.000000
# median_pnl               -23.500000
# max_drawdown           -1660.000000
# sharpe_per_trade          -1.466491
# dtype: float64
# [0.3, 12, None, None, None, 16, True, None, 'high']
# new best WinToDrawdown: n_trades                 182.000000
# win_rate                   0.395604
# avg_win                   75.736111
# avg_loss                 -47.895455
# payoff_ratio               1.581280
# expectancy_per_trade       1.013736
# gross_profit            5453.000000
# gross_loss              5268.500000
# profit_factor              1.035019
# total_pnl                184.500000
# median_pnl               -22.500000
# max_drawdown            -945.000000
# sharpe_per_trade           0.172912
# dtype: float64
# [0.3, 12, None, None, None, 18, None, True, 'high']
# new worst win_rate: n_trades                 243.000000
# win_rate                   0.353909
# avg_win                   69.261628
# avg_loss                 -45.019108
# payoff_ratio               1.538494
# expectancy_per_trade      -4.574074
# gross_profit            5956.500000
# gross_loss              7068.000000
# profit_factor              0.842742
# total_pnl              -1111.500000
# median_pnl               -22.000000
# max_drawdown           -1633.000000
# sharpe_per_trade          -1.038836
# dtype: float64
# [0.3, 12, None, None, False, 12, None, None, None]
# new worst Returns: n_trades                 199.000000
# win_rate                   0.351759
# avg_win                   57.878571
# avg_loss                 -44.565891
# payoff_ratio               1.298719
# expectancy_per_trade      -8.530151
# gross_profit            4051.500000
# gross_loss              5749.000000
# profit_factor              0.704731
# total_pnl              -1697.500000
# median_pnl               -22.500000
# max_drawdown           -1873.000000
# sharpe_per_trade          -1.954927
# dtype: float64
# [0.3, 12, None, None, False, 12, None, None, 'high']
# new worst win_rate: n_trades                 199.000000
# win_rate                   0.351759
# avg_win                   57.878571
# avg_loss                 -44.565891
# payoff_ratio               1.298719
# expectancy_per_trade      -8.530151
# gross_profit            4051.500000
# gross_loss              5749.000000
# profit_factor              0.704731
# total_pnl              -1697.500000
# median_pnl               -22.500000
# max_drawdown           -1873.000000
# sharpe_per_trade          -1.954927
# dtype: float64
# [0.3, 12, None, None, False, 12, None, None, 'high']
# new worst win_rate: n_trades                 237.000000
# win_rate                   0.350211
# avg_win                   70.626506
# avg_loss                 -44.967532
# payoff_ratio               1.570611
# expectancy_per_trade      -4.485232
# gross_profit            5862.000000
# gross_loss              6925.000000
# profit_factor              0.846498
# total_pnl              -1063.000000
# median_pnl               -22.000000
# max_drawdown           -1551.000000
# sharpe_per_trade          -0.998002
# dtype: float64
# [0.3, 12, None, None, False, 14, None, None, None]
# new worst Returns: n_trades                 196.000000
# win_rate                   0.346939
# avg_win                   58.522059
# avg_loss                 -44.460938
# payoff_ratio               1.316258
# expectancy_per_trade      -8.732143
# gross_profit            3979.500000
# gross_loss              5691.000000
# profit_factor              0.699262
# total_pnl              -1711.500000
# median_pnl               -22.750000
# max_drawdown           -1847.000000
# sharpe_per_trade          -1.979339
# dtype: float64
# [0.3, 12, None, None, False, 14, None, None, 'high']
# new worst win_rate: n_trades                 196.000000
# win_rate                   0.346939
# avg_win                   58.522059
# avg_loss                 -44.460938
# payoff_ratio               1.316258
# expectancy_per_trade      -8.732143
# gross_profit            3979.500000
# gross_loss              5691.000000
# profit_factor              0.699262
# total_pnl              -1711.500000
# median_pnl               -22.750000
# max_drawdown           -1847.000000
# sharpe_per_trade          -1.979339
# dtype: float64
# [0.3, 12, None, None, False, 14, None, None, 'high']
# new worst win_rate: n_trades                 220.000000
# win_rate                   0.340909
# avg_win                   69.420000
# avg_loss                 -45.462069
# payoff_ratio               1.526987
# expectancy_per_trade      -6.297727
# gross_profit            5206.500000
# gross_loss              6592.000000
# profit_factor              0.789821
# total_pnl              -1385.500000
# median_pnl               -22.750000
# max_drawdown           -1635.500000
# sharpe_per_trade          -1.365957
# dtype: float64
# [0.3, 12, None, None, False, 16, None, None, None]
# new worst Returns: n_trades                 181.000000
# win_rate                   0.331492
# avg_win                   55.400000
# avg_loss                 -44.533058
# payoff_ratio               1.244020
# expectancy_per_trade     -11.406077
# gross_profit            3324.000000
# gross_loss              5388.500000
# profit_factor              0.616869
# total_pnl              -2064.500000
# median_pnl               -24.500000
# max_drawdown           -2195.000000
# sharpe_per_trade          -2.594315
# dtype: float64
# [0.3, 12, None, None, False, 16, None, None, 'high']
# new worst win_rate: n_trades                 181.000000
# win_rate                   0.331492
# avg_win                   55.400000
# avg_loss                 -44.533058
# payoff_ratio               1.244020
# expectancy_per_trade     -11.406077
# gross_profit            3324.000000
# gross_loss              5388.500000
# profit_factor              0.616869
# total_pnl              -2064.500000
# median_pnl               -24.500000
# max_drawdown           -2195.000000
# sharpe_per_trade          -2.594315
# dtype: float64
# [0.3, 12, None, None, False, 16, None, None, 'high']
# new best WinToDrawdown: n_trades                 208.000000
# win_rate                   0.389423
# avg_win                   72.364198
# avg_loss                 -45.157480
# payoff_ratio               1.602485
# expectancy_per_trade       0.608173
# gross_profit            5861.500000
# gross_loss              5735.000000
# profit_factor              1.022058
# total_pnl                126.500000
# median_pnl               -20.250000
# max_drawdown            -806.000000
# sharpe_per_trade           0.116955
# dtype: float64
# [0.3, 12, None, False, None, 12, True, True, None]
# new best WinToDrawdown: n_trades                 239.000000
# win_rate                   0.380753
# avg_win                   70.769231
# avg_loss                 -43.060811
# payoff_ratio               1.643472
# expectancy_per_trade       0.280335
# gross_profit            6440.000000
# gross_loss              6373.000000
# profit_factor              1.010513
# total_pnl                 67.000000
# median_pnl               -19.000000
# max_drawdown            -676.500000
# sharpe_per_trade           0.053781
# dtype: float64
# [0.3, 12, None, False, None, 14, None, None, None]
# new best WinToDrawdown: n_trades                 218.000000
# win_rate                   0.385321
# avg_win                   69.422619
# avg_loss                 -43.410448
# payoff_ratio               1.599215
# expectancy_per_trade       0.066514
# gross_profit            5831.500000
# gross_loss              5817.000000
# profit_factor              1.002493
# total_pnl                 14.500000
# median_pnl               -18.250000
# max_drawdown            -639.000000
# sharpe_per_trade           0.005702
# dtype: float64
# [0.3, 12, None, False, None, 16, None, None, None]
# new best WinToDrawdown: n_trades                 169.000000
# win_rate                   0.390533
# avg_win                   67.893939
# avg_loss                 -43.480583
# payoff_ratio               1.561477
# expectancy_per_trade       0.014793
# gross_profit            4481.000000
# gross_loss              4478.500000
# profit_factor              1.000558
# total_pnl                  2.500000
# median_pnl               -18.500000
# max_drawdown            -549.500000
# sharpe_per_trade          -0.004802
# dtype: float64
# [0.3, 12, True, None, None, 12, True, None, None]
# new best WinToDrawdown: n_trades                 160.000000
# win_rate                   0.387500
# avg_win                   69.693548
# avg_loss                 -44.076531
# payoff_ratio               1.581194
# expectancy_per_trade       0.009375
# gross_profit            4321.000000
# gross_loss              4319.500000
# profit_factor              1.000347
# total_pnl                  1.500000
# median_pnl               -20.000000
# max_drawdown            -541.000000
# sharpe_per_trade          -0.005577
# dtype: float64
# [0.3, 12, True, None, None, 14, True, None, None]
# new worst Returns: n_trades                 167.000000
# win_rate                   0.317365
# avg_win                   53.962264
# avg_loss                 -44.916667
# payoff_ratio               1.201386
# expectancy_per_trade     -13.535928
# gross_profit            2860.000000
# gross_loss              5120.500000
# profit_factor              0.558539
# total_pnl              -2260.500000
# median_pnl               -26.000000
# max_drawdown           -2354.000000
# sharpe_per_trade          -2.999108
# dtype: float64
# [0.3, 14, None, None, False, 16, None, None, 'high']
# new worst win_rate: n_trades                 167.000000
# win_rate                   0.317365
# avg_win                   53.962264
# avg_loss                 -44.916667
# payoff_ratio               1.201386
# expectancy_per_trade     -13.535928
# gross_profit            2860.000000
# gross_loss              5120.500000
# profit_factor              0.558539
# total_pnl              -2260.500000
# median_pnl               -26.000000
# max_drawdown           -2354.000000
# sharpe_per_trade          -2.999108
# dtype: float64
# [0.3, 14, None, None, False, 16, None, None, 'high']
# new worst Returns: n_trades                 156.000000
# win_rate                   0.307692
# avg_win                   52.854167
# avg_loss                 -45.699074
# payoff_ratio               1.156570
# expectancy_per_trade     -15.375000
# gross_profit            2537.000000
# gross_loss              4935.500000
# profit_factor              0.514031
# total_pnl              -2398.500000
# median_pnl               -27.750000
# max_drawdown           -2492.000000
# sharpe_per_trade          -3.369296
# dtype: float64
# [0.3, 16, None, None, False, 16, None, None, 'high']
# new worst win_rate: n_trades                 156.000000
# win_rate                   0.307692
# avg_win                   52.854167
# avg_loss                 -45.699074
# payoff_ratio               1.156570
# expectancy_per_trade     -15.375000
# gross_profit            2537.000000
# gross_loss              4935.500000
# profit_factor              0.514031
# total_pnl              -2398.500000
# median_pnl               -27.750000
# max_drawdown           -2492.000000
# sharpe_per_trade          -3.369296
# dtype: float64
# [0.3, 16, None, None, False, 16, None, None, 'high']
# new worst win_rate: n_trades                 154.000000
# win_rate                   0.305195
# avg_win                   77.627660
# avg_loss                 -46.378505
# payoff_ratio               1.673785
# expectancy_per_trade      -8.532468
# gross_profit            3648.500000
# gross_loss              4962.500000
# profit_factor              0.735214
# total_pnl              -1314.000000
# median_pnl               -28.750000
# max_drawdown           -1563.500000
# sharpe_per_trade          -1.508248
# dtype: float64
# [0.3, 20, None, None, False, 14, None, None, None]
# new worst Returns: n_trades                 271.000000
# win_rate                   0.346863
# avg_win                   74.553191
# avg_loss                 -53.892655
# payoff_ratio               1.383365
# expectancy_per_trade      -9.339483
# gross_profit            7008.000000
# gross_loss              9539.000000
# profit_factor              0.734668
# total_pnl              -2531.000000
# median_pnl               -28.500000
# max_drawdown           -3373.000000
# sharpe_per_trade          -1.981447
# dtype: float64
# [0.4, 14, None, None, False, 12, True, None, None]
# new worst Returns: n_trades                 261.000000
# win_rate                   0.340996
# avg_win                   75.044944
# avg_loss                 -53.959302
# payoff_ratio               1.390769
# expectancy_per_trade      -9.969349
# gross_profit            6679.000000
# gross_loss              9281.000000
# profit_factor              0.719642
# total_pnl              -2602.000000
# median_pnl               -28.500000
# max_drawdown           -3197.000000
# sharpe_per_trade          -2.082107
# dtype: float64
# [0.4, 14, None, None, False, 14, True, None, None]
# new worst Returns: n_trades                 241.000000
# win_rate                   0.327801
# avg_win                   76.354430
# avg_loss                 -54.333333
# payoff_ratio               1.405296
# expectancy_per_trade     -11.493776
# gross_profit            6032.000000
# gross_loss              8802.000000
# profit_factor              0.685299
# total_pnl              -2770.000000
# median_pnl               -31.000000
# max_drawdown           -3261.500000
# sharpe_per_trade          -2.301421
# dtype: float64
# [0.4, 14, None, None, False, 16, True, None, None]
# new worst Returns: n_trades                 229.000000
# win_rate                   0.318777
# avg_win                   77.869863
# avg_loss                 -55.032051
# payoff_ratio               1.414991
# expectancy_per_trade     -12.665939
# gross_profit            5684.500000
# gross_loss              8585.000000
# profit_factor              0.662143
# total_pnl              -2900.500000
# median_pnl               -33.000000
# max_drawdown           -3279.500000
# sharpe_per_trade          -2.463272
# dtype: float64
# [0.4, 16, None, None, False, 16, True, None, None]
# new worst Returns: n_trades                 200.000000
# win_rate                   0.315000
# avg_win                   76.944444
# avg_loss                 -56.649635
# payoff_ratio               1.358251
# expectancy_per_trade     -14.567500
# gross_profit            4847.500000
# gross_loss              7761.000000
# profit_factor              0.624597
# total_pnl              -2913.500000
# median_pnl               -34.750000
# max_drawdown           -3189.000000
# sharpe_per_trade          -2.618572
# dtype: float64
# [0.4, 20, None, None, False, 12, True, None, None]
# new worst Returns: n_trades                 204.000000
# win_rate                   0.313725
# avg_win                   75.007812
# avg_loss                 -55.346429
# payoff_ratio               1.355242
# expectancy_per_trade     -14.450980
# gross_profit            4800.500000
# gross_loss              7748.500000
# profit_factor              0.619539
# total_pnl              -2948.000000
# median_pnl               -32.500000
# max_drawdown           -3404.500000
# sharpe_per_trade          -2.703356
# dtype: float64
# [0.4, 20, None, None, False, 14, None, True, None]
# new worst Returns: n_trades                 192.000000
# win_rate                   0.302083
# avg_win                   77.905172
# avg_loss                 -56.626866
# payoff_ratio               1.375763
# expectancy_per_trade     -15.986979
# gross_profit            4518.500000
# gross_loss              7588.000000
# profit_factor              0.595480
# total_pnl              -3069.500000
# median_pnl               -35.250000
# max_drawdown           -3297.500000
# sharpe_per_trade          -2.841340
# dtype: float64
# [0.4, 20, None, None, False, 14, True, None, None]
# new worst win_rate: n_trades                 192.000000
# win_rate                   0.302083
# avg_win                   77.905172
# avg_loss                 -56.626866
# payoff_ratio               1.375763
# expectancy_per_trade     -15.986979
# gross_profit            4518.500000
# gross_loss              7588.000000
# profit_factor              0.595480
# total_pnl              -3069.500000
# median_pnl               -35.250000
# max_drawdown           -3297.500000
# sharpe_per_trade          -2.841340
# dtype: float64
# [0.4, 20, None, None, False, 14, True, None, None]
# new worst win_rate: n_trades                 179.000000
# win_rate                   0.301676
# avg_win                   80.388889
# avg_loss                 -57.016000
# payoff_ratio               1.409936
# expectancy_per_trade     -15.564246
# gross_profit            4341.000000
# gross_loss              7127.000000
# profit_factor              0.609092
# total_pnl              -2786.000000
# median_pnl               -35.500000
# max_drawdown           -3049.500000
# sharpe_per_trade          -2.630675
# dtype: float64
# [0.4, 20, None, None, False, 16, True, None, None]
# new worst win_rate: n_trades                 151.000000
# win_rate                   0.298013
# avg_win                   85.766667
# avg_loss                 -56.731132
# payoff_ratio               1.511810
# expectancy_per_trade     -14.264901
# gross_profit            3859.500000
# gross_loss              6013.500000
# profit_factor              0.641806
# total_pnl              -2154.000000
# median_pnl               -35.000000
# max_drawdown           -2385.500000
# sharpe_per_trade          -2.134292
# dtype: float64
# [0.4, 20, None, False, False, 14, True, None, None]
# new worst Returns: n_trades                 166.000000
# win_rate                   0.307229
# avg_win                   69.588235
# avg_loss                 -57.556522
# payoff_ratio               1.209042
# expectancy_per_trade     -18.493976
# gross_profit            3549.000000
# gross_loss              6619.000000
# profit_factor              0.536184
# total_pnl              -3070.000000
# median_pnl               -36.250000
# max_drawdown           -3483.500000
# sharpe_per_trade          -3.222066
# dtype: float64
# [0.4, 22, None, None, False, 12, True, None, None]
# new worst win_rate: n_trades                 160.000000
# win_rate                   0.293750
# avg_win                   73.319149
# avg_loss                 -57.380531
# payoff_ratio               1.277770
# expectancy_per_trade     -18.987500
# gross_profit            3446.000000
# gross_loss              6484.000000
# profit_factor              0.531462
# total_pnl              -3038.000000
# median_pnl               -37.500000
# max_drawdown           -3423.500000
# sharpe_per_trade          -3.211950
# dtype: float64
# [0.4, 22, None, None, False, 14, True, None, None]

# %%
def filterOutCounterParameters(df, listParams):
    
    ORB_width = listParams[0]
    ADX60 = listParams[1]
    ADX60_rising3 = listParams[2]
    DIp60_over_DIn60 = listParams[3]
    ema20_over_ema50 = listParams[4]
    ADX = listParams[5]
    DIp_over_DIn = listParams[6]
    vwap = listParams[7]
    excludeSide = listParams[8]
    
    
    
    
    # ORB_width
    if ORB_width != None:
        df = df[df['ORB_width'] >= ORB_width]

    # ADX60
    if ADX60 != None:
        df = df[df['ADX60'] <= ADX60]

    # ADX60 rising
    if ADX60_rising3 != None:
        df = df[df['ADX60_rising3'] != ADX60_rising3]

    # DIp60_over_DIn60
    if DIp60_over_DIn60 != None:
        if DIp60_over_DIn60 != True:
            df = df[((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] < df['DIn60']) & (df['breach'] == 'low'))]
        elif DIp60_over_DIn60 != False:
            df = df[((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] > df['DIn60']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # # NATR
    # if NATR != None:
    #     df = df[df['NATR'] > NATR]

    # ema20_over_ema50
    if ema20_over_ema50 != None:
        if ema20_over_ema50 != True:
            df = df[((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] < df['ema50']) & (df['breach'] == 'low'))]
        elif ema20_over_ema50 != False:
            df = df[((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] > df['ema50']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX != None:
        df = df[df['ADX'] <= ADX]

    # DI+_over_DI-
    if DIp_over_DIn != None:
        if DIp_over_DIn != True:
            df = df[((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] < df['-DI']) & (df['breach'] == 'low'))]
        elif DIp_over_DIn != False:
            df = df[((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] > df['-DI']) & (df['breach'] == 'low'))]
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap != None:
        if vwap != True:
            df = df[((df['vwap'] < df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] > df['entryPrice']) & (df['breach'] == 'low'))]
        elif vwap != False:
            df = df[((df['vwap'] > df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] < df['entryPrice']) & (df['breach'] == 'low'))]
        else:
            print('error with vwap')

    
    if excludeSide != None:
        if excludeSide == 'high':
            df = df[df['breach'] == 'high']
        elif excludeSide == 'low':
            df = df[df['breach'] == 'low']
        else:
            print('error with excludeSide')


    return df




listParams = [0.3, 12, None, None, False, 16, None, None, 'high']

backtest_filtered = filterOutCounterParameters(temp, listParams)

backtest_filtered
# temp
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[444], line 89
#      82     return df
#      87 listParams = [0.3, 12, None, None, False, 16, None, None, 'high']
# ---> 89 backtest_filtered = filterOutCounterParameters(temp, listParams)
#      91 backtest_filtered
#      92 # temp
#
# Cell In[444], line 25, in filterOutCounterParameters(df, listParams)
#      22     df = df[df['ADX60'] <= ADX60]
#      24 # ADX60 rising
# ---> 25 if ADX60_rising3 != None:
#      26     df = df[df['ADX60_rising3'] != ADX60_rising3]
#      28 # DIp60_over_DIn60
#
# Cell In[444], line 25, in filterOutCounterParameters(df, listParams)
#      22     df = df[df['ADX60'] <= ADX60]
#      24 # ADX60 rising
# ---> 25 if ADX60_rising3 != None:
#      26     df = df[df['ADX60_rising3'] != ADX60_rising3]
#      28 # DIp60_over_DIn60
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_39_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:620, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:1095, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:1053, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File C:\Program Files\JetBrains\PyCharm 2023.2.5\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py:169, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     167     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     168     if frame:
# --> 169         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     170         return True
#     171 return False
#
# File C:\Program Files\JetBrains\PyCharm 2023.2.5\plugins\python\helpers\pydev\pydevd.py:1160, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1157         from_this_thread.append(frame_id)
#    1159 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1160     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File C:\Program Files\JetBrains\PyCharm 2023.2.5\plugins\python\helpers\pydev\pydevd.py:1175, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1172             self._call_mpl_hook()
#    1174         self.process_internal_commands()
# -> 1175         time.sleep(0.01)
#    1177 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1179 # process any stepping instructions
#
# KeyboardInterrupt:
