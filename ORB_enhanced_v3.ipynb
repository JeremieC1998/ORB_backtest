# %%
# Imports
import pandas as pd
import numpy as np
import datetime
from datetime import time as dtime
from datetime import timedelta
from datetime import date
import matplotlib as plt
from itertools import product
import openpyxl

# importing historical data for backtest
def get1minBars(csvName):
    
    priceData1minBars_df = pd.read_csv(csvName, usecols=['date', 'open', 'high', 'low', 'close', 'volume'])
    
    # Parse datetime column and divide in 2 columns
    # SPY_Data['datetime'] = pd.to_datetime(SPY_Data['date'].str.strip(), format='%Y%m%d %H:%M:%S')
    priceData1minBars_df.rename(columns={
        'date': 'datetime'
    }, inplace=True)
    
    priceData1minBars_df['datetime'] = pd.to_datetime(priceData1minBars_df['datetime'])
    
    priceData1minBars_df['Date'] = priceData1minBars_df['datetime'].dt.date
    priceData1minBars_df['Time'] = priceData1minBars_df['datetime'].dt.time
    
    # sorting the data by the time column to make sure it is consistent
    priceData1minBars_df.sort_values('datetime', inplace=True)
    
    # Drop original 'date' column
    # SPY_Data.drop(columns=['date'], inplace=True)
    
    # Filter for regular trading hours using datetime column
    priceData1minBars_df = priceData1minBars_df[priceData1minBars_df['datetime'].dt.time >= pd.to_datetime("09:30").time()]
    priceData1minBars_df = priceData1minBars_df[priceData1minBars_df['datetime'].dt.time <= pd.to_datetime("16:00").time()]
    
    # Making sure the order of the columns stays the same 
    priceData1minBars_df = priceData1minBars_df[['Date', 'Time', 'open', 'high', 'low', 'close', 'volume']]
    
    return priceData1minBars_df

# %%
SPY_Data = get1minBars('SPY_1min_data.csv')
SPY_Data
# Out:
#               Date      Time    open    high     low   close  volume
# 0       2019-12-31  09:30:00  320.52  320.53  320.24  320.27    4255
# 1       2019-12-31  09:31:00  320.27  320.34  320.15  320.33    2049
# 2       2019-12-31  09:32:00  320.35  320.97  320.35  320.97    2953
# 3       2019-12-31  09:33:00  320.98  321.05  320.81  320.82    2529
# 4       2019-12-31  09:34:00  320.83  320.91  320.74  320.80    1373
# ...            ...       ...     ...     ...     ...     ...     ...
# 507925  2025-08-01  15:55:00  622.10  622.29  621.64  622.25    7142
# 507926  2025-08-01  15:56:00  622.27  622.53  622.12  622.46    6161
# 507927  2025-08-01  15:57:00  622.46  622.53  622.22  622.38    7356
# 507928  2025-08-01  15:58:00  622.39  622.44  621.95  621.96   10144
# 507929  2025-08-01  15:59:00  621.97  622.03  621.51  621.71   22237
#
# [544980 rows x 7 columns]

# %%
# higher time frame datageneration

# Uses your adx(df, period=14) that returns ['+DI','-DI','DX','ADX'] on OHLC.
def adx(df, period: int = 14,
        high_col: str = "high", 
        low_col: str = "low", 
        close_col: str = "close"):
    """
    Returns a DataFrame with columns: +DI, -DI, DX, ADX computed with Wilder's smoothing.
    df must have High/Low/Close columns.
    """
    high, low, close = df[high_col].astype(float), df[low_col].astype(float), df[close_col].astype(float)

    # 1) True Range
    prev_close = close.shift(1)
    tr = pd.concat([
        (high - low),
        (high - prev_close).abs(),
        (low - prev_close).abs()
    ], axis=1).max(axis=1)

    # 2) Directional Movement
    up_move = high.diff()
    down_move = -low.diff()  # prev_low - curr_low
    plus_dm  = np.where((up_move > down_move) & (up_move > 0), up_move, 0.0)
    minus_dm = np.where((down_move > up_move) & (down_move > 0), down_move, 0.0)
    plus_dm  = pd.Series(plus_dm, index=df.index)
    minus_dm = pd.Series(minus_dm, index=df.index)

    # 3) Wilder's smoothing (RMA) via EMA with alpha=1/period
    alpha = 1 / period
    atr        = tr.ewm(alpha=alpha, adjust=False).mean()
    plus_dm_sm = plus_dm.ewm(alpha=alpha, adjust=False).mean()
    minus_dm_sm= minus_dm.ewm(alpha=alpha, adjust=False).mean()

    # 4) DIs
    plus_di  = 100 * (plus_dm_sm / atr)
    minus_di = 100 * (minus_dm_sm / atr)

    # 5) DX
    di_sum  = (plus_di + minus_di)
    di_diff = (plus_di - minus_di).abs()
    dx = 100 * (di_diff / di_sum.replace(0, np.nan))

    # 6) ADX
    adx = dx.ewm(alpha=alpha, adjust=False).mean()

    out = pd.DataFrame({
        "+DI": plus_di,
        "-DI": minus_di,
        "DX": dx,
        "ADX": adx
    })
    return out



def adx_HTF(df):
    
    df = df.copy(deep=True)
    
    df['datetime'] = pd.to_datetime(
        df['Date'].astype(str) + ' ' + df['Time'].astype(str)
    )
    
    df_1H = (
        df
        .set_index('datetime')
        .resample('60min', origin='start_day', offset='30min')
        .agg({'open':'first','high':'max','low':'min','close':'last','volume':'sum'})
        .dropna(subset=['open','high','low','close'])
        .reset_index()
    )
    
    df_1H['Date'] = df_1H['datetime'].dt.date
    df_1H['Time'] = df_1H['datetime'].dt.time
    df_1H = df_1H[['Date','Time','open','high','low','close','volume']]
   
        # df has columns: open, high, low, close, volume
    df_1H['ema20'] = df_1H['close'].ewm(span=20, adjust=False).mean().rename('EMA20').shift(1)
    df_1H['ema50'] = df_1H['close'].ewm(span=50, adjust=False).mean().rename('EMA50').shift(1)
    
    # Alignment (1 if uptrend, 0 if downtrend)
    df_1H['ema_alignment'] = (df_1H['ema20'] > df_1H['ema50']).astype(int).rename('EMA_alignment')
        
    # 2) HTF DMI/ADX
    adx_1H = adx(df_1H, period=14)
    df_1H['ADX60']  = adx_1H['ADX'].shift(1)
    df_1H['DIp60']  = adx_1H['+DI'].shift(1)
    df_1H['DIn60']  = adx_1H['-DI'].shift(1)
    df_1H['ADX60_rising3'] = (df_1H['ADX60'] > df_1H['ADX60'].shift(1)) & (df_1H['ADX60'].shift(1) > df_1H['ADX60'].shift(2))
    
    return df_1H



def true_range(df, high_col="high", low_col="low", close_col="close"):
    """
    Wilder's True Range (TR) per bar.
    TR_t = max( high_t - low_t, |high_t - close_{t-1}|, |low_t - close_{t-1}| )
    Returns a pd.Series named 'TR'.
    """
    high  = df[high_col].astype(float)
    low   = df[low_col].astype(float)
    close = df[close_col].astype(float)

    prev_close = close.shift(1)
    tr = pd.concat([
        high - low,
        (high - prev_close).abs(),
        (low  - prev_close).abs()
    ], axis=1).max(axis=1)

    tr.name = "TR"
    return tr


def ATR(df, period: int = 14,
        high_col: str = "high",
        low_col: str = "low",
        close_col: str = "close",
        method: str = "wilder"):
    """
    Average True Range (ATR) over `period`.
    method='wilder' uses RMA (EMA with alpha=1/period), which is the standard.
    method='sma' uses a simple moving average.
    Returns a pd.Series named f'ATR_{period}'.
    """
    tr = true_range(df, high_col, low_col, close_col)

    if method.lower() == "wilder":
        atr = tr.ewm(alpha=1/period, adjust=False).mean()
    elif method.lower() == "sma":
        atr = tr.rolling(window=period, min_periods=period).mean()
    else:
        raise ValueError("method must be 'wilder' or 'sma'")

    atr.name = f"ATR_{period}"
    return atr


def NATR(df, period: int = 14,
         high_col: str = "high",
         low_col: str = "low",
         close_col: str = "close",
         as_percent: bool = False,
         method: str = "wilder"):
    """
    Normalized ATR = ATR / Close  (dimensionless volatility).
    If as_percent=True, returns percentage (×100).
    Returns a pd.Series named f'NATR_{period}' (or '%').
    """
    df['ATR'] = ATR(df, period, high_col, low_col, close_col, method=method)
    close = df[close_col].astype(float)

    df['NATR'] = (df['ATR'] / close).replace([np.inf, -np.inf], np.nan)
    if as_percent:
        df['NATR'] = 100.0 * df['NATR']
    
    # patching future leak
    df['ATR'] = df['ATR'].shift(1)
    df['NATR'] = df['NATR'].shift(1)
    
    # renaming a column
    df = df.rename(columns={'volume': 'volume60'})
    
    return df


# generate the HTF data
def HTF(df):
    
    df = df.copy(deep=True)
    
    # calculate ADX on higher timeframe (1h bars)
    htf = adx_HTF(df)
    
    # calculate the NATR on the HTF (1h bars)
    htf = NATR(htf)
    
    return htf

# %%
htf_test = HTF(SPY_Data)
htf_test
# Out:
#             Date      Time    open    high     low   close  volume60  \
# 0     2019-12-31  09:30:00  320.52  321.54  320.15  320.78     55212
# 1     2019-12-31  10:30:00  320.78  320.87  320.39  320.51     36136
# 2     2019-12-31  11:30:00  320.51  320.88  320.30  320.66     26634
# 3     2019-12-31  12:30:00  320.65  320.82  320.58  320.73     21344
# 4     2019-12-31  13:30:00  320.72  321.03  320.72  321.02     26587
# ...          ...       ...     ...     ...     ...     ...       ...
# 9779  2025-08-01  11:30:00  621.51  624.97  621.38  624.21    103595
# 9780  2025-08-01  12:30:00  624.21  624.46  620.33  620.57    137281
# 9781  2025-08-01  13:30:00  620.57  621.81  619.29  621.62    108451
# 9782  2025-08-01  14:30:00  621.63  623.11  620.95  621.79    142412
# 9783  2025-08-01  15:30:00  621.78  623.30  620.84  621.71    147574
#
#            ema20       ema50  ema_alignment       ADX60      DIp60      DIn60  \
# 0            NaN         NaN              0         NaN        NaN        NaN
# 1     320.780000  320.780000              0         NaN   0.000000   0.000000
# 2     320.754286  320.769412              0         NaN   0.000000   0.000000
# 3     320.745306  320.765121              0  100.000000   0.000000   0.505476
# 4     320.743848  320.763744              0  100.000000   0.000000   0.498243
# ...          ...         ...            ...         ...        ...        ...
# 9779  632.830361  633.309401              0   25.823801  10.663527  46.998798
# 9780  632.009374  632.952561              0   28.047066  11.839346  43.162784
# 9781  630.919910  632.466971              0   30.248836  10.752101  41.533751
# 9782  630.034204  632.041599              0   32.426900  10.140201  41.518732
# 9783  629.249042  631.639576              0   33.787214  12.637961  39.446519
#
#       ADX60_rising3       ATR      NATR
# 0             False       NaN       NaN
# 1             False  1.390000  0.004333
# 2             False  1.325000  0.004134
# 3             False  1.271786  0.003966
# 4             False  1.198087  0.003735
# ...             ...       ...       ...
# 9779           True  3.107280  0.005000
# 9780           True  3.141760  0.005033
# 9781           True  3.212348  0.005176
# 9782           True  3.162895  0.005088
# 9783           True  3.091260  0.004972
#
# [9784 rows x 16 columns]

# %%
# get first breach out of ORB

def get_opening_range(df, date):
    day_df = df[df['Date'] == date].copy()
    mask = (day_df['Time'] >= pd.to_datetime("09:30").time()) & \
           (day_df['Time'] <  pd.to_datetime("9:45").time())
    or_data = day_df.loc[mask]
    if or_data.empty:
        return None, None
    return or_data['high'].max(), or_data['low'].min()


def get_first_breach(df, date):
    high_or, low_or = get_opening_range(df, date)
    if high_or is None:
        return None

    day_df = df[df['Date'] == date].copy()
    # only consider after OR is formed
    intraday = day_df[day_df['Time'] >= pd.to_datetime("9:45").time()]

    for _, row in intraday.iterrows():
        if row['close'] > high_or:   # breach to upside
            return {
                'Date': date,
                'timeBreach': row['Time'],
                'breach': 'high',
                'OR_high': high_or,
                'OR_low': low_or,
            }
        elif row['close'] < low_or:   # breach to downside
            return {
                'Date': date,
                'timeBreach': row['Time'],
                'breach': 'low',
                'OR_high': high_or,
                'OR_low': low_or,
            }
    return None


# get the first retest after the breach
def get_first_retest(data_df, date, breach_df):
    
    day_df = data_df[data_df['Date'] == date].copy()
    breachInfo = breach_df[breach_df['Date'] == date].copy()
    
    high_or = breachInfo['OR_high'].iloc[0]
    low_or = breachInfo['OR_low'].iloc[0]
    timeBreach = breachInfo['timeBreach'].iloc[0]
    typeBreach = breachInfo['breach'].iloc[0]
    
    # only consider after first OR breach
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeBreach)).time()]
    
    fullBreach = False
    
    for _, row in intraday.iterrows():
        
        if typeBreach == 'high':
            if row['low'] > high_or :
                fullBreach = True # we can start looking for a real retest now
        elif typeBreach == 'low':
            if row['high'] < low_or :
                fullBreach = True # we can start looking for a real retest now
        
        if fullBreach == True:
            if typeBreach == 'high':
                if row['low'] <= high_or:   # retest
                    return {
                        'Date': date,
                        'timeBreach': timeBreach,
                        'breach': typeBreach,
                        'OR_high': high_or,
                        'OR_low': low_or,
                        'timeRetest': row['Time']
                    }
            elif typeBreach == 'low':
                if row['high'] >= low_or:   # retest
                    return {
                        'Date': date,
                        'timeBreach': timeBreach,
                        'breach': typeBreach,
                        'OR_high': high_or,
                        'OR_low': low_or,
                        'timeRetest': row['Time']
                    }
    return None

# detect confirmation bar out of ORB after retest
def detectConfirmation(data_df, date, retests_df):
    
    day_df = data_df[data_df['Date'] == date].copy()
    retestInfo = retests_df[retests_df['Date'] == date].copy()
    
    high_or = retestInfo['OR_high'].iloc[0]
    low_or = retestInfo['OR_low'].iloc[0]
    timeRetest = retestInfo['timeRetest'].iloc[0]
    typeBreach = retestInfo['breach'].iloc[0]

    # only consider after first OR breach
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeRetest)).time()]
    
    confirmationBar = False
    
    for _, row in intraday.iterrows():
        
        if typeBreach == 'high':
            if row['low'] > high_or :
                confirmationBar = True # we can start looking for a real retest now
        elif typeBreach == 'low':
            if row['high'] < low_or :
                confirmationBar = True # we can start looking for a real retest now
        
        if confirmationBar == True:
            if typeBreach == 'high':
 
                return {
                    'Date': date,
                    'timeBreach': retestInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': row['Time']
                }
            elif typeBreach == 'low':
                return {
                    'Date': date,
                    'timeBreach': retestInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': row['Time']
                }
    return None



def getORB_retest_data(df):
    
    df = df.copy(deep=True)
    
    breaches = []
    for d in SPY_Data['Date'].unique():
        b = get_first_breach(SPY_Data, d)
        if b:
            breaches.append(b)
    
    breach_df = pd.DataFrame(breaches)
    breach_df
    
    
    
    retests = []
    for d in breach_df['Date'].unique():
        b = get_first_retest(SPY_Data, d, breach_df)
        if b:
            retests.append(b)
    
    retests_df = pd.DataFrame(retests)
    retests_df
    
    
    
    confirmationBars = []
    for d in retests_df['Date'].unique():
        b = detectConfirmation(SPY_Data, d, retests_df)
        if b:
            confirmationBars.append(b)
    
    confirmationBar_df = pd.DataFrame(confirmationBars)
    
    return confirmationBar_df

# %%
BO_and_retest = getORB_retest_data(SPY_Data)
BO_and_retest
# Out:
#             Date timeBreach breach  OR_high  OR_low timeRetest  \
# 0     2019-12-31   09:47:00   high   321.34  320.15   09:50:00
# 1     2020-01-02   10:11:00    low   324.00  323.41   12:41:00
# 2     2020-01-03   10:42:00   high   322.94  321.10   10:46:00
# 3     2020-01-06   09:46:00   high   321.43  320.36   09:55:00
# 4     2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# ...          ...        ...    ...      ...     ...        ...
# 1090  2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1091  2025-07-29   09:48:00    low   638.67  637.93   09:57:00
# 1092  2025-07-30   09:45:00   high   636.05  635.29   11:03:00
# 1093  2025-07-31   10:50:00    low   639.75  637.82   12:14:00
# 1094  2025-08-01   09:45:00    low   626.34  622.26   09:47:00
#
#      timeConfirmationBar
# 0               15:30:00
# 1               12:42:00
# 2               11:45:00
# 3               09:57:00
# 4               11:13:00
# ...                  ...
# 1090            09:59:00
# 1091            10:02:00
# 1092            11:59:00
# 1093            12:47:00
# 1094            09:48:00
#
# [1095 rows x 7 columns]

# %%
def runBacktest_WithTargets(data_df, date, confirmationBar_df, TargetMultiplier = 3, slippage=0.06):

    
    day_df = data_df[data_df['Date'] == date].copy()
    signalInfo = confirmationBar_df[confirmationBar_df['Date'] == date].copy()
    
    if signalInfo.empty or day_df.empty:
        return None

    high_or = signalInfo['OR_high'].iloc[0]
    low_or = signalInfo['OR_low'].iloc[0]
    timeRetest = signalInfo['timeRetest'].iloc[0]
    timeConfirmationBar = signalInfo['timeConfirmationBar'].iloc[0]
    typeBreach = signalInfo['breach'].iloc[0]
    
    DI_plus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['+DI'].iloc[0]
    DI_minus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['-DI'].iloc[0]
    ADX = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['ADX'].iloc[0]
    vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['vwap'].iloc[0]
    prev_vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['previous_vwap'].iloc[0]
    
    # only consider after confirmation candle
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)
    if intraday.empty:
        return None
    
    # entry price
    if typeBreach == 'high':
        entryPrice = intraday.iloc[0]['open'] + slippage
    else:
        entryPrice = intraday.iloc[0]['open'] - slippage
    
    
    # initial stop
    if typeBreach == 'high':   # long
        # stopLoss = high_or - ((high_or - low_or) * 0.15)
        stopLoss = low_or
    else:   # short
        # stopLoss = low_or + ((high_or - low_or) * 0.15)
        stopLoss = high_or

    # buffer = fraction of initial risk
    initialRisk = abs(entryPrice - stopLoss)
    buffer = initialRisk

    # loop intraday
    for i in range(len(intraday) - 1):  
        row = intraday.iloc[i]
        next_row = intraday.iloc[i+1]

        if typeBreach == 'high':  # long trade


            if row['low'] <= stopLoss:  # stop triggered
                
                exitPrice, exitTime = stopLoss, row['Time']

                # apply slippage against you
                exitPrice -= slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': exitPrice - entryPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['high'] >= entryPrice + initialRisk * TargetMultiplier: # target Reached 
                exitPrice = entryPrice + initialRisk * TargetMultiplier 
                # apply slippage against you 
                exitPrice -= slippage
                exitTime = row['Time']
                return { 'Date': date,
                         'timeBreach': signalInfo['timeBreach'].iloc[0],
                         'breach': typeBreach,
                         'OR_high': high_or,
                         'OR_low': low_or,
                         'timeRetest': timeRetest,
                         'timeConfirmationBar': timeConfirmationBar,
                         'timeExit': exitTime,
                         'entryPrice': entryPrice,
                         'exitPrice': exitPrice,
                         'returns': exitPrice - entryPrice,
                         '+DI': DI_plus,
                         '-DI': DI_minus,
                         'ADX': ADX,
                         'vwap': vwap,
                         'previous_vwap': prev_vwap }
            
            if row['high'] >= stopLoss + buffer:
                stopLoss = row['high'] - buffer


        else:  # short trade


            if row['high'] >= stopLoss:  # stop triggered
                exitPrice, exitTime = stopLoss, next_row['Time']

                # apply slippage against you
                exitPrice += slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['low'] <= entryPrice - initialRisk * TargetMultiplier: # target Reached 
                exitPrice = entryPrice - initialRisk * TargetMultiplier 
                # apply slippage against you 
                exitPrice += slippage
                exitTime = row['Time']
                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['low'] <= stopLoss - buffer:
                stopLoss = row['low'] + buffer
                
    # if stop never hit, exit at last close
    finalExit = intraday.iloc[-1]['close']
    finalExitTime = intraday.iloc[-1]['Time']

    # apply slippage
    if typeBreach == 'high':
        finalExit -= slippage
    else:
        finalExit += slippage

    return {
        'Date': date,
        'timeBreach': signalInfo['timeBreach'].iloc[0],
        'breach': typeBreach,
        'OR_high': high_or,
        'OR_low': low_or,
        'timeRetest': timeRetest,
        'timeConfirmationBar': timeConfirmationBar,
        'timeExit': finalExitTime,
        'entryPrice': entryPrice,
        'exitPrice': finalExit,
        'returns': finalExit - entryPrice if typeBreach == 'high' else entryPrice - finalExit,
        '+DI': DI_plus,
        '-DI': DI_minus,
        'ADX': ADX,
        'vwap': vwap,
        'previous_vwap': prev_vwap
    }

# %%
SPY_Data_VWAP = SPY_Data.copy(deep=True)

SPY_Data_VWAP['pv'] = (SPY_Data_VWAP['high'] + SPY_Data_VWAP['low'] + SPY_Data_VWAP['close']) * SPY_Data_VWAP['volume'] / 3
SPY_Data_VWAP['cum_pv'] = SPY_Data_VWAP.groupby('Date')['pv'].cumsum()
SPY_Data_VWAP['cum_vol'] = SPY_Data_VWAP.groupby('Date')['volume'].cumsum()
SPY_Data_VWAP['vwap'] = SPY_Data_VWAP['cum_pv'] / SPY_Data_VWAP['cum_vol']
previous_vwap = SPY_Data_VWAP.groupby('Date')['vwap'].last()
SPY_Data_VWAP['previous_vwap'] = SPY_Data_VWAP['Date'].map(previous_vwap.shift(1))

SPY_Data_VWAP = SPY_Data_VWAP.sort_values(['Date', 'Time']).copy()

SPY_Data_VWAP['bar_range'] = SPY_Data_VWAP['high'] - SPY_Data_VWAP['low']

SPY_Data_VWAP['range_ma_30m'] = (
    SPY_Data_VWAP
      .groupby('Date', group_keys=False)['bar_range']
      .rolling(window=30, min_periods=1)  # 30 bars = 30 minutes
      .mean()
      .reset_index(level=0, drop=True)
)
SPY_Data_VWAP['range_ma_30m'].shift(1)

# SPY_Data_VWAP = SPY_Data_VWAP.iloc[390:,]
# SPY_Data_VWAP




# df has columns: Date, Open, High, Low, Close, Volume
adx_df = adx(SPY_Data, period=14)
adx_df = SPY_Data_VWAP.join(adx_df)
adx_df['ADX'] = adx_df['ADX'].shift(1)


adx_df = adx_df.iloc[390:,]



# Run backtest
backtest = []
for d in BO_and_retest['Date'].unique():
    b = runBacktest_WithTargets(adx_df, d, BO_and_retest)
    if b:
        backtest.append(b)

backtest_df = pd.DataFrame(backtest)
print("Total PnL:", backtest_df['returns'].sum())
backtest_df
# Out:
# Total PnL: -24.439999999970524
#             Date timeBreach breach  OR_high  OR_low timeRetest  \
# 0     2020-01-02   10:11:00    low   324.00  323.41   12:41:00
# 1     2020-01-03   10:42:00   high   322.94  321.10   10:46:00
# 2     2020-01-06   09:46:00   high   321.43  320.36   09:55:00
# 3     2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# 4     2020-01-09   09:46:00    low   326.47  325.87   09:48:00
# ...          ...        ...    ...      ...     ...        ...
# 1089  2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1090  2025-07-29   09:48:00    low   638.67  637.93   09:57:00
# 1091  2025-07-30   09:45:00   high   636.05  635.29   11:03:00
# 1092  2025-07-31   10:50:00    low   639.75  637.82   12:14:00
# 1093  2025-08-01   09:45:00    low   626.34  622.26   09:47:00
#
#      timeConfirmationBar  timeExit  entryPrice  exitPrice  returns        +DI  \
# 0               12:42:00  14:43:00      323.30     323.72    -0.42  36.389123
# 1               11:45:00  15:59:00      323.10     322.38    -0.72  27.679027
# 2               09:57:00  15:59:00      321.69     323.61     1.92  22.183990
# 3               11:13:00  15:49:00      323.64     324.75     1.11  30.934500
# 4               10:02:00  10:40:00      325.78     326.53    -0.75  19.087368
# ...                  ...       ...         ...        ...      ...        ...
# 1089            09:59:00  10:17:00      635.17     634.10    -1.07  28.687251
# 1090            10:02:00  11:28:00      637.86     635.49     2.37  21.014290
# 1091            11:59:00  14:02:00      636.22     636.12    -0.10  33.638253
# 1092            12:47:00  14:27:00      637.53     633.71     3.82  16.225020
# 1093            09:48:00  12:03:00      621.46     624.59    -3.13   9.660471
#
#             -DI        ADX        vwap  previous_vwap
# 0     11.188261  21.224700  323.285371     321.132256
# 1     13.209203  24.469975  322.502957     323.630248
# 2     32.969274  24.218411  321.187351     322.772024
# 3     13.796344  25.297917  323.423256     322.923538
# 4     23.236385  17.128724  326.100222     324.556639
# ...         ...        ...         ...            ...
# 1089  19.533504  26.412032  634.658527     632.050872
# 1090  21.244910  22.842343  638.075902     636.841146
# 1091   8.497658  31.365205  635.860109     636.097311
# 1092  35.922195  19.319053  637.965776     634.709197
# 1093  49.292562  59.109188  623.760283     635.397610
#
# [1094 rows x 16 columns]

# %%
def runBacktest_MeanReversionTargets(
    data_df, date, confirmationBar_df,
    TargetMultiplier=3, slippage=0.06,
    target_mode='mid',          # 'mid' or 'vwap' (or 'R' to use old R-multiple)
    cap_max_R=2.0               # cap target distance to at most this many R (None to disable)
):
    """
    Mean-reversion sister to runBacktest_WithTargets.
    - After 'high' breach -> enter SHORT (fade); stop at OR_high.
    - After 'low'  breach -> enter LONG  (fade); stop at OR_low.
    - Target aims back toward range: OR midline (default) or VWAP.
      Optionally cap the target distance to <= cap_max_R * initialRisk.
    - If target_mode == 'R', behaves like your initial MR version (R-multiple).
    """

    day_df = data_df[data_df['Date'] == date].copy()
    signalInfo = confirmationBar_df[confirmationBar_df['Date'] == date].copy()
    if signalInfo.empty or day_df.empty:
        return None

    high_or = signalInfo['OR_high'].iloc[0]
    low_or  = signalInfo['OR_low'].iloc[0]
    timeRetest = signalInfo['timeRetest'].iloc[0]
    timeConfirmationBar = signalInfo['timeConfirmationBar'].iloc[0]
    typeBreach = signalInfo['breach'].iloc[0]

    # snapshot at confirmation time
    t_conf = pd.to_datetime(str(timeConfirmationBar)).time()
    snap = day_df[day_df['Time'] == t_conf].reset_index(drop=True)
    if snap.empty:
        return None

    DI_plus = snap['+DI'].iloc[0]
    DI_minus = snap['-DI'].iloc[0]
    ADX = snap['ADX'].iloc[0]
    vwap_conf = snap['vwap'].iloc[0]
    prev_vwap_conf = snap['previous_vwap'].iloc[0]

    # after confirmation bar
    intraday = day_df[day_df['Time'] > t_conf].reset_index(drop=True)
    if intraday.empty:
        return None

    # Entry + stop (fade)
    if typeBreach == 'high':
        # short entry (fade), pessimistic fill
        entryPrice = intraday.iloc[0]['open'] - slippage
        stopLoss = high_or
    else:
        # long entry (fade), pessimistic fill
        entryPrice = intraday.iloc[0]['open'] + slippage
        stopLoss = low_or

    initialRisk = abs(entryPrice - stopLoss)
    buffer = initialRisk

    # Compute mean-reversion target
    if target_mode == 'mid':
        target_level = 0.5 * (high_or + low_or)
    elif target_mode == 'vwap':
        target_level = float(vwap_conf)
    elif target_mode == 'R':
        # fallback: R-multiple (original MR logic) — tends to be too optimistic
        target_level = None
    else:
        raise ValueError("target_mode must be 'mid', 'vwap', or 'R'")

    # Optionally cap the distance to prevent huge theoretical profits
    def maybe_cap(level):
        if cap_max_R is None or level is None:
            return level
        dist = abs(level - entryPrice)
        cap_dist = cap_max_R * initialRisk
        if dist > cap_dist:
            # move target toward entry to respect cap
            return entryPrice + np.sign(level - entryPrice) * cap_dist
        return level

    if target_mode in ('mid', 'vwap'):
        target_level = maybe_cap(target_level)

    # Loop
    for i in range(len(intraday) - 1):
        row = intraday.iloc[i]
        next_row = intraday.iloc[i + 1]

        if typeBreach == 'high':
            # SHORT
            # Stop
            if row['high'] >= stopLoss:
                exitPrice, exitTime = stopLoss, next_row['Time']
                exitPrice += slippage  # against short
                return {
                    'Date': date, 'timeBreach': signalInfo['timeBreach'].iloc[0], 'breach': typeBreach,
                    'OR_high': high_or, 'OR_low': low_or, 'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar, 'timeExit': exitTime,
                    'entryPrice': entryPrice, 'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus, '-DI': DI_minus, 'ADX': ADX,
                    'vwap': vwap_conf, 'previous_vwap': prev_vwap_conf
                }

            # Target
            if target_mode == 'R':
                tgt = entryPrice - initialRisk * TargetMultiplier
                # conservative fill
                if row['low'] <= tgt:
                    exitPrice = tgt + slippage
                    exitTime = row['Time']
                    return {
                        'Date': date, 'timeBreach': signalInfo['timeBreach'].iloc[0], 'breach': typeBreach,
                        'OR_high': high_or, 'OR_low': low_or, 'timeRetest': timeRetest,
                        'timeConfirmationBar': timeConfirmationBar, 'timeExit': exitTime,
                        'entryPrice': entryPrice, 'exitPrice': exitPrice,
                        'returns': entryPrice - exitPrice,
                        '+DI': DI_plus, '-DI': DI_minus, 'ADX': ADX,
                        'vwap': vwap_conf, 'previous_vwap': prev_vwap_conf
                    }
            else:
                # mean-reversion toward range center/VWAP
                tgt = target_level
                if tgt is not None and row['low'] <= tgt:
                    exitPrice = tgt + slippage  # buy-to-cover worse fill
                    exitTime = row['Time']
                    return {
                        'Date': date, 'timeBreach': signalInfo['timeBreach'].iloc[0], 'breach': typeBreach,
                        'OR_high': high_or, 'OR_low': low_or, 'timeRetest': timeRetest,
                        'timeConfirmationBar': timeConfirmationBar, 'timeExit': exitTime,
                        'entryPrice': entryPrice, 'exitPrice': exitPrice,
                        'returns': entryPrice - exitPrice,
                        '+DI': DI_plus, '-DI': DI_minus, 'ADX': ADX,
                        'vwap': vwap_conf, 'previous_vwap': prev_vwap_conf
                    }

            # Trail (same style as your breakout)
            if row['low'] <= stopLoss - buffer:
                stopLoss = row['low'] + buffer

        else:
            # LONG
            # Stop
            if row['low'] <= stopLoss:
                exitPrice, exitTime = stopLoss, row['Time']
                exitPrice -= slippage  # against long
                return {
                    'Date': date, 'timeBreach': signalInfo['timeBreach'].iloc[0], 'breach': typeBreach,
                    'OR_high': high_or, 'OR_low': low_or, 'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar, 'timeExit': exitTime,
                    'entryPrice': entryPrice, 'exitPrice': exitPrice,
                    'returns': exitPrice - entryPrice,
                    '+DI': DI_plus, '-DI': DI_minus, 'ADX': ADX,
                    'vwap': vwap_conf, 'previous_vwap': prev_vwap_conf
                }

            # Target
            if target_mode == 'R':
                tgt = entryPrice + initialRisk * TargetMultiplier
                if row['high'] >= tgt:
                    exitPrice = tgt - slippage
                    exitTime = row['Time']
                    return {
                        'Date': date, 'timeBreach': signalInfo['timeBreach'].iloc[0], 'breach': typeBreach,
                        'OR_high': high_or, 'OR_low': low_or, 'timeRetest': timeRetest,
                        'timeConfirmationBar': timeConfirmationBar, 'timeExit': exitTime,
                        'entryPrice': entryPrice, 'exitPrice': exitPrice,
                        'returns': exitPrice - entryPrice,
                        '+DI': DI_plus, '-DI': DI_minus, 'ADX': ADX,
                        'vwap': vwap_conf, 'previous_vwap': prev_vwap_conf
                    }
            else:
                tgt = target_level
                if tgt is not None and row['high'] >= tgt:
                    exitPrice = tgt - slippage  # sell worse fill
                    exitTime = row['Time']
                    return {
                        'Date': date, 'timeBreach': signalInfo['timeBreach'].iloc[0], 'breach': typeBreach,
                        'OR_high': high_or, 'OR_low': low_or, 'timeRetest': timeRetest,
                        'timeConfirmationBar': timeConfirmationBar, 'timeExit': exitTime,
                        'entryPrice': entryPrice, 'exitPrice': exitPrice,
                        'returns': exitPrice - entryPrice,
                        '+DI': DI_plus, '-DI': DI_minus, 'ADX': ADX,
                        'vwap': vwap_conf, 'previous_vwap': prev_vwap_conf
                    }

            # Trail
            if row['high'] >= stopLoss + buffer:
                stopLoss = row['high'] - buffer

    # No stop/target: exit at close (conservative slippage)
    finalExit = intraday.iloc[-1]['close']
    finalExitTime = intraday.iloc[-1]['Time']
    if typeBreach == 'high':
        finalExit += slippage
        pnl = entryPrice - finalExit
    else:
        finalExit -= slippage
        pnl = finalExit - entryPrice

    return {
        'Date': date, 'timeBreach': signalInfo['timeBreach'].iloc[0], 'breach': typeBreach,
        'OR_high': high_or, 'OR_low': low_or, 'timeRetest': timeRetest,
        'timeConfirmationBar': timeConfirmationBar, 'timeExit': finalExitTime,
        'entryPrice': entryPrice, 'exitPrice': finalExit, 'returns': pnl,
        '+DI': DI_plus, '-DI': DI_minus, 'ADX': ADX,
        'vwap': vwap_conf, 'previous_vwap': prev_vwap_conf
    }

# %%
def runBacktest_MeanReversionTargets(data_df, date, confirmationBar_df, TargetMultiplier = 2, slippage=0.06):

    
    day_df = data_df[data_df['Date'] == date].copy()
    signalInfo = confirmationBar_df[confirmationBar_df['Date'] == date].copy()
    
    if signalInfo.empty or day_df.empty:
        return None

    high_or = signalInfo['OR_high'].iloc[0]
    low_or = signalInfo['OR_low'].iloc[0]
    timeRetest = signalInfo['timeRetest'].iloc[0]
    timeConfirmationBar = signalInfo['timeConfirmationBar'].iloc[0]
    typeBreach = signalInfo['breach'].iloc[0]
    
    DI_plus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['+DI'].iloc[0]
    DI_minus = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['-DI'].iloc[0]
    ADX = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['ADX'].iloc[0]
    vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['vwap'].iloc[0]
    prev_vwap = day_df[day_df['Time'] == pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)['previous_vwap'].iloc[0]
    
    # only consider after confirmation candle
    intraday = day_df[day_df['Time'] > pd.to_datetime(str(timeConfirmationBar)).time()].reset_index(drop=True)
    if intraday.empty:
        return None
    
    # entry price
    if typeBreach == 'high':
        entryPrice = intraday.iloc[0]['open'] - slippage
    else:
        entryPrice = intraday.iloc[0]['open'] + slippage
    
    
    # initial stop
    if typeBreach == 'high':   # long
        # stopLoss = high_or - ((high_or - low_or) * 0.15)
        stopLoss = high_or + (entryPrice - low_or)
    else:   # short
        # stopLoss = low_or + ((high_or - low_or) * 0.15)
        stopLoss = low_or - (high_or - entryPrice)

    # buffer = fraction of initial risk
    initialRisk = abs(entryPrice - stopLoss)
    buffer = initialRisk

    # loop intraday
    for i in range(len(intraday) - 1):  
        row = intraday.iloc[i]
        next_row = intraday.iloc[i+1]

        if typeBreach == 'low':  # long trade


            if row['low'] <= stopLoss:  # stop triggered
                
                exitPrice, exitTime = stopLoss, row['Time']

                # apply slippage against you
                exitPrice -= slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': exitPrice - entryPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['high'] >= entryPrice + initialRisk * TargetMultiplier: # target Reached 
                exitPrice = entryPrice + initialRisk * TargetMultiplier 
                # apply slippage against you 
                exitPrice -= slippage
                exitTime = row['Time']
                return { 'Date': date,
                         'timeBreach': signalInfo['timeBreach'].iloc[0],
                         'breach': typeBreach,
                         'OR_high': high_or,
                         'OR_low': low_or,
                         'timeRetest': timeRetest,
                         'timeConfirmationBar': timeConfirmationBar,
                         'timeExit': exitTime,
                         'entryPrice': entryPrice,
                         'exitPrice': exitPrice,
                         'returns': exitPrice - entryPrice,
                         '+DI': DI_plus,
                         '-DI': DI_minus,
                         'ADX': ADX,
                         'vwap': vwap,
                         'previous_vwap': prev_vwap }
            
            if row['high'] >= stopLoss + buffer:
                stopLoss = row['high'] - buffer


        else:  # short trade


            if row['high'] >= stopLoss:  # stop triggered
                exitPrice, exitTime = stopLoss, next_row['Time']

                # apply slippage against you
                exitPrice += slippage  

                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['low'] <= entryPrice - initialRisk * TargetMultiplier: # target Reached 
                exitPrice = entryPrice - initialRisk * TargetMultiplier 
                # apply slippage against you 
                exitPrice += slippage
                exitTime = row['Time']
                return {
                    'Date': date,
                    'timeBreach': signalInfo['timeBreach'].iloc[0],
                    'breach': typeBreach,
                    'OR_high': high_or,
                    'OR_low': low_or,
                    'timeRetest': timeRetest,
                    'timeConfirmationBar': timeConfirmationBar,
                    'timeExit': exitTime,
                    'entryPrice': entryPrice,
                    'exitPrice': exitPrice,
                    'returns': entryPrice - exitPrice,
                    '+DI': DI_plus,
                    '-DI': DI_minus,
                    'ADX': ADX,
                    'vwap': vwap,
                    'previous_vwap': prev_vwap
                }
            
            if row['low'] <= stopLoss - buffer:
                stopLoss = row['low'] + buffer
                
    # if stop never hit, exit at last close
    finalExit = intraday.iloc[-1]['close']
    finalExitTime = intraday.iloc[-1]['Time']

    # apply slippage
    if typeBreach == 'high':
        finalExit += slippage
    else:
        finalExit -= slippage

    return {
        'Date': date,
        'timeBreach': signalInfo['timeBreach'].iloc[0],
        'breach': typeBreach,
        'OR_high': high_or,
        'OR_low': low_or,
        'timeRetest': timeRetest,
        'timeConfirmationBar': timeConfirmationBar,
        'timeExit': finalExitTime,
        'entryPrice': entryPrice,
        'exitPrice': finalExit,
        'returns': finalExit - entryPrice if typeBreach == 'low' else entryPrice - finalExit,
        '+DI': DI_plus,
        '-DI': DI_minus,
        'ADX': ADX,
        'vwap': vwap,
        'previous_vwap': prev_vwap
    }

# %%
SPY_Data_VWAP = SPY_Data.copy(deep=True)

SPY_Data_VWAP['pv'] = (SPY_Data_VWAP['high'] + SPY_Data_VWAP['low'] + SPY_Data_VWAP['close']) * SPY_Data_VWAP['volume'] / 3
SPY_Data_VWAP['cum_pv'] = SPY_Data_VWAP.groupby('Date')['pv'].cumsum()
SPY_Data_VWAP['cum_vol'] = SPY_Data_VWAP.groupby('Date')['volume'].cumsum()
SPY_Data_VWAP['vwap'] = SPY_Data_VWAP['cum_pv'] / SPY_Data_VWAP['cum_vol']
previous_vwap = SPY_Data_VWAP.groupby('Date')['vwap'].last()
SPY_Data_VWAP['previous_vwap'] = SPY_Data_VWAP['Date'].map(previous_vwap.shift(1))

SPY_Data_VWAP = SPY_Data_VWAP.sort_values(['Date', 'Time']).copy()

SPY_Data_VWAP['bar_range'] = SPY_Data_VWAP['high'] - SPY_Data_VWAP['low']

SPY_Data_VWAP['range_ma_30m'] = (
    SPY_Data_VWAP
      .groupby('Date', group_keys=False)['bar_range']
      .rolling(window=30, min_periods=1)  # 30 bars = 30 minutes
      .mean()
      .reset_index(level=0, drop=True)
)
SPY_Data_VWAP['range_ma_30m'].shift(1)

# SPY_Data_VWAP = SPY_Data_VWAP.iloc[390:,]
# SPY_Data_VWAP




# df has columns: Date, Open, High, Low, Close, Volume
adx_df = adx(SPY_Data, period=14)
adx_df = SPY_Data_VWAP.join(adx_df)
adx_df['ADX'] = adx_df['ADX'].shift(1)


adx_df = adx_df.iloc[390:,]



# Run backtest
backtest = []
for d in BO_and_retest['Date'].unique():
    b = runBacktest_MeanReversionTargets(adx_df, d, BO_and_retest, 3)
    if b:
        backtest.append(b)

backtest_meanReversion_df = pd.DataFrame(backtest)
print("Total PnL:", backtest_meanReversion_df['returns'].sum())
backtest_meanReversion_df
# Out:
# Total PnL: -112.32999999997799
#             Date timeBreach breach  OR_high  OR_low timeRetest  \
# 0     2020-01-02   10:11:00    low   324.00  323.41   12:41:00
# 1     2020-01-03   10:42:00   high   322.94  321.10   10:46:00
# 2     2020-01-06   09:46:00   high   321.43  320.36   09:55:00
# 3     2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# 4     2020-01-09   09:46:00    low   326.47  325.87   09:48:00
# ...          ...        ...    ...      ...     ...        ...
# 1089  2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1090  2025-07-29   09:48:00    low   638.67  637.93   09:57:00
# 1091  2025-07-30   09:45:00   high   636.05  635.29   11:03:00
# 1092  2025-07-31   10:50:00    low   639.75  637.82   12:14:00
# 1093  2025-08-01   09:45:00    low   626.34  622.26   09:47:00
#
#      timeConfirmationBar  timeExit  entryPrice  exitPrice       returns  \
# 0               12:42:00  15:59:00      323.42     324.78  1.360000e+00
# 1               11:45:00  15:59:00      322.98     322.50  4.800000e-01
# 2               09:57:00  11:35:00      321.57     322.60 -1.030000e+00
# 3               11:13:00  11:30:00      323.52     324.26 -7.400000e-01
# 4               10:02:00  12:23:00      325.90     325.95  5.000000e-02
# ...                  ...       ...         ...        ...           ...
# 1089            09:59:00  10:34:00      635.05     635.05  1.136868e-13
# 1090            10:02:00  10:43:00      637.98     637.24 -7.400000e-01
# 1091            11:59:00  13:41:00      636.10     636.81 -7.100000e-01
# 1092            12:47:00  13:23:00      637.65     635.98 -1.670000e+00
# 1093            09:48:00  13:03:00      621.58     620.83 -7.500000e-01
#
#             +DI        -DI        ADX        vwap  previous_vwap
# 0     36.389123  11.188261  21.224700  323.285371     321.132256
# 1     27.679027  13.209203  24.469975  322.502957     323.630248
# 2     22.183990  32.969274  24.218411  321.187351     322.772024
# 3     30.934500  13.796344  25.297917  323.423256     322.923538
# 4     19.087368  23.236385  17.128724  326.100222     324.556639
# ...         ...        ...        ...         ...            ...
# 1089  28.687251  19.533504  26.412032  634.658527     632.050872
# 1090  21.014290  21.244910  22.842343  638.075902     636.841146
# 1091  33.638253   8.497658  31.365205  635.860109     636.097311
# 1092  16.225020  35.922195  19.319053  637.965776     634.709197
# 1093   9.660471  49.292562  59.109188  623.760283     635.397610
#
# [1094 rows x 16 columns]

# %%
stats, equity, dd = trade_stats(backtest_meanReversion_df, pnl_col='returns')  # or r_col='R' if you have it
print(pd.Series(stats))
# Out:
# n_trades                1094.000000
# win_rate                   0.336088
# avg_win                    1.651448
# avg_loss                  -0.959101
# payoff_ratio               1.721871
# expectancy_per_trade      -0.081726
# gross_profit             604.430000
# gross_loss               693.430000
# profit_factor              0.871653
# total_pnl                -89.000000
# median_pnl                -0.435000
# max_drawdown            -123.680000
# sharpe_per_trade          -2.259903
# dtype: float64

# %%
stats, equity, dd = trade_stats(backtest_meanReversion_df, pnl_col='returns')  # or r_col='R' if you have it
print(pd.Series(stats))
# Out:
# n_trades                1094.000000
# win_rate                   0.336088
# avg_win                    1.587705
# avg_loss                  -0.959101
# payoff_ratio               1.655410
# expectancy_per_trade      -0.103150
# gross_profit             581.100000
# gross_loss               693.430000
# profit_factor              0.838008
# total_pnl               -112.330000
# median_pnl                -0.435000
# max_drawdown            -131.200000
# sharpe_per_trade          -2.794861
# dtype: float64

# %%
# function that helps joining the higher time frame data to the lower time frame data for when making decisions
def join_HTF_to_LTF_data(LTF, HTF):
    
    LTF = LTF.copy(deep=True)
    HTF = HTF.copy(deep=True)
    
    LTF['ts'] = pd.to_datetime(LTF['Date'].astype(str) + ' ' + LTF['timeConfirmationBar'].astype(str), errors='coerce')
    LTF['ts_30'] = (LTF['ts'] - pd.Timedelta('30min')).dt.floor('H') + pd.Timedelta('30min')
    LTF['hour_rounded_down'] = LTF['ts_30'].dt.strftime('%H:%M:%S')
    
    # temp = temp.copy(deep=True)
    
    # 1) Make Date real datetimes (same tz & day-level)
    for df in (LTF, HTF):
        df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.tz_localize(None).dt.normalize()
    
    # 2) Build matching time string keys
    LTF['time_key'] = LTF['ts_30'].dt.strftime('%H:%M:%S')        # you already have ts_30
    HTF['Time_key'] = pd.to_datetime(
        HTF['Time'], format='%H:%M:%S', errors='coerce'
    ).dt.strftime('%H:%M:%S')
    
    # 3) (Optional) ensure right side is unique per key
    htf_keyed = HTF.drop_duplicates(['Date','Time_key'])
    
    # tracking column names
    LTF_columns = LTF.columns
    
    
    # 4) Merge
    LTF = LTF.merge(
        htf_keyed,
        left_on=['Date','time_key'],
        right_on=['Date','Time_key'],
        how='left',
        validate='many_to_one'
    )
    
    new_cols = ['ema20', 'ema50', 'ema_alignment','volume60','ADX60','DIp60','DIn60','ADX60_rising3','ATR','NATR']
    LTF = LTF[[*LTF_columns, *new_cols]]
    LTF = LTF.drop(columns=['ts', 'ts_30', 'hour_rounded_down'])
    
    return LTF

# %%
def trade_stats(df, pnl_col='returns', r_col=None, equity_start=0.0):
    """
    df must have a PnL column (default: 'returns').
    If you also have an R-multiple column, pass its name via r_col.
    Returns (stats_dict, equity_series, drawdown_series).
    """
    # sort (optional, helps equity curve look right)
    if {'Date','timeExit'}.issubset(df.columns):
        df = df.sort_values(['Date','timeExit'])
    s = pd.Series(df[pnl_col].astype(float).values)
    n = int(s.size)
    if n == 0:
        return {}, pd.Series(dtype=float), pd.Series(dtype=float)

    wins   = s[s > 0]
    losses = s[s < 0]

    gross_profit = float(wins.sum())
    gross_loss   = float(-losses.sum())  # positive number

    win_rate  = float(len(wins) / (len(wins) + len(losses)))
    loss_rate = float(len(losses) / (len(wins) + len(losses)))

    avg_win  = float(wins.mean())   if len(wins)   else 0.0
    avg_loss = float(losses.mean()) if len(losses) else 0.0  # negative
    payoff   = (avg_win / abs(avg_loss)) if len(wins) and len(losses) else np.inf

    profit_factor = (gross_profit / gross_loss) if gross_loss > 0 else np.inf
    expectancy    = win_rate * avg_win + loss_rate * avg_loss  # per trade

    equity = pd.Series(equity_start + s.cumsum(), name='equity')
    run_max = equity.cummax()
    drawdown = equity - run_max
    max_dd = float(drawdown.min())  # negative

    std = float(s.std(ddof=1))
    sharpe_per_trade = (float(s.mean() - 0.04) / std * np.sqrt(n)) if std > 0 and n > 1 else np.nan

    stats = {
        'n_trades': n,
        'win_rate': win_rate,
        'avg_win': avg_win,
        'avg_loss': avg_loss,                 # negative number
        'payoff_ratio': payoff,               # |avg_win| / |avg_loss|
        'expectancy_per_trade': expectancy,   # same units as returns
        'gross_profit': gross_profit,
        'gross_loss': gross_loss,
        'profit_factor': profit_factor,
        'total_pnl': float(s.sum()),
        'median_pnl': float(s.median()),
        'max_drawdown': max_dd,               # same units as returns
        'sharpe_per_trade': sharpe_per_trade
    }

    if r_col and r_col in df.columns:
        r = df[r_col].astype(float)
        stats.update({
            'avg_R': float(r.mean()),
            'median_R': float(r.median()),
            'total_R': float(r.sum()),
            'win_rate_Rpos': float((r > 0).mean())
        })

    return stats, equity, drawdown






# rawBacktest = backtest_df.copy(deep=True)
rawBacktest = backtest_meanReversion_df.copy(deep=True)

rawBacktest = join_HTF_to_LTF_data(rawBacktest, htf_test)
rawBacktest = rawBacktest[rawBacktest['Date'] != datetime.date(2025, 4, 9)]
rawBacktest = rawBacktest[rawBacktest['Date'] != pd.Timestamp('2025-04-09')]
rawBacktest['ORB_width'] = (rawBacktest['OR_high'] - rawBacktest['OR_low'])/ rawBacktest['OR_low']* 100


# temp = backtest_df.copy(deep=True)
temp = backtest_meanReversion_df.copy(deep=True)

temp = join_HTF_to_LTF_data(temp, htf_test)

temp = temp[temp['Date'] != datetime.date(2025, 4, 9)]
temp = temp[temp['Date'] != pd.Timestamp('2025-04-09')]


temp['ORB_width'] = (temp['OR_high'] - temp['OR_low'])/ temp['OR_low']* 100

# temp = temp[(temp['ORB_width'] > 0.15) & (temp['ORB_width'] < 0.5)]
# temp = temp[temp['ORB_width'] < 0.5]

# temp = backtest_df2[backtest_df2['timeConfirmationBar'] > dtime(15, 0)]

# temp = temp[temp['returns'] > 0]
# mask = (temp['breach'] == 'high') & (temp['+DI'] > temp['-DI']) & (temp['ADX'] > 18)
# temp['returns'] = temp['returns'].where(mask, 0) 

# print(temp['ADX'].median())

# mask = ~((temp['breach'] == 'low') & (temp['DIp60'] > temp['DIn60']) & (temp['ADX60'] < 18)) #& (temp['ADX60_rising3'] == False)
# temp['returns'] = temp['returns'].where(mask, 0) 

# temp = temp[(temp['ORB_width'] < 0.5) & (temp['ADX60'] > 18) & (((temp['DIp60'] > temp['DIn60']) & (temp['breach'] == 'high')) | ((temp['DIp60'] < temp['DIn60']) & (temp['breach'] == 'low'))) & (temp['ADX'] > 12)]

# temp = temp[(temp['ORB_width'] < 0.3) & (temp['ADX60'] > 18) & (((temp['ema20'] > temp['ema50']) & (temp['breach'] == 'high')) | ((temp['ema20'] < temp['ema50']) & (temp['breach'] == 'low'))) & (temp['ADX'] > 12) & (((temp['+DI'] > temp['-DI']) & (temp['breach'] == 'high')) | ((temp['+DI'] < temp['-DI']) & (temp['breach'] == 'low'))) & (((temp['entryPrice'] > temp['vwap']) & (temp['breach'] == 'high')) | ((temp['entryPrice'] < temp['vwap']) & (temp['breach'] == 'low')))]

# best win to dd
#[0.3, 18, None, None, None, True, 12, True, False]
# best win rate
#[0.5, 18, None, None, None, None, 20, True, False]


# mask = ~((temp['breach'] == 'high') & (temp['entryPrice'] < temp['vwap']))
# temp['returns'] = temp['returns'].where(mask, 0) 

print('Number of trades: ', temp[temp['returns']!= 0]['returns'].count())
temp['returns'] = temp['returns']# * 50 

stats, equity, dd = trade_stats(temp, pnl_col='returns')  # or r_col='R' if you have it
print(pd.Series(stats))



if 'Date' in temp.columns:
    temp['Date'] = pd.to_datetime(temp['Date'], errors='coerce')
    df = temp.sort_values('Date')

r = pd.to_numeric(df['returns'], errors='coerce').fillna(0)

# 1) Cumulative PnL (use for per-trade PnL/points)
df['cum_pnl'] = r.cumsum()


import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(df['Date'] if 'Date' in df.columns else df.index, df['cum_pnl'])
plt.title('Cumulative PnL')
plt.xlabel('Date' if 'Date' in df.columns else 'Trade #')
plt.ylabel('PnL')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()



temp
# Out:
# Number of trades:  1088
# n_trades                1093.000000
# win_rate                   0.336397
# avg_win                    1.587705
# avg_loss                  -0.957687
# payoff_ratio               1.657854
# expectancy_per_trade      -0.101425
# gross_profit             581.100000
# gross_loss               691.450000
# profit_factor              0.840408
# total_pnl               -110.350000
# median_pnl                -0.430000
# max_drawdown            -131.200000
# sharpe_per_trade          -2.760253
# dtype: float64
#            Date timeBreach breach  OR_high  OR_low timeRetest  \
# 0    2020-01-02   10:11:00    low   324.00  323.41   12:41:00
# 1    2020-01-03   10:42:00   high   322.94  321.10   10:46:00
# 2    2020-01-06   09:46:00   high   321.43  320.36   09:55:00
# 3    2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# 4    2020-01-09   09:46:00    low   326.47  325.87   09:48:00
# ...         ...        ...    ...      ...     ...        ...
# 1089 2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1090 2025-07-29   09:48:00    low   638.67  637.93   09:57:00
# 1091 2025-07-30   09:45:00   high   636.05  635.29   11:03:00
# 1092 2025-07-31   10:50:00    low   639.75  637.82   12:14:00
# 1093 2025-08-01   09:45:00    low   626.34  622.26   09:47:00
#
#      timeConfirmationBar  timeExit  entryPrice  exitPrice  ...       ema50  \
# 0               12:42:00  15:59:00      323.42     324.78  ...  321.098323
# 1               11:45:00  15:59:00      322.98     322.50  ...  321.598776
# 2               09:57:00  11:35:00      321.57     322.60  ...  321.843003
# 3               11:13:00  11:30:00      323.52     324.26  ...  322.353723
# 4               10:02:00  12:23:00      325.90     325.95  ...  322.879630
# ...                  ...       ...         ...        ...  ...         ...
# 1089            09:59:00  10:34:00      635.05     635.05  ...  628.011180
# 1090            10:02:00  10:43:00      637.98     637.24  ...  632.756108
# 1091            11:59:00  13:41:00      636.10     636.81  ...  633.664124
# 1092            12:47:00  13:23:00      637.65     635.98  ...  634.359902
# 1093            09:48:00  13:03:00      621.58     620.83  ...  634.216356
#
#       ema_alignment  volume60      ADX60      DIp60      DIn60 ADX60_rising3  \
# 0                 1     29925  94.169703  17.336585   1.138629         False
# 1                 1     42222  81.288298  19.176507  16.290885         False
# 2                 1     80736  58.381624  18.020335  19.912363         False
# 3                 1     51908  26.603792  20.851126  18.711194         False
# 4                 1     67463  25.953374  24.447575  15.537389         False
# ...             ...       ...        ...        ...        ...           ...
# 1089              1     93199  27.222619  35.969261  11.672061          True
# 1090              1     74009  32.240598  25.966579  18.964144         False
# 1091              1     37272  19.579287  24.020484  22.175622         False
# 1092              1     60882  16.917541  24.345256  26.954579         False
# 1093              1    214909  19.882191  15.768141  34.429888          True
#
#            ATR      NATR  ORB_width
# 0     1.088863  0.003370   0.182431
# 1     1.160276  0.003596   0.573030
# 2     1.049477  0.003255   0.333999
# 3     0.899041  0.002780   0.269625
# 4     0.965456  0.002976   0.184123
# ...        ...       ...        ...
# 1089  1.428511  0.002253   0.145113
# 1090  1.109081  0.001741   0.116000
# 1091  1.309101  0.002061   0.119630
# 1092  2.123122  0.003327   0.302593
# 1093  2.437082  0.003857   0.655674
#
# [1093 rows x 28 columns]

# %% [markdown]
# -----------------------------------------------------------
# new
# -----------------------------------------------------------

# %%
def make_param_grid():
    grid = {
        # HTF regime
        'ORB_width': [None, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8],
        'ADX60': [None, 12, 14, 16, 18, 20, 22, 24],
        'ADX60_rising3': [None, True, False],
        'DIp60_over_DIn60': [None, True, False],
        'NATR': [None, 0.0075, 0.010, 0.0125, 0.0150, 0.0175],
        'ema20_over_ema50': [None, True, False],
        'ADX': [None, 12, 14, 16, 18, 20, 22, 24],
        'DI+_over_DI-': [None, True, False],
        'vwap': [None, True, False],
        'excludeSide': [None, 'high', 'low'],
    }

    keys, vals = zip(*grid.items())
    combos = [dict(zip(keys, v)) for v in product(*vals)]
    return combos

def filterCounterParameters(df, listParams):
    ORB_width = listParams[0]
    ADX60 = listParams[1]
    ADX60_rising3 = listParams[2]
    DIp60_over_DIn60 = listParams[3]
    ema20_over_ema50 = listParams[4]
    ADX = listParams[5]
    DIp_over_DIn = listParams[6]
    vwap = listParams[7]
    excludeSide = listParams[8]

    mask = pd.Series(True, index=df.index)

    # ORB_width
    if ORB_width is not None: mask &= (df['ORB_width'] <= ORB_width)

    # ADX60
    if ADX60 is not None:
        mask &= (df['ADX60'] < ADX60)

    # ADX60 rising
    if ADX60_rising3 is not None:
        mask &= (df['ADX60_rising3'] == ADX60_rising3)

    # DIp60_over_DIn60
    if DIp60_over_DIn60 is not None:
        if DIp60_over_DIn60 == True:
            mask &= (((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | (
                        (df['DIp60'] < df['DIn60']) & (df['breach'] == 'low')))
        elif DIp60_over_DIn60 == False:
            mask &= (((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | (
                        (df['DIp60'] > df['DIn60']) & (df['breach'] == 'low')))
        else:
            print('error with DIp60_over_DIn60')

    # ema20_over_ema50
    if ema20_over_ema50 is not None:
        if ema20_over_ema50 == True:
            mask &= (((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | (
                        (df['ema20'] < df['ema50']) & (df['breach'] == 'low')))
        elif ema20_over_ema50 == False:
            mask &= (((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | (
                        (df['ema20'] > df['ema50']) & (df['breach'] == 'low')))
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX is not None:
        mask &= (df['ADX'] < ADX)

    # DI+_over_DI-
    if DIp_over_DIn is not None:
        if DIp_over_DIn == True:
            mask &= (((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | (
                        (df['+DI'] < df['-DI']) & (df['breach'] == 'low')))
        elif DIp_over_DIn == False:
            mask &= (((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | (
                        (df['+DI'] > df['-DI']) & (df['breach'] == 'low')))
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap is not None:
        if vwap == True:
            mask &= (((df['vwap'] < df['entryPrice']) & (df['breach'] == 'high')) | (
                        (df['vwap'] > df['entryPrice']) & (df['breach'] == 'low')))
        elif vwap == False:
            mask &= (((df['vwap'] > df['entryPrice']) & (df['breach'] == 'high')) | (
                        (df['vwap'] < df['entryPrice']) & (df['breach'] == 'low')))
        else:
            print('error with vwap')

    if excludeSide is not None:
        if excludeSide == 'high':
            mask &= (df['breach'] != 'high')
        elif excludeSide == 'low':
            mask &= (df['breach'] != 'low')
        else:
            print('error with excludeSide')

    return df[mask]




def filterParameters(df, listParams):
    ORB_width = listParams[0]
    ADX60 = listParams[1]
    ADX60_rising3 = listParams[2]
    DIp60_over_DIn60 = listParams[3]
    ema20_over_ema50 = listParams[4]
    ADX = listParams[5]
    DIp_over_DIn = listParams[6]
    vwap = listParams[7]
    excludeSide = listParams[8]

    mask = pd.Series(True, index=df.index)

    # ORB_width
    if ORB_width is not None: mask &= (df['ORB_width'] <= ORB_width)

    # ADX60
    if ADX60 is not None:
        mask &= (df['ADX60'] > ADX60)

    # ADX60 rising
    if ADX60_rising3 is not None:
        mask &= (df['ADX60_rising3'] == ADX60_rising3)

    # DIp60_over_DIn60
    if DIp60_over_DIn60 is not None:
        if DIp60_over_DIn60 == True:
            mask &= (((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | (
                        (df['DIp60'] < df['DIn60']) & (df['breach'] == 'low')))
        elif DIp60_over_DIn60 == False:
            mask &= (((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | (
                        (df['DIp60'] > df['DIn60']) & (df['breach'] == 'low')))
        else:
            print('error with DIp60_over_DIn60')

    # ema20_over_ema50
    if ema20_over_ema50 is not None:
        if ema20_over_ema50 == True:
            mask &= (((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | (
                        (df['ema20'] < df['ema50']) & (df['breach'] == 'low')))
        elif ema20_over_ema50 == False:
            mask &= (((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | (
                        (df['ema20'] > df['ema50']) & (df['breach'] == 'low')))
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX is not None:
        mask &= (df['ADX'] > ADX)

    # DI+_over_DI-
    if DIp_over_DIn is not None:
        if DIp_over_DIn == True:
            mask &= (((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | (
                        (df['+DI'] < df['-DI']) & (df['breach'] == 'low')))
        elif DIp_over_DIn == False:
            mask &= (((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | (
                        (df['+DI'] > df['-DI']) & (df['breach'] == 'low')))
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap is not None:
        if vwap == True:
            mask &= (((df['vwap'] < df['entryPrice']) & (df['breach'] == 'high')) | (
                        (df['vwap'] > df['entryPrice']) & (df['breach'] == 'low')))
        elif vwap == False:
            mask &= (((df['vwap'] > df['entryPrice']) & (df['breach'] == 'high')) | (
                        (df['vwap'] < df['entryPrice']) & (df['breach'] == 'low')))
        else:
            print('error with vwap')

    if excludeSide is not None:
        if excludeSide == 'high':
            mask &= (df['breach'] != 'high')
        elif excludeSide == 'low':
            mask &= (df['breach'] != 'low')
        else:
            print('error with excludeSide')

    return df[mask]








import math
import pandas as pd
import numpy as np

def run_param_search(rawBacktest, make_param_grid, min_trades=250):
    """
    Iterate over parameter combinations, filter the backtest DF, compute stats,
    and store *all* parameter + metric rows in a single DataFrame.
    """
    results = []
    count = 0
    
    for p in make_param_grid():
        print(count)
        count = count + 1
        # Unpack with your current names
        ORB_width          = p['ORB_width']
        ADX60              = p['ADX60']
        ADX60_rising3      = p['ADX60_rising3']
        DIp60_over_DIn60   = p['DIp60_over_DIn60']
        ema20_over_ema50   = p['ema20_over_ema50']
        ADX                 = p['ADX']
        DIp_over_DIn        = p['DI+_over_DI-']
        vwap               = p['vwap']
        excludeSide        = p['excludeSide']

        # Filter once per param set
        df_filt = filterParameters(
            rawBacktest.copy(deep=True),
            [ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
             ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide]
        )

        n = len(df_filt)
        if n <= 0:
            # # still log the attempt if you want: set metrics to NaN
            # results.append({
            #     'n_trades': n,
            #     'ORB_width': ORB_width, 'ADX60': ADX60, 'ADX60_rising3': ADX60_rising3,
            #     'DIp60_over_DIn60': DIp60_over_DIn60, 'ema20_over_ema50': ema20_over_ema50,
            #     'ADX': ADX, 'DIp_over_DIn': DIp_over_DIn, 'vwap': vwap, 'excludeSide': excludeSide,
            #     'total_pnl': np.nan, 'win_rate': np.nan, 'avg_win': np.nan, 'avg_loss': np.nan,
            #     'payoff_ratio': np.nan, 'expectancy_per_trade': np.nan, 'gross_profit': np.nan,
            #     'gross_loss': np.nan, 'profit_factor': np.nan, 'median_pnl': np.nan,
            #     'max_drawdown': np.nan, 'sharpe_per_trade': np.nan,
            #     'win_to_drawdown': np.nan, 'pf_adj': np.nan
            # })
            continue

        # Compute stats with your existing function
        stats, equity, dd = trade_stats(df_filt, pnl_col='returns')
        
        if stats.get('total_pnl', np.nan) <= 0:
            continue
        
        # print(pd.Series(stats))
        # Derived metrics that are handy to sort by
        max_dd = stats.get('max_drawdown', np.nan) or np.nan
        total_pnl = stats.get('total_pnl', np.nan) or np.nan
        if pd.notna(max_dd) and max_dd < 0:
            win_to_dd = total_pnl / abs(max_dd) if abs(max_dd) > 1e-9 else np.inf
        else:
            # if no drawdown recorded (or 0), treat very carefully
            win_to_dd = np.inf if pd.notna(total_pnl) and total_pnl > 0 else np.nan

        # A “penalized” profit factor that ignores ultra-low trade counts
        pf = stats.get('profit_factor', np.nan)
        pf_adj = pf if (pd.notna(pf) and n >= max(min_trades, 300)) else np.nan

        # Store row
        results.append({
            'n_trades': n,
            'ORB_width': ORB_width, 'ADX60': ADX60, 'ADX60_rising3': ADX60_rising3,
            'DIp60_over_DIn60': DIp60_over_DIn60, 'ema20_over_ema50': ema20_over_ema50,
            'ADX': ADX, 'DIp_over_DIn': DIp_over_DIn, 'vwap': vwap, 'excludeSide': excludeSide,
            'total_pnl': stats.get('total_pnl', np.nan),
            'win_rate': stats.get('win_rate', np.nan),
            'avg_win': stats.get('avg_win', np.nan),
            'avg_loss': stats.get('avg_loss', np.nan),
            'payoff_ratio': stats.get('payoff_ratio', np.nan),
            'expectancy_per_trade': stats.get('expectancy_per_trade', np.nan),
            'gross_profit': stats.get('gross_profit', np.nan),
            'gross_loss': stats.get('gross_loss', np.nan),
            'profit_factor': pf,
            'median_pnl': stats.get('median_pnl', np.nan),
            'max_drawdown': max_dd,
            'sharpe_per_trade': stats.get('sharpe_per_trade', np.nan),
            'win_to_drawdown': win_to_dd,
            'pf_adj': pf_adj
        })

    results_df = pd.DataFrame(results)

    # Optional: helpful sorts
    # Top by total_pnl
    # results_df.sort_values(['total_pnl','win_to_drawdown','n_trades'], ascending=[False, False, False], inplace=True)

    return results_df




def run_param_search_counter(rawBacktest, make_param_grid, min_trades=250):
    """
    Iterate over parameter combinations, filter the backtest DF, compute stats,
    and store *all* parameter + metric rows in a single DataFrame.
    """
    results = []
    count = 0
    
    for p in make_param_grid():
        print(count)
        count = count + 1
        # Unpack with your current names
        ORB_width          = p['ORB_width']
        ADX60              = p['ADX60']
        ADX60_rising3      = p['ADX60_rising3']
        DIp60_over_DIn60   = p['DIp60_over_DIn60']
        ema20_over_ema50   = p['ema20_over_ema50']
        ADX                 = p['ADX']
        DIp_over_DIn        = p['DI+_over_DI-']
        vwap               = p['vwap']
        excludeSide        = p['excludeSide']

        # Filter once per param set
        df_filt = filterParameters(
            rawBacktest.copy(deep=True),
            [ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
             ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide]
        )

        n = len(df_filt)
        if n <= 0:
            # # still log the attempt if you want: set metrics to NaN
            # results.append({
            #     'n_trades': n,
            #     'ORB_width': ORB_width, 'ADX60': ADX60, 'ADX60_rising3': ADX60_rising3,
            #     'DIp60_over_DIn60': DIp60_over_DIn60, 'ema20_over_ema50': ema20_over_ema50,
            #     'ADX': ADX, 'DIp_over_DIn': DIp_over_DIn, 'vwap': vwap, 'excludeSide': excludeSide,
            #     'total_pnl': np.nan, 'win_rate': np.nan, 'avg_win': np.nan, 'avg_loss': np.nan,
            #     'payoff_ratio': np.nan, 'expectancy_per_trade': np.nan, 'gross_profit': np.nan,
            #     'gross_loss': np.nan, 'profit_factor': np.nan, 'median_pnl': np.nan,
            #     'max_drawdown': np.nan, 'sharpe_per_trade': np.nan,
            #     'win_to_drawdown': np.nan, 'pf_adj': np.nan
            # })
            continue

        # Compute stats with your existing function
        stats, equity, dd = trade_stats(df_filt, pnl_col='returns')
        
        if stats.get('total_pnl', np.nan) <= 0:
            continue
        
        # print(pd.Series(stats))
        # Derived metrics that are handy to sort by
        max_dd = stats.get('max_drawdown', np.nan) or np.nan
        total_pnl = stats.get('total_pnl', np.nan) or np.nan
        if pd.notna(max_dd) and max_dd < 0:
            win_to_dd = total_pnl / abs(max_dd) if abs(max_dd) > 1e-9 else np.inf
        else:
            # if no drawdown recorded (or 0), treat very carefully
            win_to_dd = np.inf if pd.notna(total_pnl) and total_pnl > 0 else np.nan

        # A “penalized” profit factor that ignores ultra-low trade counts
        pf = stats.get('profit_factor', np.nan)
        pf_adj = pf if (pd.notna(pf) and n >= max(min_trades, 300)) else np.nan

        # Store row
        results.append({
            'n_trades': n,
            'ORB_width': ORB_width, 'ADX60': ADX60, 'ADX60_rising3': ADX60_rising3,
            'DIp60_over_DIn60': DIp60_over_DIn60, 'ema20_over_ema50': ema20_over_ema50,
            'ADX': ADX, 'DIp_over_DIn': DIp_over_DIn, 'vwap': vwap, 'excludeSide': excludeSide,
            'total_pnl': stats.get('total_pnl', np.nan),
            'win_rate': stats.get('win_rate', np.nan),
            'avg_win': stats.get('avg_win', np.nan),
            'avg_loss': stats.get('avg_loss', np.nan),
            'payoff_ratio': stats.get('payoff_ratio', np.nan),
            'expectancy_per_trade': stats.get('expectancy_per_trade', np.nan),
            'gross_profit': stats.get('gross_profit', np.nan),
            'gross_loss': stats.get('gross_loss', np.nan),
            'profit_factor': pf,
            'median_pnl': stats.get('median_pnl', np.nan),
            'max_drawdown': max_dd,
            'sharpe_per_trade': stats.get('sharpe_per_trade', np.nan),
            'win_to_drawdown': win_to_dd,
            'pf_adj': pf_adj
        })

    results_df = pd.DataFrame(results)

    # Optional: helpful sorts
    # Top by total_pnl
    # results_df.sort_values(['total_pnl','win_to_drawdown','n_trades'], ascending=[False, False, False], inplace=True)

    return results_df




results_df = run_param_search_counter(rawBacktest, make_param_grid, min_trades=250)
# results_df = run_param_search(rawBacktest, make_param_grid, min_trades=250)
# results_df.to_excel("results.xlsx", index=False)


# backtest_meanReversion_df
# results_df = run_param_search(backtest_meanReversion_df, make_param_grid, min_trades=250)
results_df.to_excel("results_MeanReversion2.xlsx", index=False)


# 
# 
# 
# bestReturns = 0
# bestWinrate = 0
# bestWinToDrawdown = 0
# 
# for p in make_param_grid():
#     stats, bestReturns, bestWinrate, bestWinToDrawdown = testParameters(rawBacktest,
#                                                                         bestReturns,
#                                                                         bestWinrate,
#                                                                         bestWinToDrawdown,
#                                                                         ORB_width=p['ORB_width'],
#                                                                         ADX60=p['ADX60'],
#                                                                         ADX60_rising3=p['ADX60_rising3'],
#                                                                         DIp60_over_DIn60=p['DIp60_over_DIn60'],
#                                                                         # NATR=p['NATR'],
#                                                                         ema20_over_ema50=p['ema20_over_ema50'],
#                                                                         ADX=p['ADX'],
#                                                                         DIp_over_DIn=p['DI+_over_DI-'],
#                                                                         vwap=p['vwap'],
#                                                                         excludeSide=p['excludeSide']
#                                                                         )
#     # if (len(stats) > 0):
#     #     print(stats['total_pnl'])
#     # print(pd.Series(stats))
# print('bestReturns:\n', pd.Series(bestReturns))
# print('bestWinrate:\n', pd.Series(bestWinrate))
# print('bestWinToDrawdown:\n', pd.Series(bestWinToDrawdown))

# %% [markdown]
# -----------------------------------------------------------
# END

# %%
results_df
# Out:
#         n_trades  ORB_width  ADX60 ADX60_rising3 DIp60_over_DIn60  \
# 0             58        NaN    NaN          None             None
# 1             15        NaN    NaN          None             None
# 2             80        NaN    NaN          None             None
# 3             37        NaN    NaN          None             None
# 4             43        NaN    NaN          None             None
# ...          ...        ...    ...           ...              ...
# 558091         2        0.8   24.0         False            False
# 558092         2        0.8   24.0         False            False
# 558093         5        0.8   24.0         False            False
# 558094         2        0.8   24.0         False            False
# 558095         3        0.8   24.0         False            False
#
#        ema20_over_ema50   ADX DIp_over_DIn   vwap excludeSide  ...  \
# 0                  None   NaN         None  False         low  ...
# 1                  None   NaN         True  False         low  ...
# 2                  None   NaN        False  False        None  ...
# 3                  None   NaN        False  False        high  ...
# 4                  None   NaN        False  False         low  ...
# ...                 ...   ...          ...    ...         ...  ...
# 558091            False  24.0         True  False        None  ...
# 558092            False  24.0         True  False         low  ...
# 558093            False  24.0        False  False        None  ...
# 558094            False  24.0        False  False        high  ...
# 558095            False  24.0        False  False         low  ...
#
#         payoff_ratio  expectancy_per_trade  gross_profit  gross_loss  \
# 0           1.793182              0.047586         31.56       28.80
# 1           1.426601              0.144000         10.86        8.70
# 2           1.646728              0.021625         43.11       41.38
# 3           1.382196              0.030541         22.41       21.28
# 4           1.922388              0.013953         20.70       20.10
# ...              ...                   ...           ...         ...
# 558091      1.034146              0.035000          2.12        2.05
# 558092      1.034146              0.035000          2.12        2.05
# 558093      4.906250              0.814000          4.71        0.64
# 558094     19.888889              0.850000          1.79        0.09
# 558095      2.654545              0.790000          2.92        0.55
#
#         profit_factor  median_pnl  max_drawdown  sharpe_per_trade  \
# 0            1.095833      -0.180         -9.65          0.045605
# 1            1.248276      -0.100         -2.50          0.265169
# 2            1.041808      -0.180        -11.92         -0.130522
# 3            1.053102      -0.150         -6.78         -0.042411
# 4            1.029851      -0.200         -8.37         -0.144120
# ...               ...         ...           ...               ...
# 558091       1.034146       0.035           NaN         -0.002398
# 558092       1.034146       0.035           NaN         -0.002398
# 558093       7.359375       1.080         -0.09          1.587593
# 558094      19.888889       0.850           NaN          0.861702
# 558095       5.309091       1.080           NaN          1.063821
#
#         win_to_drawdown  pf_adj
# 0              0.286010     NaN
# 1              0.864000     NaN
# 2              0.145134     NaN
# 3              0.166667     NaN
# 4              0.071685     NaN
# ...                 ...     ...
# 558091              inf     NaN
# 558092              inf     NaN
# 558093        45.222222     NaN
# 558094              inf     NaN
# 558095              inf     NaN
#
# [558096 rows x 24 columns]

# %%
results_df_test = results_df.copy(deep=True)
# results_df_test['']


# results_df_test = results_df_test[results_df_test['n_trades'] > 40]
results_df_test = results_df_test[results_df_test['max_drawdown'] > results_df_test['max_drawdown'].median()]
results_df_test = results_df_test[results_df_test['total_pnl']*0.20 > abs(results_df_test['max_drawdown'])]
results_df_test = results_df_test[results_df_test['win_rate'] > results_df_test['win_rate'].median()]
print(results_df_test['max_drawdown'].median())
results_df_test = results_df_test.drop_duplicates()
results_df_test
# results_df_test.to_excel("results.xlsx", index=False)
# Out:
# -0.31999999999993634
#         n_trades  ORB_width  ADX60 ADX60_rising3 DIp60_over_DIn60  \
# 1026           3        NaN    NaN          None             True
# 1040          16        NaN    NaN          None             True
# 5939          13        NaN    NaN          True            False
# 5942          12        NaN    NaN          True            False
# 5944           7        NaN    NaN          True            False
# ...          ...        ...    ...           ...              ...
# 556749         7        0.8   24.0         False            False
# 556750         4        0.8   24.0         False            False
# 556756         5        0.8   24.0         False            False
# 556766         7        0.8   24.0         False            False
# 556767         4        0.8   24.0         False            False
#
#        ema20_over_ema50   ADX DIp_over_DIn   vwap excludeSide  ...  \
# 1026               True  22.0         True  False         low  ...
# 1040               True  24.0        False   None        high  ...
# 5939               True  24.0         True   None        None  ...
# 5942               True  24.0         True   True        None  ...
# 5944               True  24.0         True   True         low  ...
# ...                 ...   ...          ...    ...         ...  ...
# 556749            False  18.0        False  False        None  ...
# 556750            False  18.0        False  False        high  ...
# 556756            False  20.0         None  False        high  ...
# 556766            False  20.0        False  False        None  ...
# 556767            False  20.0        False  False        high  ...
#
#         payoff_ratio  expectancy_per_trade  gross_profit  gross_loss  \
# 1026        3.058824              0.580000          2.08        0.34
# 1040        1.465663              0.898125         20.83        6.46
# 5939        2.231524              0.856154         15.46        4.33
# 5942        2.674740              1.047500         15.46        2.89
# 5944        3.473016              1.382857         10.94        1.26
# ...              ...                   ...           ...         ...
# 556749      3.537500              0.717143          5.66        0.64
# 556750     10.148148              0.662500          2.74        0.09
# 556756      9.750000              0.684000          3.51        0.09
# 556766      3.537500              0.717143          5.66        0.64
# 556767     10.148148              0.662500          2.74        0.09
#
#         profit_factor  median_pnl  max_drawdown  sharpe_per_trade  \
# 1026         6.117647       0.870         -0.34          1.148070
# 1040         3.224458       0.910         -2.54          1.922807
# 5939         3.570439       1.310         -1.85          1.851645
# 5942         5.349481       1.395         -1.48          2.333993
# 5944         8.682540       1.580         -1.09          2.293306
# ...               ...         ...           ...               ...
# 556749       8.843750       0.530         -0.64          1.977645
# 556750      30.444444       0.475         -0.09          1.558738
# 556756      39.000000       0.530         -0.09          2.076814
# 556766       8.843750       0.530         -0.64          1.977645
# 556767      30.444444       0.475         -0.09          1.558738
#
#         win_to_drawdown  pf_adj
# 1026           5.117647     NaN
# 1040           5.657480     NaN
# 5939           6.016216     NaN
# 5942           8.493243     NaN
# 5944           8.880734     NaN
# ...                 ...     ...
# 556749         7.843750     NaN
# 556750        29.444444     NaN
# 556756        38.000000     NaN
# 556766         7.843750     NaN
# 556767        29.444444     NaN
#
# [1697 rows x 24 columns]

# %%
def combineParametersOptimized(tradeInfo_df, filterParameters_df):

    filterParameters_df = filterParameters_df.sort_values(by="win_to_drawdown", ascending=False)

    bestCombination_df = None
    kept_params = []

    for i in range(len(filterParameters_df)):
        row = filterParameters_df.iloc[i]

        listParams = [
            None if pd.isna(x) else x
            for x in [
                row['ORB_width'],
                row['ADX60'],
                row['ADX60_rising3'],
                row['DIp60_over_DIn60'],
                row['ema20_over_ema50'],
                row['ADX'],
                row['DIp_over_DIn'],
                row['vwap'],
                row['excludeSide']
            ]
        ]

        df_filt = filterParameters(tradeInfo_df, listParams)


        if df_filt is not None and len(df_filt):

            if bestCombination_df is None:
                bestCombination_df = df_filt
                kept_params.append(row.to_dict())

            candidate_df = pd.concat([bestCombination_df, df_filt], ignore_index=True).drop_duplicates()

            stats_bestCombination, equity, dd = trade_stats(bestCombination_df, pnl_col='returns')
            stats_candidateCombination, equity, dd = trade_stats(candidate_df, pnl_col='returns')

            if (stats_candidateCombination['total_pnl'] - stats_bestCombination['total_pnl']) - (abs(stats_candidateCombination['max_drawdown']) - abs(stats_bestCombination['max_drawdown'])) >0:
                bestCombination_df = candidate_df.copy(deep=True)
                kept_params.append(row.to_dict())

    # concatenate and drop duplicate rows
    return bestCombination_df, pd.DataFrame(kept_params)




test_optimized, optimizedParams = combineParametersOptimized(rawBacktest, results_df_test)
stats, equity, dd = trade_stats(test_optimized, pnl_col='returns')
print(pd.Series(stats))
# Out:
# n_trades                126.000000
# win_rate                  0.666667
# avg_win                   1.392857
# avg_loss                 -0.626429
# payoff_ratio              2.223489
# expectancy_per_trade      0.719762
# gross_profit            117.000000
# gross_loss               26.310000
# profit_factor             4.446978
# total_pnl                90.690000
# median_pnl                0.900000
# max_drawdown             -3.080000
# sharpe_per_trade          6.601311
# dtype: float64

# %%
optimizedParams
# Out:
#     n_trades  ORB_width  ADX60 ADX60_rising3 DIp60_over_DIn60  \
# 0          6        0.5   24.0         False            False
# 1         11        0.4   22.0          True             None
# 2         11        0.5   24.0          True             None
# 3          6        0.4   24.0         False            False
# 4         10        0.5   22.0          True             True
# 5          4        NaN   24.0         False             None
# 6          8        0.6   22.0          True             None
# 7          6        0.3   20.0         False            False
# 8         11        0.6   14.0         False             True
# 9          3        0.8   20.0          True            False
# 10         6        0.3   18.0          True             None
# 11         9        NaN   20.0         False             True
# 12         9        0.5   14.0         False             True
# 13         6        NaN   16.0         False             True
# 14         6        0.4   20.0          None             None
# 15        14        0.6    NaN          True             True
# 16         5        NaN   22.0          None             True
# 17         4        0.6   12.0          None             True
# 18         3        0.4   18.0         False             True
# 19         8        NaN   18.0          True            False
# 20         6        NaN   16.0          True            False
# 21         9        0.8    NaN         False             None
# 22        13        NaN   16.0          True            False
# 23         3        0.5   12.0         False            False
# 24         7        0.3   24.0          True            False
# 25        22        NaN   18.0          None             True
# 26         3        0.3    NaN         False            False
# 27         3        0.3   22.0          None            False
# 28         5        0.8   20.0          True             None
# 29        13        0.5   14.0          True            False
# 30         5        0.3   16.0          None            False
# 31        14        0.4   24.0          True            False
#
#    ema20_over_ema50   ADX DIp_over_DIn   vwap excludeSide  ...  payoff_ratio  \
# 0             False  24.0         None  False        None  ...      5.335937
# 1              None  24.0        False   None         low  ...     12.362069
# 2              None  22.0        False   None         low  ...     11.974138
# 3             False  20.0         None  False        None  ...     10.933333
# 4              True  24.0        False   None         low  ...     12.310345
# 5              None  22.0        False  False        high  ...     16.000000
# 6              None  24.0         None  False         low  ...     15.310345
# 7             False  18.0         None  False        None  ...      8.222222
# 8              True  22.0         None  False        None  ...      5.954741
# 9              True  24.0         None   True        high  ...     12.300000
# 10             True  18.0        False   True        None  ...      2.750000
# 11             None  22.0        False   None        high  ...      5.424658
# 12             True   NaN        False  False         low  ...      5.017241
# 13             None  24.0        False   True        high  ...      3.225397
# 14            False  16.0         None  False         low  ...      3.049451
# 15            False  24.0         True   None        None  ...      2.317881
# 16             None  24.0        False   True        high  ...      3.380952
# 17             None  22.0         True  False         low  ...      4.245098
# 18             None  16.0        False  False        high  ...      6.041667
# 19             True  24.0         True   True        None  ...      3.376344
# 20             True  24.0         True   True         low  ...      2.007339
# 21             True  22.0        False   None        high  ...      4.165138
# 22             True  16.0         True   True         low  ...      1.963079
# 23             None   NaN         True  False         low  ...      4.071429
# 24             None  20.0         True   None         low  ...      1.620000
# 25             None  24.0        False   None        high  ...      1.367907
# 26            False  18.0        False   True        None  ...      3.666667
# 27             True  22.0         None   True        high  ...      3.652778
# 28            False  24.0        False   None         low  ...      1.663551
# 29             True  16.0         True   True         low  ...      1.644097
# 30             True  22.0         True   True        high  ...      1.589041
# 31             None  24.0         None   None         low  ...      1.047552
#
#     expectancy_per_trade  gross_profit  gross_loss  profit_factor  median_pnl  \
# 0               1.031667          6.83        0.64      10.671875       1.435
# 1               0.842727          9.56        0.29      32.965517       0.960
# 2               0.815455          9.26        0.29      31.931034       0.960
# 3               0.805000          4.92        0.09      54.666667       0.650
# 4               0.804000          8.33        0.29      28.724138       0.875
# 5               1.057500          4.32        0.09      48.000000       1.125
# 6               0.888750          7.40        0.29      25.517241       1.020
# 7               0.601667          3.70        0.09      41.111111       0.650
# 8               0.784545          9.21        0.58      15.879310       0.790
# 9               1.180000          3.69        0.15      24.600000       1.480
# 10              0.450000          3.30        0.60       5.500000       0.585
# 11              1.458889         13.86        0.73      18.986301       1.640
# 12              0.582222          5.82        0.58      10.034483       0.730
# 13              1.588333         10.16        0.63      16.126984       1.480
# 14              0.773333          5.55        0.91       6.098901       1.090
# 15              0.684286         12.60        3.02       4.172185       0.785
# 16              1.578000          8.52        0.63      13.523810       1.640
# 17              0.997500          4.33        0.34      12.735294       1.040
# 18              0.443333          1.45        0.12      12.083333       0.460
# 19              1.415000         12.56        1.24      10.129032       1.530
# 20              1.641667         10.94        1.09      10.036697       1.825
# 21              0.887778          9.08        1.09       8.330275       1.000
# 22              0.838462         14.09        3.19       4.416928       0.900
# 23              1.166667          3.99        0.49       8.142857       1.870
# 24              0.610000          5.67        1.40       4.050000       0.980
# 25              0.778636         26.00        8.87       2.931229       0.995
# 26              0.506667          1.76        0.24       7.333333       0.410
# 27              0.756667          2.63        0.36       7.305556       0.950
# 28              1.210000          7.12        1.07       6.654206       1.590
# 29              0.451538          9.47        3.60       2.630556       0.730
# 30              0.782000          4.64        0.73       6.356164       0.950
# 31              0.791429         14.98        3.90       3.841026       1.310
#
#     max_drawdown  sharpe_per_trade  win_to_drawdown  pf_adj
# 0          -0.09          2.185772        68.777778     NaN
# 1          -0.16          3.708945        57.937500     NaN
# 2          -0.16          3.789547        56.062500     NaN
# 3          -0.09          2.490325        53.666667     NaN
# 4          -0.16          3.184304        50.250000     NaN
# 5          -0.09          1.959548        47.000000     NaN
# 6          -0.16          2.699383        44.437500     NaN
# 7          -0.09          3.312177        40.111111     NaN
# 8          -0.32          3.168716        26.968750     NaN
# 9          -0.15          1.634195        23.600000     NaN
# 10         -0.15          1.583417        18.000000     NaN
# 11         -0.73          3.081802        17.986301     NaN
# 12         -0.32          2.303983        16.375000     NaN
# 13         -0.63          2.469765        15.126984     NaN
# 14         -0.35          1.747827        13.257143     NaN
# 15         -0.76          2.066808        12.605263     NaN
# 16         -0.63          2.457189        12.523810     NaN
# 17         -0.34          1.793804        11.735294     NaN
# 18         -0.12          1.258302        11.083333     NaN
# 19         -1.24          2.697319         9.129032     NaN
# 20         -1.09          2.577141         9.036697     NaN
# 21         -0.99          2.202479         8.070707     NaN
# 22         -1.44          2.059237         7.569444     NaN
# 23         -0.49          1.355028         7.142857     NaN
# 24         -0.63          1.653108         6.777778     NaN
# 25         -2.54          2.087660         6.744094     NaN
# 26         -0.24          1.011127         6.333333     NaN
# 27         -0.36          1.200892         6.305556     NaN
# 28         -1.07          1.968821         5.654206     NaN
# 29         -1.09          1.368671         5.385321     NaN
# 30         -0.73          1.831825         5.356164     NaN
# 31         -2.18          2.360713         5.082569     NaN
#
# [32 rows x 24 columns]

# %%
from itertools import product

def make_param_grid():
    grid = {
        # HTF regime
        'ORB_width'        : [None, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8],
        'ADX60'        : [None, 12, 14, 16, 18, 20, 22, 24],
        'ADX60_rising3' : [None, True, False],
        'DIp60_over_DIn60' : [None, True, False],
        'NATR' : [None, 0.0075, 0.010, 0.0125, 0.0150, 0.0175],
        'ema20_over_ema50' : [None, True, False],
        'ADX' : [None, 12, 14, 16, 18, 20, 22, 24],
        'DI+_over_DI-' : [None, True, False],
        'vwap' : [None, True, False],
        'excludeSide' : [None, 'high', 'low'],
    }

    keys, vals = zip(*grid.items())
    combos = [dict(zip(keys, v)) for v in product(*vals)]
    return combos

# %%
def testParameters(df, bestReturns, bestWinrate, bestWinToDrawdown, ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide):
    df = df.copy(deep=True)

    # ORB_width
    if ORB_width != None:
        df = df[df['ORB_width'] < ORB_width]

    # ADX60
    if ADX60 != None:
        df = df[df['ADX60'] > ADX60]

    # ADX60 rising
    if ADX60_rising3 != None:
        df = df[df['ADX60_rising3'] == ADX60_rising3]

    # DIp60_over_DIn60
    if DIp60_over_DIn60 != None:
        if DIp60_over_DIn60 == True:
            df = df[((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] < df['DIn60']) & (df['breach'] == 'low'))]
        elif DIp60_over_DIn60 == False:
            df = df[((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] > df['DIn60']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # # NATR
    # if NATR != None:
    #     df = df[df['NATR'] > NATR]

    # ema20_over_ema50
    if ema20_over_ema50 != None:
        if ema20_over_ema50 == True:
            df = df[((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] < df['ema50']) & (df['breach'] == 'low'))]
        elif ema20_over_ema50 == False:
            df = df[((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] > df['ema50']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX != None:
        df = df[df['ADX'] > ADX]

    # DI+_over_DI-
    if DIp_over_DIn != None:
        if DIp_over_DIn == True:
            df = df[((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] < df['-DI']) & (df['breach'] == 'low'))]
        elif DIp_over_DIn == False:
            df = df[((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] > df['-DI']) & (df['breach'] == 'low'))]
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap != None:
        if vwap == True:
            df = df[((vwap < df['entryPrice']) & (df['breach'] == 'high')) | ((vwap > df['entryPrice']) & (df['breach'] == 'low'))]
        elif vwap == False:
            df = df[((vwap > df['entryPrice']) & (df['breach'] == 'high')) | ((vwap < df['entryPrice']) & (df['breach'] == 'low'))]
        else:
            print('error with vwap')

    
    if excludeSide != None:
        if excludeSide == 'high':
            df = df[df['breach'] != 'high']
        elif excludeSide == 'low':
            df = df[df['breach'] != 'high']
        else:
            print('error with excludeSide')
            

    stats, equity, dd = trade_stats(df, pnl_col='returns')
    # print(pd.Series(stats))
    if len(df) > 250:
        if bestReturns == 0:
            bestReturns = stats
        if bestWinrate == 0:
            bestWinrate = stats
        if bestWinToDrawdown == 0:
            bestWinToDrawdown = stats

        if stats['total_pnl'] > bestReturns['total_pnl']:
            bestReturns = stats
            print('new bestReturns:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap])
        if stats['win_rate'] > bestWinrate['win_rate']:
            bestWinrate = stats
            print('new win_rate:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap])
        if ((stats['total_pnl'] / max(-stats['max_drawdown'], 1e-9)) > (
                bestWinToDrawdown['total_pnl'] / max(-bestWinToDrawdown['max_drawdown'], 1e-9))) & (
                stats['total_pnl'] > 0):
            bestWinToDrawdown = stats
            print('new bestWinToDrawdown:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
            
            

    return stats, bestReturns, bestWinrate, bestWinToDrawdown




bestReturns = 0
bestWinrate = 0
bestWinToDrawdown = 0

for p in make_param_grid():
    stats, bestReturns, bestWinrate, bestWinToDrawdown = testParameters(rawBacktest,
                                                                        bestReturns,
                                                                        bestWinrate,
                                                                        bestWinToDrawdown,
                                                                        ORB_width=p['ORB_width'],
                                                                        ADX60=p['ADX60'],
                                                                        ADX60_rising3=p['ADX60_rising3'],
                                                                        DIp60_over_DIn60=p['DIp60_over_DIn60'],
                                                                        # NATR=p['NATR'],
                                                                        ema20_over_ema50=p['ema20_over_ema50'],
                                                                        ADX=p['ADX'],
                                                                        DIp_over_DIn=p['DI+_over_DI-'],
                                                                        vwap=p['vwap'],
                                                                        excludeSide=p['excludeSide']
                                                                        )
    # if (len(stats) > 0):
    #     print(stats['total_pnl'])
    # print(pd.Series(stats))
print('bestReturns:\n', pd.Series(bestReturns))
print('bestWinrate:\n', pd.Series(bestWinrate))
print('bestWinToDrawdown:\n', pd.Series(bestWinToDrawdown))
# Out:
# new bestWinToDrawdown: n_trades                535.000000
# win_rate                  0.405607
# avg_win                   2.058341
# avg_loss                 -1.182044
# payoff_ratio              1.741340
# expectancy_per_trade      0.132280
# gross_profit            446.660000
# gross_loss              375.890000
# profit_factor             1.188273
# total_pnl                70.770000
# median_pnl               -0.390000
# max_drawdown            -33.600000
# sharpe_per_trade          0.930910
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, None, None, None, 'high']
# new win_rate: n_trades                558.000000
# win_rate                  0.410394
# avg_win                   1.629039
# avg_loss                 -1.083587
# payoff_ratio              1.503377
# expectancy_per_trade      0.029659
# gross_profit            373.050000
# gross_loss              356.500000
# profit_factor             1.046424
# total_pnl                16.550000
# median_pnl               -0.340000
# max_drawdown            -41.070000
# sharpe_per_trade         -0.134268
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, None, None, True]
# new win_rate: n_trades                901.000000
# win_rate                  0.410655
# avg_win                   1.807297
# avg_loss                 -1.146874
# payoff_ratio              1.575847
# expectancy_per_trade      0.066271
# gross_profit            668.700000
# gross_loss              608.990000
# profit_factor             1.098048
# total_pnl                59.710000
# median_pnl               -0.370000
# max_drawdown            -46.680000
# sharpe_per_trade          0.378864
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, None, True, None]
# new win_rate: n_trades                444.000000
# win_rate                  0.414414
# avg_win                   1.636957
# avg_loss                 -1.075308
# payoff_ratio              1.522315
# expectancy_per_trade      0.048694
# gross_profit            301.200000
# gross_loss              279.580000
# profit_factor             1.077330
# total_pnl                21.620000
# median_pnl               -0.320000
# max_drawdown            -42.110000
# sharpe_per_trade          0.099070
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, None, True, True]
# new bestReturns: n_trades                1065.000000
# win_rate                   0.408451
# avg_win                    1.860391
# avg_loss                  -1.141079
# payoff_ratio               1.630378
# expectancy_per_trade       0.084873
# gross_profit             809.270000
# gross_loss               718.880000
# profit_factor              1.125737
# total_pnl                 90.390000
# median_pnl                -0.380000
# max_drawdown             -58.440000
# sharpe_per_trade           0.702695
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 12, None, None]
# new bestWinToDrawdown: n_trades                522.000000
# win_rate                  0.402299
# avg_win                   2.100143
# avg_loss                 -1.185897
# payoff_ratio              1.770931
# expectancy_per_trade      0.136073
# gross_profit            441.030000
# gross_loss              370.000000
# profit_factor             1.191973
# total_pnl                71.030000
# median_pnl               -0.395000
# max_drawdown            -31.530000
# sharpe_per_trade          0.948272
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 12, None, None, 'high']
# new win_rate: n_trades                431.000000
# win_rate                  0.417633
# avg_win                   1.646611
# avg_loss                 -1.085219
# payoff_ratio              1.517307
# expectancy_per_trade      0.055684
# gross_profit            296.390000
# gross_loss              272.390000
# profit_factor             1.088109
# total_pnl                24.000000
# median_pnl               -0.310000
# max_drawdown            -42.370000
# sharpe_per_trade          0.174458
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 12, True, True]
# new win_rate: n_trades                390.000000
# win_rate                  0.417949
# avg_win                   1.650798
# avg_loss                 -1.105859
# payoff_ratio              1.492774
# expectancy_per_trade      0.046282
# gross_profit            269.080000
# gross_loss              251.030000
# profit_factor             1.071904
# total_pnl                18.050000
# median_pnl               -0.330000
# max_drawdown            -42.180000
# sharpe_per_trade          0.065705
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 14, True, True]
# new bestReturns: n_trades                932.000000
# win_rate                  0.407725
# avg_win                   1.908184
# avg_loss                 -1.148388
# payoff_ratio              1.661620
# expectancy_per_trade      0.097854
# gross_profit            725.110000
# gross_loss              633.910000
# profit_factor             1.143869
# total_pnl                91.200000
# median_pnl               -0.380000
# max_drawdown            -56.660000
# sharpe_per_trade          0.830216
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 16, None, None]
# new bestWinToDrawdown: n_trades                473.000000
# win_rate                  0.401691
# avg_win                   2.157211
# avg_loss                 -1.160035
# payoff_ratio              1.859608
# expectancy_per_trade      0.172474
# gross_profit            409.870000
# gross_loss              328.290000
# profit_factor             1.248500
# total_pnl                81.580000
# median_pnl               -0.390000
# max_drawdown            -33.440000
# sharpe_per_trade          1.231972
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 16, None, None, 'high']
# new win_rate: n_trades                354.000000
# win_rate                  0.418079
# avg_win                   1.672770
# avg_loss                 -1.136553
# payoff_ratio              1.471792
# expectancy_per_trade      0.037966
# gross_profit            247.570000
# gross_loss              234.130000
# profit_factor             1.057404
# total_pnl                13.440000
# median_pnl               -0.330000
# max_drawdown            -35.810000
# sharpe_per_trade         -0.019835
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 16, True, True]
# new bestReturns: n_trades                831.000000
# win_rate                  0.418773
# avg_win                   1.907069
# avg_loss                 -1.151884
# payoff_ratio              1.655608
# expectancy_per_trade      0.129122
# gross_profit            663.660000
# gross_loss              556.360000
# profit_factor             1.192861
# total_pnl               107.300000
# median_pnl               -0.360000
# max_drawdown            -41.280000
# sharpe_per_trade          1.202770
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 18, None, None]
# new win_rate: n_trades                831.000000
# win_rate                  0.418773
# avg_win                   1.907069
# avg_loss                 -1.151884
# payoff_ratio              1.655608
# expectancy_per_trade      0.129122
# gross_profit            663.660000
# gross_loss              556.360000
# profit_factor             1.192861
# total_pnl               107.300000
# median_pnl               -0.360000
# max_drawdown            -41.280000
# sharpe_per_trade          1.202770
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 18, None, None]
# new bestWinToDrawdown: n_trades                831.000000
# win_rate                  0.418773
# avg_win                   1.907069
# avg_loss                 -1.151884
# payoff_ratio              1.655608
# expectancy_per_trade      0.129122
# gross_profit            663.660000
# gross_loss              556.360000
# profit_factor             1.192861
# total_pnl               107.300000
# median_pnl               -0.360000
# max_drawdown            -41.280000
# sharpe_per_trade          1.202770
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 18, None, None, None]
# new bestWinToDrawdown: n_trades                428.000000
# win_rate                  0.413551
# avg_win                   2.162881
# avg_loss                 -1.171992
# payoff_ratio              1.845474
# expectancy_per_trade      0.207150
# gross_profit            382.830000
# gross_loss              294.170000
# profit_factor             1.301390
# total_pnl                88.660000
# median_pnl               -0.370000
# max_drawdown            -29.240000
# sharpe_per_trade          1.458533
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 18, None, None, 'high']
# new win_rate: n_trades                403.000000
# win_rate                  0.424318
# avg_win                   1.642281
# avg_loss                 -1.130129
# payoff_ratio              1.453179
# expectancy_per_trade      0.046253
# gross_profit            280.830000
# gross_loss              262.190000
# profit_factor             1.071093
# total_pnl                18.640000
# median_pnl               -0.340000
# max_drawdown            -21.440000
# sharpe_per_trade          0.067721
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 18, None, True]
# new win_rate: n_trades                309.000000
# win_rate                  0.427184
# avg_win                   1.681136
# avg_loss                 -1.126497
# payoff_ratio              1.492357
# expectancy_per_trade      0.072880
# gross_profit            221.910000
# gross_loss              199.390000
# profit_factor             1.112944
# total_pnl                22.520000
# median_pnl               -0.300000
# max_drawdown            -22.980000
# sharpe_per_trade          0.302980
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 18, True, True]
# new win_rate: n_trades                351.000000
# win_rate                  0.435897
# avg_win                   1.587712
# avg_loss                 -1.150303
# payoff_ratio              1.380256
# expectancy_per_trade      0.043191
# gross_profit            242.920000
# gross_loss              227.760000
# profit_factor             1.066561
# total_pnl                15.160000
# median_pnl               -0.320000
# max_drawdown            -18.310000
# sharpe_per_trade          0.033298
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 20, None, True]
# new win_rate: n_trades                266.000000
# win_rate                  0.439850
# avg_win                   1.600684
# avg_loss                 -1.136644
# payoff_ratio              1.408254
# expectancy_per_trade      0.067368
# gross_profit            187.280000
# gross_loss              169.360000
# profit_factor             1.105810
# total_pnl                17.920000
# median_pnl               -0.270000
# max_drawdown            -19.100000
# sharpe_per_trade          0.245569
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, None, 20, True, True]
# new win_rate: n_trades                265.000000
# win_rate                  0.441509
# avg_win                   1.351026
# avg_loss                 -0.914797
# payoff_ratio              1.476858
# expectancy_per_trade      0.085585
# gross_profit            158.070000
# gross_loss              135.390000
# profit_factor             1.167516
# total_pnl                22.680000
# median_pnl               -0.270000
# max_drawdown            -25.060000
# sharpe_per_trade          0.501895
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 14, True, True]
# new bestWinToDrawdown: n_trades                476.000000
# win_rate                  0.441176
# avg_win                   1.942667
# avg_loss                 -1.135977
# payoff_ratio              1.710128
# expectancy_per_trade      0.222248
# gross_profit            407.960000
# gross_loss              302.170000
# profit_factor             1.350101
# total_pnl               105.790000
# median_pnl               -0.260000
# max_drawdown            -34.600000
# sharpe_per_trade          1.795905
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 16, None, None, None]
# new win_rate: n_trades                376.000000
# win_rate                  0.444149
# avg_win                   1.934012
# avg_loss                 -1.164880
# payoff_ratio              1.660267
# expectancy_per_trade      0.211489
# gross_profit            322.980000
# gross_loss              243.460000
# profit_factor             1.326624
# total_pnl                79.520000
# median_pnl               -0.245000
# max_drawdown            -22.890000
# sharpe_per_trade          1.468391
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 16, True, None]
# new bestWinToDrawdown: n_trades                376.000000
# win_rate                  0.444149
# avg_win                   1.934012
# avg_loss                 -1.164880
# payoff_ratio              1.660267
# expectancy_per_trade      0.211489
# gross_profit            322.980000
# gross_loss              243.460000
# profit_factor             1.326624
# total_pnl                79.520000
# median_pnl               -0.245000
# max_drawdown            -22.890000
# sharpe_per_trade          1.468391
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 16, True, None, None]
# new bestReturns: n_trades                420.000000
# win_rate                  0.454762
# avg_win                   1.953298
# avg_loss                 -1.144672
# payoff_ratio              1.706426
# expectancy_per_trade      0.264167
# gross_profit            373.080000
# gross_loss              262.130000
# profit_factor             1.423263
# total_pnl               110.950000
# median_pnl               -0.240000
# max_drawdown            -29.270000
# sharpe_per_trade          2.052374
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 18, None, None]
# new win_rate: n_trades                420.000000
# win_rate                  0.454762
# avg_win                   1.953298
# avg_loss                 -1.144672
# payoff_ratio              1.706426
# expectancy_per_trade      0.264167
# gross_profit            373.080000
# gross_loss              262.130000
# profit_factor             1.423263
# total_pnl               110.950000
# median_pnl               -0.240000
# max_drawdown            -29.270000
# sharpe_per_trade          2.052374
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 18, None, None]
# new bestWinToDrawdown: n_trades                420.000000
# win_rate                  0.454762
# avg_win                   1.953298
# avg_loss                 -1.144672
# payoff_ratio              1.706426
# expectancy_per_trade      0.264167
# gross_profit            373.080000
# gross_loss              262.130000
# profit_factor             1.423263
# total_pnl               110.950000
# median_pnl               -0.240000
# max_drawdown            -29.270000
# sharpe_per_trade          2.052374
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 18, None, None, None]
# new win_rate: n_trades                327.000000
# win_rate                  0.458716
# avg_win                   1.941400
# avg_loss                 -1.167458
# payoff_ratio              1.662930
# expectancy_per_trade      0.258624
# gross_profit            291.210000
# gross_loss              206.640000
# profit_factor             1.409262
# total_pnl                84.570000
# median_pnl               -0.180000
# max_drawdown            -15.760000
# sharpe_per_trade          1.729179
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 18, True, None]
# new bestWinToDrawdown: n_trades                327.000000
# win_rate                  0.458716
# avg_win                   1.941400
# avg_loss                 -1.167458
# payoff_ratio              1.662930
# expectancy_per_trade      0.258624
# gross_profit            291.210000
# gross_loss              206.640000
# profit_factor             1.409262
# total_pnl                84.570000
# median_pnl               -0.180000
# max_drawdown            -15.760000
# sharpe_per_trade          1.729179
# dtype: float64
# [None, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 18, True, None, None]
# new bestWinToDrawdown: n_trades                267.000000
# win_rate                  0.456929
# avg_win                   1.870000
# avg_loss                 -1.060828
# payoff_ratio              1.762775
# expectancy_per_trade      0.278352
# gross_profit            228.140000
# gross_loss              153.820000
# profit_factor             1.483162
# total_pnl                74.320000
# median_pnl               -0.180000
# max_drawdown            -11.730000
# sharpe_per_trade          1.921654
# dtype: float64
# [None, None, None, True, <function NATR at 0x0000020802EB01F0>, True, 16, True, None, None]
# new bestWinToDrawdown: n_trades                336.000000
# win_rate                  0.428571
# avg_win                   2.177500
# avg_loss                 -1.159948
# payoff_ratio              1.877239
# expectancy_per_trade      0.270387
# gross_profit            313.560000
# gross_loss              222.710000
# profit_factor             1.407930
# total_pnl                90.850000
# median_pnl               -0.330000
# max_drawdown            -13.630000
# sharpe_per_trade          1.742853
# dtype: float64
# [None, None, False, None, <function NATR at 0x0000020802EB01F0>, None, 12, None, None, 'high']
# new bestWinToDrawdown: n_trades                273.000000
# win_rate                  0.446886
# avg_win                   2.247459
# avg_loss                 -1.134503
# payoff_ratio              1.981007
# expectancy_per_trade      0.376850
# gross_profit            274.190000
# gross_loss              171.310000
# profit_factor             1.600549
# total_pnl               102.880000
# median_pnl               -0.290000
# max_drawdown            -13.850000
# sharpe_per_trade          2.233074
# dtype: float64
# [None, None, False, None, <function NATR at 0x0000020802EB01F0>, None, 18, None, None, 'high']
# new win_rate: n_trades                352.000000
# win_rate                  0.460227
# avg_win                   1.905185
# avg_loss                 -1.135000
# payoff_ratio              1.678577
# expectancy_per_trade      0.264176
# gross_profit            308.640000
# gross_loss              215.650000
# profit_factor             1.431208
# total_pnl                92.990000
# median_pnl               -0.205000
# max_drawdown            -20.940000
# sharpe_per_trade          1.862308
# dtype: float64
# [None, None, False, None, <function NATR at 0x0000020802EB01F0>, True, None, None, None]
# new win_rate: n_trades                312.000000
# win_rate                  0.464744
# avg_win                   1.955310
# avg_loss                 -1.165749
# payoff_ratio              1.677300
# expectancy_per_trade      0.284744
# gross_profit            283.520000
# gross_loss              194.680000
# profit_factor             1.456339
# total_pnl                88.840000
# median_pnl               -0.160000
# max_drawdown            -19.960000
# sharpe_per_trade          1.851898
# dtype: float64
# [None, None, False, None, <function NATR at 0x0000020802EB01F0>, True, 14, None, None]
# new win_rate: n_trades                283.000000
# win_rate                  0.473498
# avg_win                   1.998955
# avg_loss                 -1.141745
# payoff_ratio              1.750790
# expectancy_per_trade      0.345371
# gross_profit            267.860000
# gross_loss              170.120000
# profit_factor             1.574536
# total_pnl                97.740000
# median_pnl               -0.120000
# max_drawdown            -18.890000
# sharpe_per_trade          2.170457
# dtype: float64
# [None, None, False, None, <function NATR at 0x0000020802EB01F0>, True, 16, None, None]
# new win_rate: n_trades                258.000000
# win_rate                  0.476744
# avg_win                   2.023577
# avg_loss                 -1.157111
# payoff_ratio              1.748818
# expectancy_per_trade      0.359264
# gross_profit            248.900000
# gross_loss              156.210000
# profit_factor             1.593368
# total_pnl                92.690000
# median_pnl               -0.100000
# max_drawdown            -17.010000
# sharpe_per_trade          2.137610
# dtype: float64
# [None, 14, False, None, <function NATR at 0x0000020802EB01F0>, True, 16, None, None]
# new win_rate: n_trades                253.000000
# win_rate                  0.478261
# avg_win                   1.947934
# avg_loss                 -1.167273
# payoff_ratio              1.668791
# expectancy_per_trade      0.322609
# gross_profit            235.700000
# gross_loss              154.080000
# profit_factor             1.529725
# total_pnl                81.620000
# median_pnl               -0.110000
# max_drawdown            -21.760000
# sharpe_per_trade          1.902158
# dtype: float64
# [None, 18, False, None, <function NATR at 0x0000020802EB01F0>, True, None, None, None]
# new bestReturns: n_trades                319.000000
# win_rate                  0.454545
# avg_win                   2.127379
# avg_loss                 -1.109655
# payoff_ratio              1.917154
# expectancy_per_trade      0.361724
# gross_profit            308.470000
# gross_loss              193.080000
# profit_factor             1.597628
# total_pnl               115.390000
# median_pnl               -0.180000
# max_drawdown            -22.320000
# sharpe_per_trade          2.446929
# dtype: float64
# [None, 20, None, None, <function NATR at 0x0000020802EB01F0>, True, 16, None, None]
# new bestWinToDrawdown: n_trades                314.000000
# win_rate                  0.449045
# avg_win                   1.402340
# avg_loss                 -0.712254
# payoff_ratio              1.968876
# expectancy_per_trade      0.237293
# gross_profit            197.730000
# gross_loss              123.220000
# profit_factor             1.604691
# total_pnl                74.510000
# median_pnl               -0.215000
# max_drawdown             -7.230000
# sharpe_per_trade          2.567847
# dtype: float64
# [0.3, None, None, None, <function NATR at 0x0000020802EB01F0>, True, None, None, None, None]
# new bestWinToDrawdown: n_trades                309.000000
# win_rate                  0.449838
# avg_win                   1.417626
# avg_loss                 -0.718824
# payoff_ratio              1.972147
# expectancy_per_trade      0.242233
# gross_profit            197.050000
# gross_loss              122.200000
# profit_factor             1.612520
# total_pnl                74.850000
# median_pnl               -0.200000
# max_drawdown             -6.990000
# sharpe_per_trade          2.592778
# dtype: float64
# [0.3, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 12, None, None, None]
# new bestWinToDrawdown: n_trades                281.000000
# win_rate                  0.469751
# avg_win                   1.403333
# avg_loss                 -0.730738
# payoff_ratio              1.920432
# expectancy_per_trade      0.271744
# gross_profit            185.240000
# gross_loss              108.880000
# profit_factor             1.701323
# total_pnl                76.360000
# median_pnl               -0.140000
# max_drawdown             -6.510000
# sharpe_per_trade          2.825942
# dtype: float64
# [0.3, None, None, None, <function NATR at 0x0000020802EB01F0>, True, 14, None, None, None]
# new bestWinToDrawdown: n_trades                306.000000
# win_rate                  0.454248
# avg_win                   1.403741
# avg_loss                 -0.710180
# payoff_ratio              1.976600
# expectancy_per_trade      0.250065
# gross_profit            195.120000
# gross_loss              118.600000
# profit_factor             1.645194
# total_pnl                76.520000
# median_pnl               -0.180000
# max_drawdown             -6.150000
# sharpe_per_trade          2.685175
# dtype: float64
# [0.3, 12, None, None, <function NATR at 0x0000020802EB01F0>, True, None, None, None, None]
# new bestWinToDrawdown: n_trades                301.000000
# win_rate                  0.455150
# avg_win                   1.419270
# avg_loss                 -0.716951
# payoff_ratio              1.979591
# expectancy_per_trade      0.255349
# gross_profit            194.440000
# gross_loss              117.580000
# profit_factor             1.653683
# total_pnl                76.860000
# median_pnl               -0.180000
# max_drawdown             -6.150000
# sharpe_per_trade          2.710531
# dtype: float64
# [0.3, 12, None, None, <function NATR at 0x0000020802EB01F0>, True, 12, None, None, None]
# new bestWinToDrawdown: n_trades                290.000000
# win_rate                  0.462069
# avg_win                   1.431194
# avg_loss                 -0.700256
# payoff_ratio              2.043814
# expectancy_per_trade      0.284621
# gross_profit            191.780000
# gross_loss              109.240000
# profit_factor             1.755584
# total_pnl                82.540000
# median_pnl               -0.165000
# max_drawdown             -6.150000
# sharpe_per_trade          3.010473
# dtype: float64
# [0.3, 14, None, None, <function NATR at 0x0000020802EB01F0>, True, None, None, None, None]
# new bestWinToDrawdown: n_trades                285.000000
# win_rate                  0.463158
# avg_win                   1.447727
# avg_loss                 -0.707320
# payoff_ratio              2.046778
# expectancy_per_trade      0.290807
# gross_profit            191.100000
# gross_loss              108.220000
# profit_factor             1.765847
# total_pnl                82.880000
# median_pnl               -0.150000
# max_drawdown             -6.150000
# sharpe_per_trade          3.036944
# dtype: float64
# [0.3, 14, None, None, <function NATR at 0x0000020802EB01F0>, True, 12, None, None, None]
# new win_rate: n_trades                261.000000
# win_rate                  0.478927
# avg_win                   1.434320
# avg_loss                 -0.720221
# payoff_ratio              1.991501
# expectancy_per_trade      0.311648
# gross_profit            179.290000
# gross_loss               97.950000
# profit_factor             1.830424
# total_pnl                81.340000
# median_pnl               -0.090000
# max_drawdown             -6.020000
# sharpe_per_trade          3.143896
# dtype: float64
# [0.3, 14, None, None, <function NATR at 0x0000020802EB01F0>, True, 14, None, None]
# new bestWinToDrawdown: n_trades                261.000000
# win_rate                  0.478927
# avg_win                   1.434320
# avg_loss                 -0.720221
# payoff_ratio              1.991501
# expectancy_per_trade      0.311648
# gross_profit            179.290000
# gross_loss               97.950000
# profit_factor             1.830424
# total_pnl                81.340000
# median_pnl               -0.090000
# max_drawdown             -6.020000
# sharpe_per_trade          3.143896
# dtype: float64
# [0.3, 14, None, None, <function NATR at 0x0000020802EB01F0>, True, 14, None, None, None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[507], line 111
#     110 for p in make_param_grid():
# --> 111     stats, bestReturns, bestWinrate, bestWinToDrawdown = testParameters(rawBacktest,
#     112                                                                         bestReturns,
#     113                                                                         bestWinrate,
#     114                                                                         bestWinToDrawdown,
#     115                                                                         ORB_width=p['ORB_width'],
#     116                                                                         ADX60=p['ADX60'],
#     117                                                                         ADX60_rising3=p['ADX60_rising3'],
#     118                                                                         DIp60_over_DIn60=p['DIp60_over_DIn60'],
#     119                                                                         # NATR=p['NATR'],
#     120                                                                         ema20_over_ema50=p['ema20_over_ema50'],
#     121                                                                         ADX=p['ADX'],
#     122                                                                         DIp_over_DIn=p['DI+_over_DI-'],
#     123                                                                         vwap=p['vwap'],
#     124                                                                         excludeSide=p['excludeSide']
#     125                                                                         )
#     126     # if (len(stats) > 0):
#     127     #     print(stats['total_pnl'])
#     128     # print(pd.Series(stats))
#
# Cell In[507], line 71, in testParameters(df, bestReturns, bestWinrate, bestWinToDrawdown, ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60, ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide)
#      68         print('error with excludeSide')
# ---> 71 stats, equity, dd = trade_stats(df, pnl_col='returns')
#      72 # print(pd.Series(stats))
#
# Cell In[501], line 9, in trade_stats(df, pnl_col, r_col, equity_start)
#       8 if {'Date','timeExit'}.issubset(df.columns):
# ----> 9     df = df.sort_values(['Date','timeExit'])
#      10 s = pd.Series(df[pnl_col].astype(float).values)
#
# File ~\PycharmProjects\AlgoTrading\venv\lib\site-packages\pandas\core\frame.py:6938, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6933         keys = [
#    6934             Series(k, name=name)  # type: ignore[misc]
#    6935             for (k, name) in zip(keys, by)
#    6936         ]
# -> 6938     indexer = lexsort_indexer(
#    6939         keys, orders=ascending, na_position=na_position, key=key
#    6940     )
#    6941 elif len(by):
#    6942     # len(by) == 1
#
# File ~\PycharmProjects\AlgoTrading\venv\lib\site-packages\pandas\core\sorting.py:375, in lexsort_indexer(keys, orders, na_position, key, codes_given)
#     374 n = len(cat.categories)
# --> 375 codes = cat.codes.copy()
#     376 mask = cat.codes == -1
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
from itertools import product

def make_Counterparam_grid():
    grid = {
        # HTF regime
        'ORB_width'        : [ 0.3, 0.4, 0.5, 0.6, 0.7, 0.8],
        'ADX60'        : [ 12, 14, 16, 18, 20, 22, 24],
        'ADX60_rising3' : [None, True, False],
        'DIp60_over_DIn60' : [None, True, False],
        'NATR' : [ 0.0075, 0.010, 0.0125, 0.0150, 0.0175],
        'ema20_over_ema50' : [None, True, False],
        'ADX' : [12, 14, 16, 18, 20, 22, 24],
        'DI+_over_DI-' : [None, True, False],
        'vwap' : [None, True, False],
        'excludeSide' : [None, 'high', 'low'],
    }

    keys, vals = zip(*grid.items())
    combos = [dict(zip(keys, v)) for v in product(*vals)]
    return combos

# %%
def testCounterParameters(df, worstReturns, worstWinrate, worstWinToDrawdown, ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide):
    df = df.copy(deep=True)

    # ORB_width
    if ORB_width != None:
        df = df[df['ORB_width'] > ORB_width]

    # ADX60
    if ADX60 != None:
        df = df[df['ADX60'] < ADX60]

    # ADX60 rising
    if ADX60_rising3 != None:
        df = df[df['ADX60_rising3'] == ADX60_rising3]

    # DIp60_over_DIn60
    if DIp60_over_DIn60 != None:
        if DIp60_over_DIn60 == True:
            df = df[((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] < df['DIn60']) & (df['breach'] == 'low'))]
        elif DIp60_over_DIn60 == False:
            df = df[((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] > df['DIn60']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # # NATR
    # if NATR != None:
    #     df = df[df['NATR'] > NATR]

    # ema20_over_ema50
    if ema20_over_ema50 != None:
        if ema20_over_ema50 == True:
            df = df[((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] < df['ema50']) & (df['breach'] == 'low'))]
        elif ema20_over_ema50 == False:
            df = df[((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] > df['ema50']) & (df['breach'] == 'low'))]
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX != None:
        df = df[df['ADX'] < ADX]

    # DI+_over_DI-
    if DIp_over_DIn != None:
        if DIp_over_DIn == True:
            df = df[((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] < df['-DI']) & (df['breach'] == 'low'))]
        elif DIp_over_DIn == False:
            df = df[((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] > df['-DI']) & (df['breach'] == 'low'))]
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap != None:
        if vwap == True:
            df = df[((df['vwap'] < df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] > df['entryPrice']) & (df['breach'] == 'low'))]
        elif vwap == False:
            df = df[((df['vwap'] > df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] < df['entryPrice']) & (df['breach'] == 'low'))]
        else:
            print('error with vwap')

    
    if excludeSide != None:
        if excludeSide == 'high':
            df = df[df['breach'] != 'high']
        elif excludeSide == 'low':
            df = df[df['breach'] != 'low']
        else:
            print('error with excludeSide')
            
    stats = worstReturns        
    if len(df) > 150:
        stats, equity, dd = trade_stats(df, pnl_col='returns')
        # print(pd.Series(stats))
    
        if worstReturns == 0:
            worstReturns = stats
        if worstWinrate == 0:
            worstWinrate = stats
        if worstWinToDrawdown == 0:
            worstWinToDrawdown = stats

        if stats['total_pnl'] < worstReturns['total_pnl']:
            worstReturns = stats
            print('new worst Returns:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
        if stats['win_rate'] < worstWinrate['win_rate']:
            worstWinrate = stats
            print('new worst win_rate:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
        if ((stats['total_pnl'] / max(-stats['max_drawdown'], 1e-9)) < (
                worstWinToDrawdown['total_pnl'] / max(-worstWinToDrawdown['max_drawdown'], 1e-9))) & (
                stats['total_pnl'] > 0):
            worstWinToDrawdown = stats
            print('new best WinToDrawdown:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
            
            

    return stats, worstReturns, worstWinrate, worstWinToDrawdown




worstReturns = 0
worstWinrate = 0
worstWinToDrawdown = 0

for p in make_Counterparam_grid():
    stats, worstReturns, worstWinrate, worstWinToDrawdown = testCounterParameters(rawBacktest,
                                                                        worstReturns,
                                                                        worstWinrate,
                                                                        worstWinToDrawdown,
                                                                        ORB_width=p['ORB_width'],
                                                                        ADX60=p['ADX60'],
                                                                        ADX60_rising3=p['ADX60_rising3'],
                                                                        DIp60_over_DIn60=p['DIp60_over_DIn60'],
                                                                        # NATR=p['NATR'],
                                                                        ema20_over_ema50=p['ema20_over_ema50'],
                                                                        ADX=p['ADX'],
                                                                        DIp_over_DIn=p['DI+_over_DI-'],
                                                                        vwap=p['vwap'],
                                                                        excludeSide=p['excludeSide']
                                                                        )
    # if (len(stats) > 0):
    #     print(stats['total_pnl'])
    # print(pd.Series(stats))
print('worstReturns:\n', pd.Series(worstReturns))
print('worstWinrate:\n', pd.Series(worstWinrate))
print('worstWinToDrawdown:\n', pd.Series(worstWinToDrawdown))
# Out:
# KeyboardInterrupt

# %%
def testCounterParameters(df, worstReturns, worstWinrate, worstWinToDrawdown, ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide):
    df = df.copy(deep=True)

    df = filterOutCounterParameters(df, [ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60, ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
            
    stats = worstReturns        
    if len(df) > 150:
        stats, equity, dd = trade_stats(df, pnl_col='returns')
        # print(pd.Series(stats))
    
        if worstReturns == 0:
            worstReturns = stats
        if worstWinrate == 0:
            worstWinrate = stats
        if worstWinToDrawdown == 0:
            worstWinToDrawdown = stats

        if stats['total_pnl'] < worstReturns['total_pnl']:
            worstReturns = stats
            print('new worst Returns:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
        if stats['win_rate'] < worstWinrate['win_rate']:
            worstWinrate = stats
            print('new worst win_rate:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
        if ((stats['total_pnl'] / max(-stats['max_drawdown'], 1e-9)) < (
                worstWinToDrawdown['total_pnl'] / max(-worstWinToDrawdown['max_drawdown'], 1e-9))) & (
                stats['total_pnl'] > 0):
            worstWinToDrawdown = stats
            print('new best WinToDrawdown:', pd.Series(stats))
            print([ORB_width, ADX60, ADX60_rising3, DIp60_over_DIn60,
                    ema20_over_ema50, ADX, DIp_over_DIn, vwap, excludeSide])
            
            

    return stats, worstReturns, worstWinrate, worstWinToDrawdown




worstReturns = 0
worstWinrate = 0
worstWinToDrawdown = 0

for p in make_Counterparam_grid():
    stats, worstReturns, worstWinrate, worstWinToDrawdown = testCounterParameters(rawBacktest,
                                                                        worstReturns,
                                                                        worstWinrate,
                                                                        worstWinToDrawdown,
                                                                        ORB_width=p['ORB_width'],
                                                                        ADX60=p['ADX60'],
                                                                        ADX60_rising3=p['ADX60_rising3'],
                                                                        DIp60_over_DIn60=p['DIp60_over_DIn60'],
                                                                        # NATR=p['NATR'],
                                                                        ema20_over_ema50=p['ema20_over_ema50'],
                                                                        ADX=p['ADX'],
                                                                        DIp_over_DIn=p['DI+_over_DI-'],
                                                                        vwap=p['vwap'],
                                                                        excludeSide=p['excludeSide']
                                                                        )
    # if (len(stats) > 0):
    #     print(stats['total_pnl'])
    # print(pd.Series(stats))
print('worstReturns:\n', pd.Series(worstReturns))
print('worstWinrate:\n', pd.Series(worstWinrate))
print('worstWinToDrawdown:\n', pd.Series(worstWinToDrawdown))
# Out:
# new worst Returns: n_trades                775.000000
# win_rate                  0.358710
# avg_win                   1.794979
# avg_loss                 -1.213618
# payoff_ratio              1.479032
# expectancy_per_trade     -0.134405
# gross_profit            499.004271
# gross_loss              603.168172
# profit_factor             0.827305
# total_pnl              -104.163902
# median_pnl               -0.510500
# max_drawdown           -123.934947
# sharpe_per_trade         -2.379977
# dtype: float64
# [0.3, 12, None, None, None, 12, None, None, 'low']
# new worst win_rate: n_trades                775.000000
# win_rate                  0.358710
# avg_win                   1.794979
# avg_loss                 -1.213618
# payoff_ratio              1.479032
# expectancy_per_trade     -0.134405
# gross_profit            499.004271
# gross_loss              603.168172
# profit_factor             0.827305
# total_pnl              -104.163902
# median_pnl               -0.510500
# max_drawdown           -123.934947
# sharpe_per_trade         -2.379977
# dtype: float64
# [0.3, 12, None, None, None, 12, None, None, 'low']
# new worst Returns: n_trades                801.000000
# win_rate                  0.358302
# avg_win                   1.775498
# avg_loss                 -1.197307
# payoff_ratio              1.482910
# expectancy_per_trade     -0.132145
# gross_profit            509.567937
# gross_loss              615.415755
# profit_factor             0.828006
# total_pnl              -105.847818
# median_pnl               -0.508833
# max_drawdown           -123.611447
# sharpe_per_trade         -2.412973
# dtype: float64
# [0.3, 12, None, None, None, 12, None, True, 'low']
# new worst win_rate: n_trades                801.000000
# win_rate                  0.358302
# avg_win                   1.775498
# avg_loss                 -1.197307
# payoff_ratio              1.482910
# expectancy_per_trade     -0.132145
# gross_profit            509.567937
# gross_loss              615.415755
# profit_factor             0.828006
# total_pnl              -105.847818
# median_pnl               -0.508833
# max_drawdown           -123.611447
# sharpe_per_trade         -2.412973
# dtype: float64
# [0.3, 12, None, None, None, 12, None, True, 'low']
# new worst Returns: n_trades                832.000000
# win_rate                  0.359375
# avg_win                   1.750630
# avg_loss                 -1.181869
# payoff_ratio              1.481238
# expectancy_per_trade     -0.128002
# gross_profit            523.438271
# gross_loss              629.936116
# profit_factor             0.830939
# total_pnl              -106.497845
# median_pnl               -0.506833
# max_drawdown           -123.083724
# sharpe_per_trade         -2.432606
# dtype: float64
# [0.3, 12, None, None, None, 12, True, True, 'low']
# new worst Returns: n_trades                799.000000
# win_rate                  0.356696
# avg_win                   1.775263
# avg_loss                 -1.197487
# payoff_ratio              1.482490
# expectancy_per_trade     -0.137119
# gross_profit            505.949854
# gross_loss              615.508208
# profit_factor             0.822003
# total_pnl              -109.558354
# median_pnl               -0.510500
# max_drawdown           -131.734400
# sharpe_per_trade         -2.483288
# dtype: float64
# [0.3, 12, None, None, None, 14, None, None, 'low']
# new worst win_rate: n_trades                799.000000
# win_rate                  0.356696
# avg_win                   1.775263
# avg_loss                 -1.197487
# payoff_ratio              1.482490
# expectancy_per_trade     -0.137119
# gross_profit            505.949854
# gross_loss              615.508208
# profit_factor             0.822003
# total_pnl              -109.558354
# median_pnl               -0.510500
# max_drawdown           -131.734400
# sharpe_per_trade         -2.483288
# dtype: float64
# [0.3, 12, None, None, None, 14, None, None, 'low']
# new worst Returns: n_trades                825.000000
# win_rate                  0.356364
# avg_win                   1.756849
# avg_loss                 -1.182214
# payoff_ratio              1.486066
# expectancy_per_trade     -0.134839
# gross_profit            516.513521
# gross_loss              627.755791
# profit_factor             0.822794
# total_pnl              -111.242271
# median_pnl               -0.508833
# max_drawdown           -131.410900
# sharpe_per_trade         -2.515583
# dtype: float64
# [0.3, 12, None, None, None, 14, None, True, 'low']
# new worst win_rate: n_trades                825.000000
# win_rate                  0.356364
# avg_win                   1.756849
# avg_loss                 -1.182214
# payoff_ratio              1.486066
# expectancy_per_trade     -0.134839
# gross_profit            516.513521
# gross_loss              627.755791
# profit_factor             0.822794
# total_pnl              -111.242271
# median_pnl               -0.508833
# max_drawdown           -131.410900
# sharpe_per_trade         -2.515583
# dtype: float64
# [0.3, 12, None, None, None, 14, None, True, 'low']
# new worst Returns: n_trades                789.000000
# win_rate                  0.356147
# avg_win                   1.780843
# avg_loss                 -1.204536
# payoff_ratio              1.478447
# expectancy_per_trade     -0.141302
# gross_profit            500.416771
# gross_loss              611.904210
# profit_factor             0.817802
# total_pnl              -111.487440
# median_pnl               -0.512833
# max_drawdown           -131.209694
# sharpe_per_trade         -2.515765
# dtype: float64
# [0.3, 14, None, None, None, 12, None, None, 'low']
# new worst win_rate: n_trades                789.000000
# win_rate                  0.356147
# avg_win                   1.780843
# avg_loss                 -1.204536
# payoff_ratio              1.478447
# expectancy_per_trade     -0.141302
# gross_profit            500.416771
# gross_loss              611.904210
# profit_factor             0.817802
# total_pnl              -111.487440
# median_pnl               -0.512833
# max_drawdown           -131.209694
# sharpe_per_trade         -2.515765
# dtype: float64
# [0.3, 14, None, None, None, 12, None, None, 'low']
# new worst Returns: n_trades                815.000000
# win_rate                  0.355828
# avg_win                   1.762002
# avg_loss                 -1.188861
# payoff_ratio              1.482093
# expectancy_per_trade     -0.138861
# gross_profit            510.980437
# gross_loss              624.151793
# profit_factor             0.818680
# total_pnl              -113.171356
# median_pnl               -0.510500
# max_drawdown           -130.886194
# sharpe_per_trade         -2.547892
# dtype: float64
# [0.3, 14, None, None, None, 12, None, True, 'low']
# new worst win_rate: n_trades                815.000000
# win_rate                  0.355828
# avg_win                   1.762002
# avg_loss                 -1.188861
# payoff_ratio              1.482093
# expectancy_per_trade     -0.138861
# gross_profit            510.980437
# gross_loss              624.151793
# profit_factor             0.818680
# total_pnl              -113.171356
# median_pnl               -0.510500
# max_drawdown           -130.886194
# sharpe_per_trade         -2.547892
# dtype: float64
# [0.3, 14, None, None, None, 12, None, True, 'low']
# new worst Returns: n_trades                844.000000
# win_rate                  0.356635
# avg_win                   1.743060
# avg_loss                 -1.174692
# payoff_ratio              1.483844
# expectancy_per_trade     -0.134119
# gross_profit            524.661187
# gross_loss              637.857987
# profit_factor             0.822536
# total_pnl              -113.196800
# median_pnl               -0.508583
# max_drawdown           -129.733887
# sharpe_per_trade         -2.554727
# dtype: float64
# [0.3, 14, None, None, None, 12, True, True, 'low']
# new worst Returns: n_trades                812.000000
# win_rate                  0.354680
# avg_win                   1.761675
# avg_loss                 -1.188721
# payoff_ratio              1.481992
# expectancy_per_trade     -0.142275
# gross_profit            507.362354
# gross_loss              622.889579
# profit_factor             0.814530
# total_pnl              -115.527225
# median_pnl               -0.510786
# max_drawdown           -137.654479
# sharpe_per_trade         -2.594645
# dtype: float64
# [0.3, 14, None, None, None, 14, None, None, 'low']
# new worst win_rate: n_trades                812.000000
# win_rate                  0.354680
# avg_win                   1.761675
# avg_loss                 -1.188721
# payoff_ratio              1.481992
# expectancy_per_trade     -0.142275
# gross_profit            507.362354
# gross_loss              622.889579
# profit_factor             0.814530
# total_pnl              -115.527225
# median_pnl               -0.510786
# max_drawdown           -137.654479
# sharpe_per_trade         -2.594645
# dtype: float64
# [0.3, 14, None, None, None, 14, None, None, 'low']
# new worst Returns: n_trades                838.000000
# win_rate                  0.354415
# avg_win                   1.743859
# avg_loss                 -1.174006
# payoff_ratio              1.485392
# expectancy_per_trade     -0.139870
# gross_profit            517.926021
# gross_loss              635.137162
# profit_factor             0.815455
# total_pnl              -117.211142
# median_pnl               -0.509667
# max_drawdown           -137.330979
# sharpe_per_trade         -2.626234
# dtype: float64
# [0.3, 14, None, None, None, 14, None, True, 'low']
# new worst win_rate: n_trades                838.000000
# win_rate                  0.354415
# avg_win                   1.743859
# avg_loss                 -1.174006
# payoff_ratio              1.485392
# expectancy_per_trade     -0.139870
# gross_profit            517.926021
# gross_loss              635.137162
# profit_factor             0.815455
# total_pnl              -117.211142
# median_pnl               -0.509667
# max_drawdown           -137.330979
# sharpe_per_trade         -2.626234
# dtype: float64
# [0.3, 14, None, None, None, 14, None, True, 'low']
# new worst win_rate: n_trades                858.000000
# win_rate                  0.354312
# avg_win                   1.733882
# avg_loss                 -1.162470
# payoff_ratio              1.491549
# expectancy_per_trade     -0.136257
# gross_profit            527.100021
# gross_loss              644.008533
# profit_factor             0.818467
# total_pnl              -116.908513
# median_pnl               -0.506833
# max_drawdown           -132.666684
# sharpe_per_trade         -2.623108
# dtype: float64
# [0.3, 18, None, None, None, 12, None, True, 'low']
# new worst Returns: n_trades                858.000000
# win_rate                  0.354312
# avg_win                   1.725242
# avg_loss                 -1.159589
# payoff_ratio              1.487805
# expectancy_per_trade     -0.137457
# gross_profit            524.473687
# gross_loss              642.412152
# profit_factor             0.816413
# total_pnl              -117.938465
# median_pnl               -0.499077
# max_drawdown           -138.380636
# sharpe_per_trade         -2.648757
# dtype: float64
# [0.3, 18, None, None, None, 14, None, None, 'low']
# new worst Returns: n_trades                879.000000
# win_rate                  0.353811
# avg_win                   1.717188
# avg_loss                 -1.149870
# payoff_ratio              1.493376
# expectancy_per_trade     -0.135473
# gross_profit            534.045604
# gross_loss              653.126236
# profit_factor             0.817676
# total_pnl              -119.080632
# median_pnl               -0.505333
# max_drawdown           -137.243803
# sharpe_per_trade         -2.667961
# dtype: float64
# [0.3, 18, None, None, None, 14, None, True, 'low']
# new worst win_rate: n_trades                879.000000
# win_rate                  0.353811
# avg_win                   1.717188
# avg_loss                 -1.149870
# payoff_ratio              1.493376
# expectancy_per_trade     -0.135473
# gross_profit            534.045604
# gross_loss              653.126236
# profit_factor             0.817676
# total_pnl              -119.080632
# median_pnl               -0.505333
# max_drawdown           -137.243803
# sharpe_per_trade         -2.667961
# dtype: float64
# [0.3, 18, None, None, None, 14, None, True, 'low']
# KeyboardInterrupt

# %%
def filterOutCounterParameters(df, listParams):


    ORB_width = listParams[0]
    ADX60 = listParams[1]
    ADX60_rising3 = listParams[2]
    DIp60_over_DIn60 = listParams[3]
    ema20_over_ema50 = listParams[4]
    ADX = listParams[5]
    DIp_over_DIn = listParams[6]
    vwap = listParams[7]
    excludeSide = listParams[8]



    mask = pd.Series(True, index=df.index)
    
    # ORB_width
    if ORB_width is not None: mask &= (df['ORB_width'] <= ORB_width)
    
    
    # ADX60
    if ADX60 is not None:
       mask &= (df['ADX60'] > ADX60)
    
    
    
    # ADX60 rising
    if ADX60_rising3 is not None:
         mask &= (df['ADX60_rising3'] == ADX60_rising3)

    # DIp60_over_DIn60
    if DIp60_over_DIn60 is not None:
        if DIp60_over_DIn60 == True:
            mask &= (((df['DIp60'] > df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] < df['DIn60']) & (df['breach'] == 'low')))
        elif DIp60_over_DIn60 == False:
            mask &= (((df['DIp60'] < df['DIn60']) & (df['breach'] == 'high')) | ((df['DIp60'] > df['DIn60']) & (df['breach'] == 'low')))
        else:
            print('error with DIp60_over_DIn60')



    # ema20_over_ema50
    if ema20_over_ema50 is not None:
        if ema20_over_ema50 == True:
            mask &= (((df['ema20'] > df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] < df['ema50']) & (df['breach'] == 'low')))
        elif ema20_over_ema50 == False:
            mask &= (((df['ema20'] < df['ema50']) & (df['breach'] == 'high')) | ((df['ema20'] > df['ema50']) & (df['breach'] == 'low')))
        else:
            print('error with DIp60_over_DIn60')

    # ADX
    if ADX is not None:
        mask &= (df['ADX'] > ADX)

    # DI+_over_DI-
    if DIp_over_DIn is not None:
        if DIp_over_DIn == True:
            mask &=(((df['+DI'] > df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] < df['-DI']) & (df['breach'] == 'low')))
        elif DIp_over_DIn == False:
            mask &=(((df['+DI'] < df['-DI']) & (df['breach'] == 'high')) | ((df['+DI'] > df['-DI']) & (df['breach'] == 'low')))
        else:
            print('error with +DI_over_-DI')

    # vwap
    if vwap is not None:
        if vwap == True:
            mask &=(((df['vwap'] < df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] > df['entryPrice']) & (df['breach'] == 'low')))
        elif vwap == False:
            mask &=(((df['vwap'] > df['entryPrice']) & (df['breach'] == 'high')) | ((df['vwap'] < df['entryPrice']) & (df['breach'] == 'low')))
        else:
            print('error with vwap')

    
    if excludeSide is not None:
        if excludeSide == 'high':
            mask &=(df['breach'] != 'high')
        elif excludeSide == 'low':
            mask &=(df['breach'] != 'low')
        else:
            print('error with excludeSide')
            
            
    return df[mask]
    


backtest_filtered = rawBacktest
backtest_filtered = filterOutCounterParameters(rawBacktest, [0.3, 18, None, None, None, 14, None, True, 'low'])
# backtest_filtered = filterOutCounterParameters(backtest_filtered, [0.6, 12, None, None, None, 12, None, True, None])
# backtest_filtered = filterOutCounterParameters(backtest_filtered, [0.8, 14, None, None, None, 12, None, None, None])


stats, equity, dd = trade_stats(backtest_filtered, pnl_col='returns')  # or r_col='R' if you have it
print(pd.Series(stats))



if 'Date' in temp.columns:
    backtest_filtered['Date'] = pd.to_datetime(backtest_filtered['Date'], errors='coerce')
    df = backtest_filtered.sort_values('Date')

r = pd.to_numeric(df['returns'], errors='coerce').fillna(0)

# 1) Cumulative PnL (use for per-trade PnL/points)
df['cum_pnl'] = r.cumsum()


import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(df['Date'] if 'Date' in df.columns else df.index, df['cum_pnl'])
plt.title('Cumulative PnL')
plt.xlabel('Date' if 'Date' in df.columns else 'Trade #')
plt.ylabel('PnL')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()



backtest_filtered
# Out:
# n_trades                175.000000
# win_rate                  0.491429
# avg_win                   1.408907
# avg_loss                 -0.697848
# payoff_ratio              2.018932
# expectancy_per_trade      0.337472
# gross_profit            121.166016
# gross_loss               62.108444
# profit_factor             1.950878
# total_pnl                59.057571
# median_pnl               -0.055167
# max_drawdown             -8.631458
# sharpe_per_trade          3.009005
# dtype: float64
# C:\Users\JayCo\AppData\Local\Temp\ipykernel_5204\215169675.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   backtest_filtered['Date'] = pd.to_datetime(backtest_filtered['Date'], errors='coerce')
#            Date timeBreach breach  OR_high  OR_low timeRetest  \
# 3    2020-01-08   09:53:00   high   323.54  322.67   10:24:00
# 6    2020-01-13   09:56:00   high   326.56  325.92   10:05:00
# 9    2020-01-16   13:36:00   high   329.99  329.54   14:04:00
# 10   2020-01-21   11:13:00   high   331.56  330.86   13:20:00
# 11   2020-01-22   09:49:00   high   332.72  332.00   10:29:00
# ...         ...        ...    ...      ...     ...        ...
# 1041 2025-07-11   10:14:00   high   623.52  621.69   10:48:00
# 1042 2025-07-14   09:51:00   high   623.35  621.79   10:25:00
# 1045 2025-07-17   09:49:00   high   625.64  624.18   09:59:00
# 1050 2025-07-24   09:47:00   high   634.91  633.99   09:54:00
# 1052 2025-07-30   09:45:00   high   636.05  635.29   11:03:00
#
#      timeConfirmationBar timeEntry  timeExit  entryPrice  ...       ema50  \
# 3               11:13:00  11:14:00  15:49:00  323.594500  ...  322.353723
# 6               10:25:00  10:26:00  15:59:00  326.645750  ...  324.364549
# 9               14:05:00  14:34:00  15:59:00  330.038667  ...  326.867556
# 10              13:25:00  13:26:00  14:01:00  331.661083  ...  328.726931
# 11              10:37:00  10:38:00  11:07:00  332.788667  ...  329.264133
# ...                  ...       ...       ...         ...  ...         ...
# 1041            10:49:00  10:50:00  15:59:00  623.793833  ...  620.584822
# 1042            10:58:00  10:59:00  15:59:00  623.428167  ...  621.372842
# 1045            10:00:00  10:07:00  15:59:00  625.868833  ...  622.637719
# 1050            09:59:00  10:00:00  10:13:00  635.084583  ...  628.011180
# 1052            11:59:00  12:00:00  14:02:00  636.167417  ...  633.664124
#
#       ema_alignment  volume60      ADX60      DIp60      DIn60  ADX60_rising3  \
# 3                 1     51908  26.603792  20.851126  18.711194          False
# 6                 1     56851  22.940106  20.582413  24.614807          False
# 9                 1     29008  18.182185  28.456936  16.264270           True
# 10                1     41826  30.243327  31.679922  16.576277          False
# 11                1     51059  25.899763  31.204085  16.990747          False
# ...             ...       ...        ...        ...        ...            ...
# 1041              1     57959  21.902099  23.443010  30.045528          False
# 1042              1     58703  18.526511  16.388058  29.101967          False
# 1045              1     82535  19.614901  18.731892  26.074741          False
# 1050              1     93199  27.222619  35.969261  11.672061           True
# 1052              1     37272  19.579287  24.020484  22.175622          False
#
#            ATR      NATR  ORB_width
# 3     0.899041  0.002780   0.269625
# 6     0.796782  0.002446   0.196367
# 9     0.808368  0.002450   0.136554
# 10    0.665832  0.002006   0.211570
# 11    0.746818  0.002245   0.216867
# ...        ...       ...        ...
# 1041  1.644612  0.002636   0.294359
# 1042  1.554269  0.002496   0.250889
# 1045  1.768276  0.002833   0.233907
# 1050  1.428511  0.002253   0.145113
# 1052  1.309101  0.002061   0.119630
#
# [175 rows x 29 columns]

# %%
worstReturns = 0
worstWinrate = 0
worstWinToDrawdown = 0


for p in make_Counterparam_grid():
    stats, worstReturns, worstWinrate, worstWinToDrawdown = testCounterParameters(backtest_filtered,
                                                                        worstReturns,
                                                                        worstWinrate,
                                                                        worstWinToDrawdown,
                                                                        ORB_width=p['ORB_width'],
                                                                        ADX60=p['ADX60'],
                                                                        ADX60_rising3=p['ADX60_rising3'],
                                                                        DIp60_over_DIn60=p['DIp60_over_DIn60'],
                                                                        # NATR=p['NATR'],
                                                                        ema20_over_ema50=p['ema20_over_ema50'],
                                                                        ADX=p['ADX'],
                                                                        DIp_over_DIn=p['DI+_over_DI-'],
                                                                        vwap=p['vwap'],
                                                                        excludeSide=p['excludeSide']
                                                                        )
    # if (len(stats) > 0):
    #     print(stats['total_pnl'])
    # print(pd.Series(stats))
print('worstReturns:\n', pd.Series(worstReturns))
print('worstWinrate:\n', pd.Series(worstWinrate))
print('worstWinToDrawdown:\n', pd.Series(worstWinToDrawdown))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 7
#       3 worstWinToDrawdown = 0
#       6 for p in make_Counterparam_grid():
# ----> 7     stats, worstReturns, worstWinrate, worstWinToDrawdown = testCounterParameters(backtest_filtered,
#       8                                                                         worstReturns,
#       9                                                                         worstWinrate,
#      10                                                                         worstWinToDrawdown,
#      11                                                                         ORB_width=p['ORB_width'],
#      12                                                                         ADX60=p['ADX60'],
#      13                                                                         ADX60_rising3=p['ADX60_rising3'],
#      14                                                                         DIp60_over_DIn60=p['DIp60_over_DIn60'],
#      15                                                                         # NATR=p['NATR'],
#      16                                                                         ema20_over_ema50=p['ema20_over_ema50'],
#      17                                                                         ADX=p['ADX'],
#      18                                                                         DIp_over_DIn=p['DI+_over_DI-'],
#      19                                                                         vwap=p['vwap'],
#      20                                                                         excludeSide=p['excludeSide']
#      21                                                                         )
#      22     # if (len(stats) > 0):
#      23     #     print(stats['total_pnl'])
#      24     # print(pd.Series(stats))
#      25 print('worstReturns:\n', pd.Series(worstReturns))
#
# NameError: name 'backtest_filtered' is not defined
